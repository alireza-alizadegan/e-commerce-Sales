# %% [markdown]
# <h1 id="tocheading">Table of Contents</h1>
# <div id="toc"></div>

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %% [markdown]
# # Data Cleaning

# %%
# frequently used python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Order Dataset

# %%
order_df = pd.read_csv('olist_orders_dataset.csv')
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
# order_id                         99441 non-null object
# customer_id                      99441 non-null object
# order_status                     99441 non-null object
# order_purchase_timestamp         99441 non-null object
# order_approved_at                99281 non-null object
# order_delivered_carrier_date     97658 non-null object
# order_delivered_customer_date    96476 non-null object
# order_estimated_delivery_date    99441 non-null object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
order_df[order_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# Index: []

# %%
order_df.drop(['order_status',
               'order_delivered_carrier_date',
               'order_approved_at',
               'order_purchase_timestamp'], axis='columns', inplace=True)

from datetime import datetime, date
for column in ['order_delivered_customer_date', 'order_estimated_delivery_date']:
    order_df[column] = pd.to_datetime(order_df[column])
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 4 columns):
# order_id                         99441 non-null object
# customer_id                      99441 non-null object
# order_delivered_customer_date    96476 non-null datetime64[ns]
# order_estimated_delivery_date    99441 non-null datetime64[ns]
# dtypes: datetime64[ns](2), object(2)
# memory usage: 3.0+ MB

# %%
order_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_delivered_customer_date order_estimated_delivery_date
# 0           2017-10-10 21:25:13                    2017-10-18
# 1           2018-08-07 15:27:45                    2018-08-13
# 2           2018-08-17 18:06:29                    2018-09-04
# 3           2017-12-02 00:28:42                    2017-12-15
# 4           2018-02-16 18:17:02                    2018-02-26

# %% [markdown]
# ## Customer Dataset

# %%
customer_df = pd.read_csv('olist_customers_dataset.csv')
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
# customer_id                 99441 non-null object
# customer_unique_id          99441 non-null object
# customer_zip_code_prefix    99441 non-null int64
# customer_city               99441 non-null object
# customer_state              99441 non-null object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customer_df[customer_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state]
# Index: []

# %%
customer_df.drop(['customer_zip_code_prefix', 'customer_city'], axis='columns', inplace=True)

# %%
customer_df.nunique()
# Out:
# customer_id           99441
# customer_unique_id    96096
# customer_state           27
# dtype: int64

# %%
customer_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#   customer_state
# 0             SP
# 1             SP
# 2             SP
# 3             SP
# 4             SP

# %% [markdown]
# ## Payment Dataset

# %%
payment_df = pd.read_csv('olist_order_payments_dataset.csv')
payment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
# order_id                103886 non-null object
# payment_sequential      103886 non-null int64
# payment_type            103886 non-null object
# payment_installments    103886 non-null int64
# payment_value           103886 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
payment_df.order_id.nunique()
# Out:
# 99440

# %%
payment_df[payment_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, payment_sequential, payment_type, payment_installments, payment_value]
# Index: []

# %%
payment_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
payment_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
payment_df.nunique()
# Out:
# order_id                99440
# payment_sequential         29
# payment_type                5
# payment_installments       24
# payment_value           29077
# dtype: int64

# %% [markdown]
# ## Review Dataset

# %%
review_df = pd.read_csv('olist_order_reviews_dataset.csv')
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
# review_id                  100000 non-null object
# order_id                   100000 non-null object
# review_score               100000 non-null int64
# review_comment_title       11715 non-null object
# review_comment_message     41753 non-null object
# review_creation_date       100000 non-null object
# review_answer_timestamp    100000 non-null object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
review_df[review_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [review_id, order_id, review_score, review_comment_title, review_comment_message, review_creation_date, review_answer_timestamp]
# Index: []

# %%
review_df.drop(['review_id', 'review_creation_date', 'review_answer_timestamp'], axis='columns', inplace=True)
review_df.columns
# Out:
# Index(['order_id', 'review_score', 'review_comment_title',
#        'review_comment_message'],
#       dtype='object')

# %%
for columns in ['review_comment_title', 'review_comment_message']:
    # replace present values with 1
    review_df.loc[review_df[columns].notnull(), columns] = 1
    # replace null values with 0
    review_df.loc[review_df[columns].isna(), columns] = 0
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
# order_id                  100000 non-null object
# review_score              100000 non-null int64
# review_comment_title      100000 non-null int64
# review_comment_message    100000 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 3.1+ MB

# %%
review_df.head()
# Out:
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  a548910a1c6147796b98fdf73dbeba33             5                     0
# 2  f9e4b658b201a9f2ecdecbb34bed034b             5                     0
# 3  658677c97b385a9be170737859d3511b             5                     0
# 4  8e6bfb81e283fa7e4f11123a3fb894f1             5                     0
#
#    review_comment_message
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       1

# %% [markdown]
# ## Item Dataset

# %%
item_df = pd.read_csv('olist_order_items_dataset.csv')

# %%
item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
# order_id               112650 non-null object
# order_item_id          112650 non-null int64
# product_id             112650 non-null object
# seller_id              112650 non-null object
# shipping_limit_date    112650 non-null object
# price                  112650 non-null float64
# freight_value          112650 non-null float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
item_df[item_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value]
# Index: []

# %%
'''
item_df.drop(['seller_id',
              'shipping_limit_date',
              'price',
              'freight_value',
              'order_item_id'], axis='columns', inplace=True)
item_df.columns
'''
# Out:
# "\nitem_df.drop(['seller_id',\n              'shipping_limit_date',\n              'price',\n              'freight_value',\n              'order_item_id'], axis='columns', inplace=True)\nitem_df.columns\n"

# %%
item_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
item_df.order_id.nunique()
# Out:
# 98666

# %% [markdown]
# ## Product Dataset

# %%
product_df = pd.read_csv('olist_products_dataset.csv')

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
# product_id                    32951 non-null object
# product_category_name         32341 non-null object
# product_name_lenght           32341 non-null float64
# product_description_lenght    32341 non-null float64
# product_photos_qty            32341 non-null float64
# product_weight_g              32949 non-null float64
# product_length_cm             32949 non-null float64
# product_height_cm             32949 non-null float64
# product_width_cm              32949 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df[product_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm]
# Index: []

# %%
'''
product_df.drop(['product_name_lenght',
                 'product_description_lenght', 
                 'product_photos_qty', 
                 'product_weight_g',
                 'product_length_cm',
                 'product_height_cm',
                 'product_width_cm'], axis='columns', inplace=True)
'''
# Out:
# "\nproduct_df.drop(['product_name_lenght',\n                 'product_description_lenght', \n                 'product_photos_qty', \n                 'product_weight_g',\n                 'product_length_cm',\n                 'product_height_cm',\n                 'product_width_cm'], axis='columns', inplace=True)\n"

# %%
product_df.fillna(product_df.median(), inplace=True)
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
# product_id                    32951 non-null object
# product_category_name         32341 non-null object
# product_name_lenght           32951 non-null float64
# product_description_lenght    32951 non-null float64
# product_photos_qty            32951 non-null float64
# product_weight_g              32951 non-null float64
# product_length_cm             32951 non-null float64
# product_height_cm             32951 non-null float64
# product_width_cm              32951 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.fillna('other', inplace=True)
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
# product_id                    32951 non-null object
# product_category_name         32951 non-null object
# product_name_lenght           32951 non-null float64
# product_description_lenght    32951 non-null float64
# product_photos_qty            32951 non-null float64
# product_weight_g              32951 non-null float64
# product_length_cm             32951 non-null float64
# product_height_cm             32951 non-null float64
# product_width_cm              32951 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
product_df.product_category_name.nunique()
# Out:
# 74

# %% [markdown]
# ## Translation Dataset

# %%
translation_df = pd.read_csv('product_category_name_translation.csv')
translation_df.info()
translation_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
# product_category_name            71 non-null object
# product_category_name_english    71 non-null object
# dtypes: object(2)
# memory usage: 1.2+ KB
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# ## Seller Dataset

# %%
seller_df = pd.read_csv('olist_sellers_dataset.csv')
seller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
# seller_id                 3095 non-null object
# seller_zip_code_prefix    3095 non-null int64
# seller_city               3095 non-null object
# seller_state              3095 non-null object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
seller_df.drop(['seller_zip_code_prefix', 'seller_city'], axis='columns', inplace=True)
seller_df.columns
# Out:
# Index(['seller_id', 'seller_state'], dtype='object')

# %% [markdown]
# ## Database Joins

# %%
ro_df = pd.merge(review_df, order_df, how='left', on='order_id')
ro_df.info()
ro_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
# order_id                         100000 non-null object
# review_score                     100000 non-null int64
# review_comment_title             100000 non-null int64
# review_comment_message           100000 non-null int64
# customer_id                      100000 non-null object
# order_delivered_customer_date    97013 non-null datetime64[ns]
# order_estimated_delivery_date    100000 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int64(3), object(2)
# memory usage: 6.1+ MB
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  a548910a1c6147796b98fdf73dbeba33             5                     0
# 2  f9e4b658b201a9f2ecdecbb34bed034b             5                     0
# 3  658677c97b385a9be170737859d3511b             5                     0
# 4  8e6bfb81e283fa7e4f11123a3fb894f1             5                     0
#
#    review_comment_message                       customer_id  \
# 0                       0  41dcb106f807e993532d446263290104
# 1                       0  8a2e7ef9053dea531e4dc76bd6d853e6
# 2                       0  e226dfed6544df5b7b87a48208690feb
# 3                       1  de6dff97e5f1ba84a3cd9a3bc97df5f6
# 4                       1  5986b333ca0d44534a156a52a8e33a83
#
#   order_delivered_customer_date order_estimated_delivery_date
# 0           2018-01-17 18:42:41                    2018-02-02
# 1           2018-03-09 23:17:20                    2018-03-14
# 2           2018-02-16 17:28:48                    2018-03-09
# 3           2017-04-20 09:08:35                    2017-05-10
# 4           2018-02-28 16:33:35                    2018-03-09

# %%
roc_df = pd.merge(ro_df, customer_df, how='left', on='customer_id')
roc_df.drop(['customer_id', 'customer_unique_id'], axis='columns', inplace=True)
roc_df.info()
roc_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
# order_id                         100000 non-null object
# review_score                     100000 non-null int64
# review_comment_title             100000 non-null int64
# review_comment_message           100000 non-null int64
# order_delivered_customer_date    97013 non-null datetime64[ns]
# order_estimated_delivery_date    100000 non-null datetime64[ns]
# customer_state                   100000 non-null object
# dtypes: datetime64[ns](2), int64(3), object(2)
# memory usage: 6.1+ MB
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  a548910a1c6147796b98fdf73dbeba33             5                     0
# 2  f9e4b658b201a9f2ecdecbb34bed034b             5                     0
# 3  658677c97b385a9be170737859d3511b             5                     0
# 4  8e6bfb81e283fa7e4f11123a3fb894f1             5                     0
#
#    review_comment_message order_delivered_customer_date  \
# 0                       0           2018-01-17 18:42:41
# 1                       0           2018-03-09 23:17:20
# 2                       0           2018-02-16 17:28:48
# 3                       1           2017-04-20 09:08:35
# 4                       1           2018-02-28 16:33:35
#
#   order_estimated_delivery_date customer_state
# 0                    2018-02-02             SP
# 1                    2018-03-14             SP
# 2                    2018-03-09             BA
# 3                    2017-05-10             SC
# 4                    2018-03-09             SC

# %%
rocp_df = pd.merge(roc_df, payment_df, on='order_id')
rocp_df.drop('payment_sequential', axis='columns', inplace=True)
rocp_df.info()
rocp_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104485 entries, 0 to 104484
# Data columns (total 10 columns):
# order_id                         104485 non-null object
# review_score                     104485 non-null int64
# review_comment_title             104485 non-null int64
# review_comment_message           104485 non-null int64
# order_delivered_customer_date    101331 non-null datetime64[ns]
# order_estimated_delivery_date    104485 non-null datetime64[ns]
# customer_state                   104485 non-null object
# payment_type                     104485 non-null object
# payment_installments             104485 non-null int64
# payment_value                    104485 non-null float64
# dtypes: datetime64[ns](2), float64(1), int64(4), object(3)
# memory usage: 8.8+ MB
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  a548910a1c6147796b98fdf73dbeba33             5                     0
# 2  f9e4b658b201a9f2ecdecbb34bed034b             5                     0
# 3  658677c97b385a9be170737859d3511b             5                     0
# 4  8e6bfb81e283fa7e4f11123a3fb894f1             5                     0
#
#    review_comment_message order_delivered_customer_date  \
# 0                       0           2018-01-17 18:42:41
# 1                       0           2018-03-09 23:17:20
# 2                       0           2018-02-16 17:28:48
# 3                       1           2017-04-20 09:08:35
# 4                       1           2018-02-28 16:33:35
#
#   order_estimated_delivery_date customer_state payment_type  \
# 0                    2018-02-02             SP  credit_card
# 1                    2018-03-14             SP  credit_card
# 2                    2018-03-09             BA  credit_card
# 3                    2017-05-10             SC  credit_card
# 4                    2018-03-09             SC  credit_card
#
#    payment_installments  payment_value
# 0                     8         397.26
# 1                     1          88.09
# 2                     1         194.12
# 3                     1         222.84
# 4                    10        1333.25

# %%
rocpi_df = pd.merge(rocp_df, item_df, on='order_id')
rocpi_df.drop(['shipping_limit_date', 'order_item_id'], axis='columns', inplace=True)
rocpi_df.info()
rocpi_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 14 columns):
# order_id                         118315 non-null object
# review_score                     118315 non-null int64
# review_comment_title             118315 non-null int64
# review_comment_message           118315 non-null int64
# order_delivered_customer_date    115727 non-null datetime64[ns]
# order_estimated_delivery_date    118315 non-null datetime64[ns]
# customer_state                   118315 non-null object
# payment_type                     118315 non-null object
# payment_installments             118315 non-null int64
# payment_value                    118315 non-null float64
# product_id                       118315 non-null object
# seller_id                        118315 non-null object
# price                            118315 non-null float64
# freight_value                    118315 non-null float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(5)
# memory usage: 13.5+ MB
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  73fc7af87114b39712e6da79b0a377eb             4                     0
# 2  a548910a1c6147796b98fdf73dbeba33             5                     0
# 3  f9e4b658b201a9f2ecdecbb34bed034b             5                     0
# 4  658677c97b385a9be170737859d3511b             5                     0
#
#    review_comment_message order_delivered_customer_date  \
# 0                       0           2018-01-17 18:42:41
# 1                       0           2018-01-17 18:42:41
# 2                       0           2018-03-09 23:17:20
# 3                       0           2018-02-16 17:28:48
# 4                       1           2017-04-20 09:08:35
#
#   order_estimated_delivery_date customer_state payment_type  \
# 0                    2018-02-02             SP  credit_card
# 1                    2018-02-02             SP  credit_card
# 2                    2018-03-14             SP  credit_card
# 3                    2018-03-09             BA  credit_card
# 4                    2017-05-10             SC  credit_card
#
#    payment_installments  payment_value                        product_id  \
# 0                     8         397.26  fd25ab760bfbba13c198fa3b4f1a0cd3
# 1                     8         397.26  fd25ab760bfbba13c198fa3b4f1a0cd3
# 2                     1          88.09  be0dbdc3d67d55727a65d4cd696ca73c
# 3                     1         194.12  d1c427060a0f73f6b889a5c7c61f2ac4
# 4                     1         222.84  52c80cedd4e90108bf4fa6a206ef6b03
#
#                           seller_id   price  freight_value
# 0  6d803cb79cc31c41c4c789a75933b3c7  185.00          13.63
# 1  6d803cb79cc31c41c4c789a75933b3c7  185.00          13.63
# 2  8e6d7754bc7e0f22c96d255ebda59eba   79.79           8.30
# 3  a1043bafd471dff536d0c462352beb48  149.00          45.12
# 4  a1043bafd471dff536d0c462352beb48  179.99          42.85

# %%
rocpip_df = pd.merge(rocpi_df, product_df, on='product_id')
rocpip_df.drop('product_id', axis='columns', inplace=True)
rocpip_df.info()
rocpip_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 21 columns):
# order_id                         118315 non-null object
# review_score                     118315 non-null int64
# review_comment_title             118315 non-null int64
# review_comment_message           118315 non-null int64
# order_delivered_customer_date    115727 non-null datetime64[ns]
# order_estimated_delivery_date    118315 non-null datetime64[ns]
# customer_state                   118315 non-null object
# payment_type                     118315 non-null object
# payment_installments             118315 non-null int64
# payment_value                    118315 non-null float64
# seller_id                        118315 non-null object
# price                            118315 non-null float64
# freight_value                    118315 non-null float64
# product_category_name            118315 non-null object
# product_name_lenght              118315 non-null float64
# product_description_lenght       118315 non-null float64
# product_photos_qty               118315 non-null float64
# product_weight_g                 118315 non-null float64
# product_length_cm                118315 non-null float64
# product_height_cm                118315 non-null float64
# product_width_cm                 118315 non-null float64
# dtypes: datetime64[ns](2), float64(10), int64(4), object(5)
# memory usage: 19.9+ MB
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  73fc7af87114b39712e6da79b0a377eb             4                     0
# 2  19721d59a9764437477eff0730b48665             5                     0
# 3  efd626e6a12a82d76e456e34093f8356             5                     0
# 4  a548910a1c6147796b98fdf73dbeba33             5                     0
#
#    review_comment_message order_delivered_customer_date  \
# 0                       0           2018-01-17 18:42:41
# 1                       0           2018-01-17 18:42:41
# 2                       0           2018-04-09 21:53:23
# 3                       0           2017-12-27 18:19:53
# 4                       0           2018-03-09 23:17:20
#
#   order_estimated_delivery_date customer_state payment_type  \
# 0                    2018-02-02             SP  credit_card
# 1                    2018-02-02             SP  credit_card
# 2                    2018-04-27             RS  credit_card
# 3                    2018-01-08             MG  credit_card
# 4                    2018-03-14             SP  credit_card
#
#    payment_installments  payment_value  ...   price  freight_value  \
# 0                     8         397.26  ...  185.00          13.63
# 1                     8         397.26  ...  185.00          13.63
# 2                     3         205.26  ...  185.00          20.26
# 3                     2         202.05  ...  185.00          17.05
# 4                     1          88.09  ...   79.79           8.30
#
#     product_category_name product_name_lenght  product_description_lenght  \
# 0           esporte_lazer                42.0                       858.0
# 1           esporte_lazer                42.0                       858.0
# 2           esporte_lazer                42.0                       858.0
# 3           esporte_lazer                42.0                       858.0
# 4  informatica_acessorios                47.0                       493.0
#
#    product_photos_qty  product_weight_g  product_length_cm  product_height_cm  \
# 0                 1.0            1300.0               30.0               30.0
# 1                 1.0            1300.0               30.0               30.0
# 2                 1.0            1300.0               30.0               30.0
# 3                 1.0            1300.0               30.0               30.0
# 4                 1.0             245.0               19.0               14.0
#
#    product_width_cm
# 0              35.0
# 1              35.0
# 2              35.0
# 3              35.0
# 4              14.0
#
# [5 rows x 21 columns]

# %%
rocpips_df = pd.merge(rocpip_df, seller_df, on='seller_id')
rocpips_df.drop('seller_id', axis='columns', inplace=True)
rocpips_df.info()
rocpips_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 21 columns):
# order_id                         118315 non-null object
# review_score                     118315 non-null int64
# review_comment_title             118315 non-null int64
# review_comment_message           118315 non-null int64
# order_delivered_customer_date    115727 non-null datetime64[ns]
# order_estimated_delivery_date    118315 non-null datetime64[ns]
# customer_state                   118315 non-null object
# payment_type                     118315 non-null object
# payment_installments             118315 non-null int64
# payment_value                    118315 non-null float64
# price                            118315 non-null float64
# freight_value                    118315 non-null float64
# product_category_name            118315 non-null object
# product_name_lenght              118315 non-null float64
# product_description_lenght       118315 non-null float64
# product_photos_qty               118315 non-null float64
# product_weight_g                 118315 non-null float64
# product_length_cm                118315 non-null float64
# product_height_cm                118315 non-null float64
# product_width_cm                 118315 non-null float64
# seller_state                     118315 non-null object
# dtypes: datetime64[ns](2), float64(10), int64(4), object(5)
# memory usage: 19.9+ MB
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  73fc7af87114b39712e6da79b0a377eb             4                     0
# 2  19721d59a9764437477eff0730b48665             5                     0
# 3  efd626e6a12a82d76e456e34093f8356             5                     0
# 4  b0bc656fed47584c160f8cff2d7b8bbd             5                     0
#
#    review_comment_message order_delivered_customer_date  \
# 0                       0           2018-01-17 18:42:41
# 1                       0           2018-01-17 18:42:41
# 2                       0           2018-04-09 21:53:23
# 3                       0           2017-12-27 18:19:53
# 4                       0           2018-03-16 14:16:19
#
#   order_estimated_delivery_date customer_state payment_type  \
# 0                    2018-02-02             SP  credit_card
# 1                    2018-02-02             SP  credit_card
# 2                    2018-04-27             RS  credit_card
# 3                    2018-01-08             MG  credit_card
# 4                    2018-03-23             MG  credit_card
#
#    payment_installments  payment_value  ...  freight_value  \
# 0                     8         397.26  ...          13.63
# 1                     8         397.26  ...          13.63
# 2                     3         205.26  ...          20.26
# 3                     2         202.05  ...          17.05
# 4                     1         306.40  ...          18.20
#
#    product_category_name product_name_lenght  product_description_lenght  \
# 0          esporte_lazer                42.0                       858.0
# 1          esporte_lazer                42.0                       858.0
# 2          esporte_lazer                42.0                       858.0
# 3          esporte_lazer                42.0                       858.0
# 4          esporte_lazer                47.0                       858.0
#
#    product_photos_qty  product_weight_g  product_length_cm  product_height_cm  \
# 0                 1.0            1300.0               30.0               30.0
# 1                 1.0            1300.0               30.0               30.0
# 2                 1.0            1300.0               30.0               30.0
# 3                 1.0            1300.0               30.0               30.0
# 4                 1.0            1600.0               30.0               30.0
#
#    product_width_cm  seller_state
# 0              35.0            SP
# 1              35.0            SP
# 2              35.0            SP
# 3              35.0            SP
# 4              35.0            SP
#
# [5 rows x 21 columns]

# %% [markdown]
# # Exploratory Data Analytics

# %% [markdown]
# ## Score Distribution

# %%
review_df.nunique()
# Out:
# order_id                  99441
# review_score                  5
# review_comment_title          2
# review_comment_message        2
# dtype: int64

# %%
review_df.review_score.value_counts(normalize=True)
# Out:
# 5    0.57420
# 4    0.19200
# 1    0.11858
# 3    0.08287
# 2    0.03235
# Name: review_score, dtype: float64

# %%
plt.bar(review_df.review_score.value_counts().index, review_df.review_score.value_counts().values)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Price vs. Payment

# %%
payment_value_df = pd.DataFrame(payment_df.groupby('order_id')['payment_value'].sum())
payment_value_df
# Out:
#                                   payment_value
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214          72.19
# 00018f77f2f0320c557190d7a144bdd3         259.83
# 000229ec398224ef6ca0657da4fc703e         216.87
# 00024acbcdf0a6daa1e931b038114c75          25.78
# 00042b26cf59d7ce69dfabb4e55b4fd9         218.04
# ...                                         ...
# fffc94f6ce00a00581880bf54a75a037         343.40
# fffcd46ef2263f404302a634eb57f7eb         386.53
# fffce4705a9662cd70adb13d4a31832d         116.85
# fffe18544ffabc95dfada21779c9644f          64.71
# fffe41c64501cc87c801fd61db3f6244          55.79
#
# [99440 rows x 1 columns]

# %%
price_df = pd.DataFrame(item_df.groupby('order_id')['price'].sum())
price_df
# Out:
#                                    price
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214   58.90
# 00018f77f2f0320c557190d7a144bdd3  239.90
# 000229ec398224ef6ca0657da4fc703e  199.00
# 00024acbcdf0a6daa1e931b038114c75   12.99
# 00042b26cf59d7ce69dfabb4e55b4fd9  199.90
# ...                                  ...
# fffc94f6ce00a00581880bf54a75a037  299.99
# fffcd46ef2263f404302a634eb57f7eb  350.00
# fffce4705a9662cd70adb13d4a31832d   99.90
# fffe18544ffabc95dfada21779c9644f   55.99
# fffe41c64501cc87c801fd61db3f6244   43.00
#
# [98666 rows x 1 columns]

# %%
payment_price_df = pd.merge(payment_value_df, price_df, how='left', left_index=True, right_index=True)
payment_price_df['overcharge'] = payment_price_df.payment_value - payment_price_df.price
payment_price_df
# Out:
#                                   payment_value   price  overcharge
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214          72.19   58.90       13.29
# 00018f77f2f0320c557190d7a144bdd3         259.83  239.90       19.93
# 000229ec398224ef6ca0657da4fc703e         216.87  199.00       17.87
# 00024acbcdf0a6daa1e931b038114c75          25.78   12.99       12.79
# 00042b26cf59d7ce69dfabb4e55b4fd9         218.04  199.90       18.14
# ...                                         ...     ...         ...
# fffc94f6ce00a00581880bf54a75a037         343.40  299.99       43.41
# fffcd46ef2263f404302a634eb57f7eb         386.53  350.00       36.53
# fffce4705a9662cd70adb13d4a31832d         116.85   99.90       16.95
# fffe18544ffabc95dfada21779c9644f          64.71   55.99        8.72
# fffe41c64501cc87c801fd61db3f6244          55.79   43.00       12.79
#
# [99440 rows x 3 columns]

# %%
payment_price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99440 entries, 00010242fe8c5a6d1ba2dd792cb16214 to fffe41c64501cc87c801fd61db3f6244
# Data columns (total 3 columns):
# payment_value    99440 non-null float64
# price            98665 non-null float64
# overcharge       98665 non-null float64
# dtypes: float64(3)
# memory usage: 5.5+ MB

# %%
plt.scatter(payment_price_df.payment_value, payment_price_df.price)

# %%
plt.hist(payment_price_df.overcharge, bins=100);

# %%
print(payment_price_df.overcharge.min())
print(payment_price_df.overcharge.max())
# Out:
# -5.170000000000016
# 1794.96

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Delivery Delay

# %%
rocpips_df['delay'] = (rocpips_df.order_delivered_customer_date - rocpips_df.order_estimated_delivery_date).dt.days
rocpips_df.drop(['order_delivered_customer_date', 'order_estimated_delivery_date'], axis='columns', inplace=True)
rocpips_df.fillna(rocpips_df.median(), inplace=True)

# %%
rocpips_df
# Out:
#                                 order_id  review_score  review_comment_title  \
# 0       73fc7af87114b39712e6da79b0a377eb             4                     0
# 1       73fc7af87114b39712e6da79b0a377eb             4                     0
# 2       19721d59a9764437477eff0730b48665             5                     0
# 3       efd626e6a12a82d76e456e34093f8356             5                     0
# 4       b0bc656fed47584c160f8cff2d7b8bbd             5                     0
# ...                                  ...           ...                   ...
# 118310  8c1d27c10cc60cc369a428813bb71350             4                     1
# 118311  80ba449ea98f8e879a829759b5a66294             5                     0
# 118312  5fd71cc4eb69ae6f65ac3acfcbc17ab5             5                     0
# 118313  61d5f1dcdf9b023ea7622b65d2362e4f             1                     0
# 118314  5f4a120717a4d152577d7d2ec66c45be             5                     0
#
#         review_comment_message customer_state payment_type  \
# 0                            0             SP  credit_card
# 1                            0             SP  credit_card
# 2                            0             RS  credit_card
# 3                            0             MG  credit_card
# 4                            0             MG  credit_card
# ...                        ...            ...          ...
# 118310                       1             MG  credit_card
# 118311                       0             GO  credit_card
# 118312                       0             RJ  credit_card
# 118313                       1             SP  credit_card
# 118314                       0             RJ  credit_card
#
#         payment_installments  payment_value  price  freight_value  \
# 0                          8         397.26  185.0          13.63
# 1                          8         397.26  185.0          13.63
# 2                          3         205.26  185.0          20.26
# 3                          2         202.05  185.0          17.05
# 4                          1         306.40  135.0          18.20
# ...                      ...            ...    ...            ...
# 118310                     1         108.63   89.9          18.73
# 118311                     4         327.25  289.9          37.35
# 118312                     2          98.34   79.9          18.44
# 118313                     8         767.69  750.0          17.69
# 118314                     3         201.34  161.0          40.34
#
#                                  product_category_name  product_name_lenght  \
# 0                                        esporte_lazer                 42.0
# 1                                        esporte_lazer                 42.0
# 2                                        esporte_lazer                 42.0
# 3                                        esporte_lazer                 42.0
# 4                                        esporte_lazer                 47.0
# ...                                                ...                  ...
# 118310                                moveis_decoracao                 50.0
# 118311                                    beleza_saude                 47.0
# 118312                         sinalizacao_e_seguranca                 36.0
# 118313                              relogios_presentes                 43.0
# 118314  moveis_cozinha_area_de_servico_jantar_e_jardim                 38.0
#
#         product_description_lenght  product_photos_qty  product_weight_g  \
# 0                            858.0                 1.0            1300.0
# 1                            858.0                 1.0            1300.0
# 2                            858.0                 1.0            1300.0
# 3                            858.0                 1.0            1300.0
# 4                            858.0                 1.0            1600.0
# ...                            ...                 ...               ...
# 118310                      1141.0                 2.0             450.0
# 118311                       696.0                 1.0             692.0
# 118312                       609.0                 2.0             575.0
# 118313                       381.0                 4.0             350.0
# 118314                       245.0                 1.0            4000.0
#
#         product_length_cm  product_height_cm  product_width_cm seller_state  \
# 0                    30.0               30.0              35.0           SP
# 1                    30.0               30.0              35.0           SP
# 2                    30.0               30.0              35.0           SP
# 3                    30.0               30.0              35.0           SP
# 4                    30.0               30.0              35.0           SP
# ...                   ...                ...               ...          ...
# 118310               16.0               16.0              16.0           SP
# 118311               15.0               12.0              14.0           PR
# 118312               45.0               21.0              23.0           SP
# 118313               20.0               20.0              20.0           SP
# 118314               31.0               42.0              43.0           PR
#
#         delay
# 0       -16.0
# 1       -16.0
# 2       -18.0
# 3       -12.0
# 4        -7.0
# ...       ...
# 118310  -14.0
# 118311  -15.0
# 118312  -14.0
# 118313   -7.0
# 118314  -24.0
#
# [118315 rows x 20 columns]

# %% [markdown]
# ## Extra Charge

# %%
rocpipso_df = pd.merge(rocpips_df, pd.DataFrame(payment_price_df.overcharge), how='left', left_on='order_id', right_index=True)
rocpipso_df
# Out:
#                                 order_id  review_score  review_comment_title  \
# 0       73fc7af87114b39712e6da79b0a377eb             4                     0
# 1       73fc7af87114b39712e6da79b0a377eb             4                     0
# 2       19721d59a9764437477eff0730b48665             5                     0
# 3       efd626e6a12a82d76e456e34093f8356             5                     0
# 4       b0bc656fed47584c160f8cff2d7b8bbd             5                     0
# ...                                  ...           ...                   ...
# 118310  8c1d27c10cc60cc369a428813bb71350             4                     1
# 118311  80ba449ea98f8e879a829759b5a66294             5                     0
# 118312  5fd71cc4eb69ae6f65ac3acfcbc17ab5             5                     0
# 118313  61d5f1dcdf9b023ea7622b65d2362e4f             1                     0
# 118314  5f4a120717a4d152577d7d2ec66c45be             5                     0
#
#         review_comment_message customer_state payment_type  \
# 0                            0             SP  credit_card
# 1                            0             SP  credit_card
# 2                            0             RS  credit_card
# 3                            0             MG  credit_card
# 4                            0             MG  credit_card
# ...                        ...            ...          ...
# 118310                       1             MG  credit_card
# 118311                       0             GO  credit_card
# 118312                       0             RJ  credit_card
# 118313                       1             SP  credit_card
# 118314                       0             RJ  credit_card
#
#         payment_installments  payment_value  price  freight_value  ...  \
# 0                          8         397.26  185.0          13.63  ...
# 1                          8         397.26  185.0          13.63  ...
# 2                          3         205.26  185.0          20.26  ...
# 3                          2         202.05  185.0          17.05  ...
# 4                          1         306.40  135.0          18.20  ...
# ...                      ...            ...    ...            ...  ...
# 118310                     1         108.63   89.9          18.73  ...
# 118311                     4         327.25  289.9          37.35  ...
# 118312                     2          98.34   79.9          18.44  ...
# 118313                     8         767.69  750.0          17.69  ...
# 118314                     3         201.34  161.0          40.34  ...
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     42.0                       858.0                 1.0
# 1                     42.0                       858.0                 1.0
# 2                     42.0                       858.0                 1.0
# 3                     42.0                       858.0                 1.0
# 4                     47.0                       858.0                 1.0
# ...                    ...                         ...                 ...
# 118310                50.0                      1141.0                 2.0
# 118311                47.0                       696.0                 1.0
# 118312                36.0                       609.0                 2.0
# 118313                43.0                       381.0                 4.0
# 118314                38.0                       245.0                 1.0
#
#         product_weight_g  product_length_cm  product_height_cm  \
# 0                 1300.0               30.0               30.0
# 1                 1300.0               30.0               30.0
# 2                 1300.0               30.0               30.0
# 3                 1300.0               30.0               30.0
# 4                 1600.0               30.0               30.0
# ...                  ...                ...                ...
# 118310             450.0               16.0               16.0
# 118311             692.0               15.0               12.0
# 118312             575.0               45.0               21.0
# 118313             350.0               20.0               20.0
# 118314            4000.0               31.0               42.0
#
#         product_width_cm  seller_state delay  overcharge
# 0                   35.0            SP -16.0       27.26
# 1                   35.0            SP -16.0       27.26
# 2                   35.0            SP -18.0       20.26
# 3                   35.0            SP -12.0       17.05
# 4                   35.0            SP  -7.0       36.40
# ...                  ...           ...   ...         ...
# 118310              16.0            SP -14.0       18.73
# 118311              14.0            PR -15.0       37.35
# 118312              23.0            SP -14.0       18.44
# 118313              20.0            SP  -7.0       17.69
# 118314              43.0            PR -24.0       40.34
#
# [118315 rows x 21 columns]

# %%
dummies_df = rocpipso_df.drop('order_id', axis='columns')
dummied_df = pd.get_dummies(dummies_df)
target = dummied_df.review_score
df = dummied_df.drop('review_score', axis='columns')
df['review_score'] = target

# %% [markdown]
# # Correlation Analysis

# %%
from scipy import stats
corr_array=[]
for i in range(df.shape[1]-1):  
    corr_array.append([df.columns[i],
                       np.abs(stats.pearsonr(df[df.columns[i]], df[df.columns[-1]])[0]),
                       stats.pearsonr(df[df.columns[i]], df[df.columns[-1]])[0],
                       stats.pearsonr(df[df.columns[i]], df[df.columns[-1]])[1]])
    
corr_df = pd.DataFrame(corr_array, columns = ['feature', 'abs_corr', 'corr', 'p_value'])
corr_df.sort_values(by='abs_corr', ascending=False, inplace=True)
corr_df.reset_index(drop=True, inplace=True)
corr_df
# Out:
#                                             feature  abs_corr      corr  \
# 0                            review_comment_message  0.292954 -0.292954
# 1                                             delay  0.217062 -0.217062
# 2                                        overcharge  0.133149 -0.133149
# 3                                     payment_value  0.084428 -0.084428
# 4                                 customer_state_RJ  0.061966 -0.061966
# ..                                              ...       ...       ...
# 138                product_category_name_la_cuisine  0.000640 -0.000640
# 139  product_category_name_tablets_impressao_imagem  0.000609  0.000609
# 140                                 seller_state_PI  0.000495  0.000495
# 141        product_category_name_ferramentas_jardim  0.000463 -0.000463
# 142              product_category_name_market_place  0.000019  0.000019
#
#            p_value
# 0     0.000000e+00
# 1     0.000000e+00
# 2     0.000000e+00
# 3    4.498171e-186
# 4    5.408486e-101
# ..             ...
# 138   8.257624e-01
# 139   8.341371e-01
# 140   8.648774e-01
# 141   8.735259e-01
# 142   9.947402e-01
#
# [143 rows x 4 columns]

# %%
rocpipso_df = pd.merge(rocpips_df, pd.DataFrame(payment_price_df.overcharge), how='left', left_on='order_id', right_index=True)
rocpipso_df
# Out:
#                                 order_id  review_score  review_comment_title  \
# 0       73fc7af87114b39712e6da79b0a377eb             4                     0
# 1       73fc7af87114b39712e6da79b0a377eb             4                     0
# 2       19721d59a9764437477eff0730b48665             5                     0
# 3       efd626e6a12a82d76e456e34093f8356             5                     0
# 4       b0bc656fed47584c160f8cff2d7b8bbd             5                     0
# ...                                  ...           ...                   ...
# 118310  8c1d27c10cc60cc369a428813bb71350             4                     1
# 118311  80ba449ea98f8e879a829759b5a66294             5                     0
# 118312  5fd71cc4eb69ae6f65ac3acfcbc17ab5             5                     0
# 118313  61d5f1dcdf9b023ea7622b65d2362e4f             1                     0
# 118314  5f4a120717a4d152577d7d2ec66c45be             5                     0
#
#         review_comment_message customer_state payment_type  \
# 0                            0             SP  credit_card
# 1                            0             SP  credit_card
# 2                            0             RS  credit_card
# 3                            0             MG  credit_card
# 4                            0             MG  credit_card
# ...                        ...            ...          ...
# 118310                       1             MG  credit_card
# 118311                       0             GO  credit_card
# 118312                       0             RJ  credit_card
# 118313                       1             SP  credit_card
# 118314                       0             RJ  credit_card
#
#         payment_installments  payment_value  price  freight_value  ...  \
# 0                          8         397.26  185.0          13.63  ...
# 1                          8         397.26  185.0          13.63  ...
# 2                          3         205.26  185.0          20.26  ...
# 3                          2         202.05  185.0          17.05  ...
# 4                          1         306.40  135.0          18.20  ...
# ...                      ...            ...    ...            ...  ...
# 118310                     1         108.63   89.9          18.73  ...
# 118311                     4         327.25  289.9          37.35  ...
# 118312                     2          98.34   79.9          18.44  ...
# 118313                     8         767.69  750.0          17.69  ...
# 118314                     3         201.34  161.0          40.34  ...
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     42.0                       858.0                 1.0
# 1                     42.0                       858.0                 1.0
# 2                     42.0                       858.0                 1.0
# 3                     42.0                       858.0                 1.0
# 4                     47.0                       858.0                 1.0
# ...                    ...                         ...                 ...
# 118310                50.0                      1141.0                 2.0
# 118311                47.0                       696.0                 1.0
# 118312                36.0                       609.0                 2.0
# 118313                43.0                       381.0                 4.0
# 118314                38.0                       245.0                 1.0
#
#         product_weight_g  product_length_cm  product_height_cm  \
# 0                 1300.0               30.0               30.0
# 1                 1300.0               30.0               30.0
# 2                 1300.0               30.0               30.0
# 3                 1300.0               30.0               30.0
# 4                 1600.0               30.0               30.0
# ...                  ...                ...                ...
# 118310             450.0               16.0               16.0
# 118311             692.0               15.0               12.0
# 118312             575.0               45.0               21.0
# 118313             350.0               20.0               20.0
# 118314            4000.0               31.0               42.0
#
#         product_width_cm  seller_state delay  overcharge
# 0                   35.0            SP -16.0       27.26
# 1                   35.0            SP -16.0       27.26
# 2                   35.0            SP -18.0       20.26
# 3                   35.0            SP -12.0       17.05
# 4                   35.0            SP  -7.0       36.40
# ...                  ...           ...   ...         ...
# 118310              16.0            SP -14.0       18.73
# 118311              14.0            PR -15.0       37.35
# 118312              23.0            SP -14.0       18.44
# 118313              20.0            SP  -7.0       17.69
# 118314              43.0            PR -24.0       40.34
#
# [118315 rows x 21 columns]

# %%
dummies_df = rocpipso_df.drop('order_id', axis='columns')
dummied_df = pd.get_dummies(dummies_df)
target = dummied_df.review_score
df = dummied_df.drop('review_score', axis='columns')
df['review_score'] = target

# %%
from scipy import stats
corr_array=[]
for i in range(df.shape[1]-1):  
    corr_array.append([df.columns[i],
                       np.abs(stats.pearsonr(df[df.columns[i]], df[df.columns[-1]])[0]),
                       stats.pearsonr(df[df.columns[i]], df[df.columns[-1]])[0],
                       stats.pearsonr(df[df.columns[i]], df[df.columns[-1]])[1]])
    
corr_df = pd.DataFrame(corr_array, columns = ['feature', 'abs_corr', 'corr', 'p_value'])
corr_df.sort_values(by='abs_corr', ascending=False, inplace=True)
corr_df.reset_index(drop=True, inplace=True)
corr_df
# Out:
#                                             feature  abs_corr      corr  \
# 0                            review_comment_message  0.292954 -0.292954
# 1                                             delay  0.217062 -0.217062
# 2                                        overcharge  0.133149 -0.133149
# 3                                     payment_value  0.084428 -0.084428
# 4                                 customer_state_RJ  0.061966 -0.061966
# ..                                              ...       ...       ...
# 138                product_category_name_la_cuisine  0.000640 -0.000640
# 139  product_category_name_tablets_impressao_imagem  0.000609  0.000609
# 140                                 seller_state_PI  0.000495  0.000495
# 141        product_category_name_ferramentas_jardim  0.000463 -0.000463
# 142              product_category_name_market_place  0.000019  0.000019
#
#            p_value
# 0     0.000000e+00
# 1     0.000000e+00
# 2     0.000000e+00
# 3    4.498171e-186
# 4    5.408486e-101
# ..             ...
# 138   8.257624e-01
# 139   8.341371e-01
# 140   8.648774e-01
# 141   8.735259e-01
# 142   9.947402e-01
#
# [143 rows x 4 columns]

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## Variance Inflation Factor

# %%
df.loc[df.review_score < 5, 'review_score'] = 0
df.loc[df.review_score == 5, 'review_score'] = 1

# seperate target from features
X = df[df.columns[:-1]]
y = df[df.columns[-1]]

# variance inflation factors
from statsmodels.stats.outliers_influence import variance_inflation_factor
VIF_series = pd.Series([variance_inflation_factor(X.values, i) for i in range(X.shape[1])], index=X.columns)
VIF_series.sort_values(ascending=False, inplace=True)

VIF_df = pd.DataFrame(VIF_series, columns=['vif'])
VIF_df
# Out:
#                                               vif
# seller_state_SP                               inf
# product_category_name_eletroportateis         inf
# product_category_name_alimentos               inf
# product_category_name_alimentos_bebidas       inf
# product_category_name_artes                   inf
# ...                                           ...
# product_photos_qty                       1.174266
# review_comment_title                     1.148413
# review_comment_message                   1.140944
# product_name_lenght                      1.118501
# delay                                    1.040642
#
# [143 rows x 1 columns]

# %%
VIF_df[VIF_df.vif!=float('inf')]
# Out:
#                                  vif
# payment_value               3.837101
# price                       3.653994
# freight_value               3.260795
# product_weight_g            2.865146
# overcharge                  2.778037
# product_height_cm           1.922582
# product_width_cm            1.904896
# product_length_cm           1.764042
# payment_installments        1.405485
# product_description_lenght  1.244845
# product_photos_qty          1.174266
# review_comment_title        1.148413
# review_comment_message      1.140944
# product_name_lenght         1.118501
# delay                       1.040642

# %%
# seperate target from features
X = df[VIF_df[VIF_df.vif!=float('inf')].index]
y = df[df.columns[-1]]

# scale data with standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = pd.DataFrame(data=scaler.fit_transform(X), columns=X.columns)

# fit logit function 
import statsmodels.api as sm
X_withconstant = sm.add_constant(X)
logit = sm.Logit(y, X_withconstant).fit()
display(logit.summary()) 

# table of significant coefficinets sorted by absolute value
coef_table = logit.summary().tables[1]
coef_df = pd.DataFrame(data=coef_table.data[1:], columns=coef_table.data[0])
coef_df['coef'] = coef_df['coef'].astype(float)
coef_df['P>|z|'] = coef_df['P>|z|'].astype(float)
coef_df['abs_coef'] = np.abs(coef_df['coef'])
coef_df.drop(0, axis='index', inplace=True)
coefs_by_mag = coef_df.sort_values(by='abs_coef', ascending=False)
coefs_by_mag = coefs_by_mag[coefs_by_mag['P>|z|'] <= 0.05]

# bar chart of feature coefficients
bar_names = coefs_by_mag['']
bar_heights = coefs_by_mag['coef']
bar_colors = np.where(bar_heights>0, 'blue', 'red')
plt.figure(figsize=(5.0, 4.0))
plt.barh(bar_names, bar_heights, color=bar_colors)
plt.xlabel('normalized coefficient')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.653694
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           review_score   No. Observations:               118315
# Model:                          Logit   Df Residuals:                   118299
# Method:                           MLE   Df Model:                           15
# Date:                Thu, 19 Mar 2020   Pseudo R-squ.:                 0.04667
# Time:                        22:10:54   Log-Likelihood:                -77342.
# converged:                       True   LL-Null:                       -81128.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.2484      0.006     40.998      0.000       0.237       0.260
# payment_value                 -0.0901      0.018     -4.965      0.000      -0.126      -0.055
# price                          0.0947      0.015      6.444      0.000       0.066       0.123
# freight_value                  0.0707      0.011      6.387      0.000       0.049       0.092
# product_weight_g               0.0227      0.010      2.330      0.020       0.004       0.042
# overcharge                    -0.2926      0.015    -18.943      0.000      -0.323      -0.262
# product_height_cm             -0.0044      0.008     -0.584      0.559      -0.019       0.010
# product_width_cm               0.0140      0.008      1.814      0.070      -0.001       0.029
# product_length_cm             -0.0270      0.008     -3.592      0.000      -0.042      -0.012
# payment_installments          -0.0063      0.006     -0.970      0.332      -0.019       0.006
# product_description_lenght     0.0191      0.006      3.027      0.002       0.007       0.031
# product_photos_qty             0.0106      0.006      1.711      0.087      -0.002       0.023
# review_comment_title           0.0789      0.006     12.382      0.000       0.066       0.091
# review_comment_message        -0.3332      0.006    -52.129      0.000      -0.346      -0.321
# product_name_lenght           -0.0357      0.006     -5.785      0.000      -0.048      -0.024
# delay                         -0.3619      0.007    -52.150      0.000      -0.376      -0.348
# ==============================================================================================
# """
# Text(0.5, 0, 'normalized coefficient')

# %% [markdown]
# ## L1 Regularization

# %%
# seperate target from features
X = df[df.columns[:-1]]
y = df[df.columns[-1]]

# scale data with standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = pd.DataFrame(data=scaler.fit_transform(X), columns=X.columns)

# fit regularized logit function 
import statsmodels.api as sm
X_withconstant = sm.add_constant(X)
logit = sm.Logit(y, X_withconstant).fit_regularized(method='l1')
display(logit.summary()) 

# table of significant coefficinets sorted by absolute value
coef_table = logit.summary().tables[1]
coef_df = pd.DataFrame(data=coef_table.data[1:], columns=coef_table.data[0])
coef_df['coef'] = coef_df['coef'].astype(float)
coef_df['P>|z|'] = coef_df['P>|z|'].astype(float)
coef_df['abs_coef'] = np.abs(coef_df['coef'])
coef_df.drop(0, axis='index', inplace=True)
coefs_by_mag = coef_df.sort_values(by='abs_coef', ascending=False)
coefs_by_mag = coefs_by_mag[coefs_by_mag['P>|z|'] <= 0.05]

# bar chart of feature coefficients
bar_names = coefs_by_mag['']
bar_heights = coefs_by_mag['coef']
bar_colors = np.where(bar_heights>0, 'blue', 'red')
plt.figure(figsize=(5.0, 4.0))
plt.barh(bar_names, bar_heights, color=bar_colors)
plt.xlabel('normalized coefficient')
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.6494275113187081
#             Iterations: 63
#             Function evaluations: 64
#             Gradient evaluations: 63
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           review_score   No. Observations:               118315
# Model:                          Logit   Df Residuals:                   118171
# Method:                           MLE   Df Model:                          143
# Date:                Thu, 19 Mar 2020   Pseudo R-squ.:                 0.05289
# Time:                        22:11:03   Log-Likelihood:                -76837.
# converged:                       True   LL-Null:                       -81128.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ========================================================================================================================================
#                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------
# const                                                                    0.2492      0.008     31.149      0.000       0.234       0.265
# review_comment_title                                                     0.0733      0.006     11.347      0.000       0.061       0.086
# review_comment_message                                                  -0.3248      0.006    -50.335      0.000      -0.337      -0.312
# payment_installments                                                     0.0065      0.007      0.889      0.374      -0.008       0.021
# payment_value                                                           -0.1042      0.019     -5.457      0.000      -0.142      -0.067
# price                                                                    0.0896      0.015      5.807      0.000       0.059       0.120
# freight_value                                                            0.1151      0.012      9.528      0.000       0.091       0.139
# product_name_lenght                                                     -0.0270      0.006     -4.194      0.000      -0.040      -0.014
# product_description_lenght                                               0.0065      0.007      0.950      0.342      -0.007       0.020
# product_photos_qty                                                       0.0051      0.007      0.773      0.439      -0.008       0.018
# product_weight_g                                                         0.0185      0.010      1.784      0.074      -0.002       0.039
# product_length_cm                                                       -0.0226      0.008     -2.791      0.005      -0.038      -0.007
# product_height_cm                                                       -0.0265      0.008     -3.137      0.002      -0.043      -0.010
# product_width_cm                                                         0.0046      0.008      0.552      0.581      -0.012       0.021
# delay                                                                   -0.3680      0.007    -51.715      0.000      -0.382      -0.354
# overcharge                                                              -0.2640      0.016    -16.616      0.000      -0.295      -0.233
# customer_state_AC                                                       -0.0036   1.15e+04  -3.13e-07      1.000   -2.26e+04    2.26e+04
# customer_state_AL                                                       -0.0126   2.54e+04  -4.97e-07      1.000   -4.97e+04    4.97e+04
# customer_state_AM                                                       -0.0039   1.55e+04  -2.54e-07      1.000   -3.04e+04    3.04e+04
# customer_state_AP                                                       -0.0089   1.08e+04   -8.2e-07      1.000   -2.12e+04    2.12e+04
# customer_state_BA                                                       -0.0417   7.41e+04  -5.63e-07      1.000   -1.45e+05    1.45e+05
# customer_state_CE                                                       -0.0191   4.63e+04  -4.13e-07      1.000   -9.08e+04    9.08e+04
# customer_state_DF                                                       -0.0072   5.85e+04  -1.23e-07      1.000   -1.15e+05    1.15e+05
# customer_state_ES                                                       -0.0066   5.67e+04  -1.16e-07      1.000   -1.11e+05    1.11e+05
# customer_state_GO                                                       -0.0137   5.79e+04  -2.37e-07      1.000   -1.14e+05    1.14e+05
# customer_state_MA                                                       -0.0216   3.43e+04   -6.3e-07      1.000   -6.72e+04    6.72e+04
# customer_state_MG                                                        0.0104    1.3e+05   8.01e-08      1.000   -2.55e+05    2.55e+05
# customer_state_MS                                                        0.0125   3.45e+04   3.62e-07      1.000   -6.75e+04    6.75e+04
# customer_state_MT                                                       -0.0171   3.95e+04  -4.32e-07      1.000   -7.74e+04    7.74e+04
# customer_state_PA                                                       -0.0333   3.94e+04  -8.44e-07      1.000   -7.73e+04    7.73e+04
# customer_state_PB                                                        0.0060   2.98e+04   2.02e-07      1.000   -5.84e+04    5.84e+04
# customer_state_PE                                                       -0.0061   5.11e+04   -1.2e-07      1.000      -1e+05       1e+05
# customer_state_PI                                                       -0.0135   2.82e+04  -4.79e-07      1.000   -5.54e+04    5.54e+04
# customer_state_PR                                                        0.0138   8.91e+04   1.55e-07      1.000   -1.75e+05    1.75e+05
# customer_state_RJ                                                       -0.0349   1.37e+05  -2.55e-07      1.000   -2.68e+05    2.68e+05
# customer_state_RN                                                       -0.0016   2.82e+04  -5.63e-08      1.000   -5.52e+04    5.52e+04
# customer_state_RO                                                       -0.0108      2e+04  -5.41e-07      1.000   -3.91e+04    3.91e+04
# customer_state_RR                                                       -0.0141   8520.384  -1.66e-06      1.000   -1.67e+04    1.67e+04
# customer_state_RS                                                       -0.0141   9.29e+04  -1.52e-07      1.000   -1.82e+05    1.82e+05
# customer_state_SC                                                     7.983e-05   7.62e+04   1.05e-09      1.000   -1.49e+05    1.49e+05
# customer_state_SE                                                        0.0005   2.35e+04   1.99e-08      1.000   -4.61e+04    4.61e+04
# customer_state_SP                                                        0.0717   2.01e+05   3.57e-07      1.000   -3.93e+05    3.93e+05
# customer_state_TO                                                        0.0036   2.17e+04   1.64e-07      1.000   -4.26e+04    4.26e+04
# payment_type_boleto                                                      0.0137   2.27e+05   6.04e-08      1.000   -4.46e+05    4.46e+05
# payment_type_credit_card                                                -0.0068   2.53e+05  -2.68e-08      1.000   -4.95e+05    4.95e+05
# payment_type_debit_card                                                  0.0179   6.84e+04   2.62e-07      1.000   -1.34e+05    1.34e+05
# payment_type_voucher                                                    -0.0206   1.29e+05  -1.59e-07      1.000   -2.53e+05    2.53e+05
# product_category_name_agro_industria_e_comercio                          0.0011        nan        nan        nan         nan         nan
# product_category_name_alimentos                                          0.0151        nan        nan        nan         nan         nan
# product_category_name_alimentos_bebidas                                  0.0142        nan        nan        nan         nan         nan
# product_category_name_artes                                             -0.0073        nan        nan        nan         nan         nan
# product_category_name_artes_e_artesanato                                 0.0042        nan        nan        nan         nan         nan
# product_category_name_artigos_de_festas                                 -0.0025        nan        nan        nan         nan         nan
# product_category_name_artigos_de_natal                                  -0.0065        nan        nan        nan         nan         nan
# product_category_name_audio                                             -0.0076        nan        nan        nan         nan         nan
# product_category_name_automotivo                                         0.0015        nan        nan        nan         nan         nan
# product_category_name_bebes                                             -0.0091        nan        nan        nan         nan         nan
# product_category_name_bebidas                                           -0.0010        nan        nan        nan         nan         nan
# product_category_name_beleza_saude                                       0.0321        nan        nan        nan         nan         nan
# product_category_name_brinquedos                                         0.0295        nan        nan        nan         nan         nan
# product_category_name_cama_mesa_banho                                   -0.0415        nan        nan        nan         nan         nan
# product_category_name_casa_conforto                                      0.0086        nan        nan        nan         nan         nan
# product_category_name_casa_conforto_2                                   -0.0053        nan        nan        nan         nan         nan
# product_category_name_casa_construcao                                   -0.0162        nan        nan        nan         nan         nan
# product_category_name_cds_dvds_musicais                                  0.0054        nan        nan        nan         nan         nan
# product_category_name_cine_foto                                          0.0141        nan        nan        nan         nan         nan
# product_category_name_climatizacao                                      -0.0035        nan        nan        nan         nan         nan
# product_category_name_consoles_games                                    -0.0127        nan        nan        nan         nan         nan
# product_category_name_construcao_ferramentas_construcao                  0.0038        nan        nan        nan         nan         nan
# product_category_name_construcao_ferramentas_ferramentas                 0.0142        nan        nan        nan         nan         nan
# product_category_name_construcao_ferramentas_iluminacao                 -0.0055        nan        nan        nan         nan         nan
# product_category_name_construcao_ferramentas_jardim                      0.0090        nan        nan        nan         nan         nan
# product_category_name_construcao_ferramentas_seguranca                  -0.0083        nan        nan        nan         nan         nan
# product_category_name_cool_stuff                                         0.0126        nan        nan        nan         nan         nan
# product_category_name_dvds_blu_ray                                      -0.0006        nan        nan        nan         nan         nan
# product_category_name_eletrodomesticos                                   0.0044        nan        nan        nan         nan         nan
# product_category_name_eletrodomesticos_2                                -0.0018        nan        nan        nan         nan         nan
# product_category_name_eletronicos                                       -0.0070        nan        nan        nan         nan         nan
# product_category_name_eletroportateis                                    0.0045        nan        nan        nan         nan         nan
# product_category_name_esporte_lazer                                      0.0204        nan        nan        nan         nan         nan
# product_category_name_fashion_bolsas_e_acessorios                       -0.0050        nan        nan        nan         nan         nan
# product_category_name_fashion_calcados                                   0.0129        nan        nan        nan         nan         nan
# product_category_name_fashion_esporte                                    0.0005        nan        nan        nan         nan         nan
# product_category_name_fashion_roupa_feminina                            -0.0137        nan        nan        nan         nan         nan
# product_category_name_fashion_roupa_infanto_juvenil                      0.0110        nan        nan        nan         nan         nan
# product_category_name_fashion_roupa_masculina                           -0.0056        nan        nan        nan         nan         nan
# product_category_name_fashion_underwear_e_moda_praia                    -0.0075        nan        nan        nan         nan         nan
# product_category_name_ferramentas_jardim                                 0.0234        nan        nan        nan         nan         nan
# product_category_name_flores                                             0.0063        nan        nan        nan         nan         nan
# product_category_name_fraldas_higiene                                   -0.0209        nan        nan        nan         nan         nan
# product_category_name_industria_comercio_e_negocios                      0.0012        nan        nan        nan         nan         nan
# product_category_name_informatica_acessorios                            -0.0301        nan        nan        nan         nan         nan
# product_category_name_instrumentos_musicais                              0.0130        nan        nan        nan         nan         nan
# product_category_name_la_cuisine                                         0.0071        nan        nan        nan         nan         nan
# product_category_name_livros_importados                                  0.0201        nan        nan        nan         nan         nan
# product_category_name_livros_interesse_geral                             0.0400        nan        nan        nan         nan         nan
# product_category_name_livros_tecnicos                                    0.0237        nan        nan        nan         nan         nan
# product_category_name_malas_acessorios                                   0.0336        nan        nan        nan         nan         nan
# product_category_name_market_place                                      -0.0160        nan        nan        nan         nan         nan
# product_category_name_moveis_colchao_e_estofado                         -0.0045        nan        nan        nan         nan         nan
# product_category_name_moveis_cozinha_area_de_servico_jantar_e_jardim    -0.0123        nan        nan        nan         nan         nan
# product_category_name_moveis_decoracao                                  -0.0123        nan        nan        nan         nan         nan
# product_category_name_moveis_escritorio                                 -0.0559        nan        nan        nan         nan         nan
# product_category_name_moveis_quarto                                      0.0005        nan        nan        nan         nan         nan
# product_category_name_moveis_sala                                       -0.0097        nan        nan        nan         nan         nan
# product_category_name_musica                                             0.0011        nan        nan        nan         nan         nan
# product_category_name_other                                             -0.0180        nan        nan        nan         nan         nan
# product_category_name_papelaria                                          0.0249        nan        nan        nan         nan         nan
# product_category_name_pc_gamer                                          -0.0113        nan        nan        nan         nan         nan
# product_category_name_pcs                                                0.0139        nan        nan        nan         nan         nan
# product_category_name_perfumaria                                         0.0317        nan        nan        nan         nan         nan
# product_category_name_pet_shop                                           0.0237        nan        nan        nan         nan         nan
# product_category_name_portateis_casa_forno_e_cafe                        0.0086        nan        nan        nan         nan         nan
# product_category_name_portateis_cozinha_e_preparadores_de_alimentos     -0.0101        nan        nan        nan         nan         nan
# product_category_name_relogios_presentes                                -0.0159        nan        nan        nan         nan         nan
# product_category_name_seguros_e_servicos                                -0.0478        nan        nan        nan         nan         nan
# product_category_name_sinalizacao_e_seguranca                            0.0082        nan        nan        nan         nan         nan
# product_category_name_tablets_impressao_imagem                          -0.0068        nan        nan        nan         nan         nan
# product_category_name_telefonia                                         -0.0363        nan        nan        nan         nan         nan
# product_category_name_telefonia_fixa                                    -0.0180        nan        nan        nan         nan         nan
# product_category_name_utilidades_domesticas                              0.0111        nan        nan        nan         nan         nan
# seller_state_AC                                                         -0.0380        nan        nan        nan         nan         nan
# seller_state_AM                                                          0.0011        nan        nan        nan         nan         nan
# seller_state_BA                                                         -0.0060        nan        nan        nan         nan         nan
# seller_state_CE                                                          0.0072        nan        nan        nan         nan         nan
# seller_state_DF                                                          0.0016        nan        nan        nan         nan         nan
# seller_state_ES                                                         -0.0102        nan        nan        nan         nan         nan
# seller_state_GO                                                          0.0147        nan        nan        nan         nan         nan
# seller_state_MA                                                         -0.0126        nan        nan        nan         nan         nan
# seller_state_MG                                                         -0.0008        nan        nan        nan         nan         nan
# seller_state_MS                                                          0.0208        nan        nan        nan         nan         nan
# seller_state_MT                                                         -0.0062        nan        nan        nan         nan         nan
# seller_state_PA                                                          0.0041        nan        nan        nan         nan         nan
# seller_state_PB                                                         -0.0036        nan        nan        nan         nan         nan
# seller_state_PE                                                         -0.0013        nan        nan        nan         nan         nan
# seller_state_PI                                                         -0.0007        nan        nan        nan         nan         nan
# seller_state_PR                                                         -0.0049        nan        nan        nan         nan         nan
# seller_state_RJ                                                          0.0177        nan        nan        nan         nan         nan
# seller_state_RN                                                          0.0055        nan        nan        nan         nan         nan
# seller_state_RO                                                         -0.0033        nan        nan        nan         nan         nan
# seller_state_RS                                                          0.0096        nan        nan        nan         nan         nan
# seller_state_SC                                                         -0.0062        nan        nan        nan         nan         nan
# seller_state_SE                                                         -0.0003        nan        nan        nan         nan         nan
# seller_state_SP                                                         -0.0020        nan        nan        nan         nan         nan
# ========================================================================================================================================
# """
# Text(0.5, 0, 'normalized coefficient')
