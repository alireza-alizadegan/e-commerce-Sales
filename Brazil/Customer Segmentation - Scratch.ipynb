# %% [markdown]
# <h1 id='tocheading'>Table of Content</h1>
# <div id='toc'></div>

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %% [markdown]
# # Data Cleaning

# %%
# frequently used libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import timeit
from datetime import date

# %% [markdown]
# ## Order Dataset

# %%
order_df = pd.read_csv('olist_orders_dataset.csv')
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
# order_id                         99441 non-null object
# customer_id                      99441 non-null object
# order_status                     99441 non-null object
# order_purchase_timestamp         99441 non-null object
# order_approved_at                99281 non-null object
# order_delivered_carrier_date     97658 non-null object
# order_delivered_customer_date    96476 non-null object
# order_estimated_delivery_date    99441 non-null object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
order_df[order_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# Index: []

# %%
order_df.drop(['order_status',
               'order_delivered_carrier_date',
               'order_approved_at',
               'order_delivered_customer_date',
               'order_estimated_delivery_date'], axis='columns', inplace=True)

order_df.order_purchase_timestamp = pd.to_datetime(order_df.order_purchase_timestamp).dt.date
#pocipr_df['order_purchase_timestamp'] = pocipr_df['order_purchase_timestamp'].dt.date

# %%
order_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_purchase_timestamp
# 0               2017-10-02
# 1               2018-07-24
# 2               2018-08-08
# 3               2017-11-18
# 4               2018-02-13

# %% [markdown]
# ## Customer Dataset

# %%
customer_df = pd.read_csv('olist_customers_dataset.csv')
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
# customer_id                 99441 non-null object
# customer_unique_id          99441 non-null object
# customer_zip_code_prefix    99441 non-null int64
# customer_city               99441 non-null object
# customer_state              99441 non-null object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customer_df[customer_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state]
# Index: []

# %%
customer_df.drop(['customer_zip_code_prefix', 'customer_city'], axis='columns', inplace=True)

# %%
customer_df.nunique()
# Out:
# customer_id           99441
# customer_unique_id    96096
# customer_state           27
# dtype: int64

# %%
customer_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#   customer_state
# 0             SP
# 1             SP
# 2             SP
# 3             SP
# 4             SP

# %% [markdown]
# ## Payment Dataset

# %%
payment_df = pd.read_csv('olist_order_payments_dataset.csv')
payment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
# order_id                103886 non-null object
# payment_sequential      103886 non-null int64
# payment_type            103886 non-null object
# payment_installments    103886 non-null int64
# payment_value           103886 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
payment_df.drop('payment_sequential', axis='columns', inplace=True)

# %%
payment_df[payment_df.duplicated()]
# Out:
#                                 order_id payment_type  payment_installments  \
# 3675    8ca5bdac5ebe8f2d6fc9171d5ebc906a      voucher                     1
# 4829    59d02be1c50fb6e6930cafd6ff6a31e5      voucher                     1
# 5091    4689b1816de42507a7d63a4617383c59      voucher                     1
# 6940    cf101c3abd3c061ca9f78c1bbb1125af      voucher                     1
# 7441    d744783ed2ace06cac647a9e64dcbcfd      voucher                     1
# ...                                  ...          ...                   ...
# 102942  dbc097913df341f30b9f9e92f459cee2      voucher                     1
# 103046  c5fd5386640ddd76adc482b72d24a02b      voucher                     1
# 103216  4d9190887b47ff1b89c657c788c038f6      voucher                     1
# 103551  1ea11b975aea60ca92fa0559184d3d34      voucher                     1
# 103747  cf101c3abd3c061ca9f78c1bbb1125af      voucher                     1
#
#         payment_value
# 3675            15.00
# 4829            20.00
# 5091            56.42
# 6940             8.46
# 7441             1.47
# ...               ...
# 102942          50.00
# 103046           5.79
# 103216          12.80
# 103551          12.69
# 103747           8.46
#
# [614 rows x 4 columns]

# %%
payment_df.head()
# Out:
#                            order_id payment_type  payment_installments  \
# 0  b81ef226f3fe1789b1e8b2acac839d17  credit_card                     8
# 1  a9810da82917af2d9aefd1278f1dcfa0  credit_card                     1
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd  credit_card                     1
# 3  ba78997921bbcdc1373bb41e913ab953  credit_card                     8
# 4  42fdf880ba16b47b59251dd489d4441a  credit_card                     2
#
#    payment_value
# 0          99.33
# 1          24.39
# 2          65.71
# 3         107.78
# 4         128.45

# %%
payment_df.nunique()
# Out:
# order_id                99440
# payment_type                5
# payment_installments       24
# payment_value           29077
# dtype: int64

# %% [markdown]
# ## Item Dataset

# %%
item_df = pd.read_csv('olist_order_items_dataset.csv')

# %%
item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
# order_id               112650 non-null object
# order_item_id          112650 non-null int64
# product_id             112650 non-null object
# seller_id              112650 non-null object
# shipping_limit_date    112650 non-null object
# price                  112650 non-null float64
# freight_value          112650 non-null float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
item_df.drop('order_item_id', axis='columns', inplace=True)

# %%
item_df[item_df.duplicated()]
# Out:
#                                 order_id                        product_id  \
# 14      0008288aa423d2a3f00fcb17cd7d8719  368c6c730842d78016ad823897a372db
# 33      00143d0f86d6fbd9f9b38ab440ac16f5  e95ee6822b66ac6058e2e4aff656071a
# 34      00143d0f86d6fbd9f9b38ab440ac16f5  e95ee6822b66ac6058e2e4aff656071a
# 43      001ab0a7578dd66cd4b0a71f5b6e1e41  0b0172eb0fd18479d29c3bc122c058c2
# 44      001ab0a7578dd66cd4b0a71f5b6e1e41  0b0172eb0fd18479d29c3bc122c058c2
# ...                                  ...                               ...
# 112617  ffecd5a79a0084f6a592288c67e3c298  50fd2b788dc166edd20512370dac54df
# 112635  fff8287bbae429a99bb7e8c21d151c41  bee2e070c39f3dd2f6883a17a5f0da45
# 112641  fffb9224b6fc7c43ebb0904318b10b5f  43423cdffde7fda63d0414ed38c11a73
# 112642  fffb9224b6fc7c43ebb0904318b10b5f  43423cdffde7fda63d0414ed38c11a73
# 112643  fffb9224b6fc7c43ebb0904318b10b5f  43423cdffde7fda63d0414ed38c11a73
#
#                                seller_id  shipping_limit_date   price  \
# 14      1f50f920176fa81dab994f9023523100  2018-02-21 02:55:52   49.90
# 33      a17f621c590ea0fab3d5d883e1630ec6  2017-10-20 16:07:52   21.33
# 34      a17f621c590ea0fab3d5d883e1630ec6  2017-10-20 16:07:52   21.33
# 43      5656537e588803a555b8eb41f07a944b  2018-01-04 02:33:42   24.89
# 44      5656537e588803a555b8eb41f07a944b  2018-01-04 02:33:42   24.89
# ...                                  ...                  ...     ...
# 112617  8b321bb669392f5163d04c59e235e066  2018-03-05 20:15:27   21.90
# 112635  4e922959ae960d389249c378d1c939f5  2018-03-27 12:29:22  180.00
# 112641  b1fc4f64df5a0e8b6913ab38803c57a9  2017-11-03 02:55:58   55.00
# 112642  b1fc4f64df5a0e8b6913ab38803c57a9  2017-11-03 02:55:58   55.00
# 112643  b1fc4f64df5a0e8b6913ab38803c57a9  2017-11-03 02:55:58   55.00
#
#         freight_value
# 14              13.37
# 33              15.10
# 34              15.10
# 43              17.63
# 44              17.63
# ...               ...
# 112617          15.79
# 112635          48.14
# 112641          34.19
# 112642          34.19
# 112643          34.19
#
# [10225 rows x 6 columns]

# %%
item_df.drop(['seller_id', 'shipping_limit_date'], axis='columns', inplace=True)
item_df.columns
# Out:
# Index(['order_id', 'product_id', 'price', 'freight_value'], dtype='object')

# %%
item_df.head()
# Out:
#                            order_id                        product_id   price  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61   58.90
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f  239.90
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd  199.00
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc   12.99
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089  199.90
#
#    freight_value
# 0          13.29
# 1          19.93
# 2          17.87
# 3          12.79
# 4          18.14

# %% [markdown]
# ## Product Dataset

# %%
product_df = pd.read_csv('olist_products_dataset.csv')

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
# product_id                    32951 non-null object
# product_category_name         32341 non-null object
# product_name_lenght           32341 non-null float64
# product_description_lenght    32341 non-null float64
# product_photos_qty            32341 non-null float64
# product_weight_g              32949 non-null float64
# product_length_cm             32949 non-null float64
# product_height_cm             32949 non-null float64
# product_width_cm              32949 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df[product_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm]
# Index: []

# %%
product_df.fillna(product_df.median(), inplace=True)
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
# product_id                    32951 non-null object
# product_category_name         32341 non-null object
# product_name_lenght           32951 non-null float64
# product_description_lenght    32951 non-null float64
# product_photos_qty            32951 non-null float64
# product_weight_g              32951 non-null float64
# product_length_cm             32951 non-null float64
# product_height_cm             32951 non-null float64
# product_width_cm              32951 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.fillna('other', inplace=True)
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
# product_id                    32951 non-null object
# product_category_name         32951 non-null object
# product_name_lenght           32951 non-null float64
# product_description_lenght    32951 non-null float64
# product_photos_qty            32951 non-null float64
# product_weight_g              32951 non-null float64
# product_length_cm             32951 non-null float64
# product_height_cm             32951 non-null float64
# product_width_cm              32951 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
product_df.product_category_name.nunique()
# Out:
# 74

# %% [markdown]
# ## Translation Dataset

# %%
translation_df = pd.read_csv('product_category_name_translation.csv')
translation_df.info()
translation_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
# product_category_name            71 non-null object
# product_category_name_english    71 non-null object
# dtypes: object(2)
# memory usage: 1.2+ KB
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# ## Review Dataset

# %%
review_df = pd.read_csv('olist_order_reviews_dataset.csv')
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
# review_id                  100000 non-null object
# order_id                   100000 non-null object
# review_score               100000 non-null int64
# review_comment_title       11715 non-null object
# review_comment_message     41753 non-null object
# review_creation_date       100000 non-null object
# review_answer_timestamp    100000 non-null object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
review_df[review_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [review_id, order_id, review_score, review_comment_title, review_comment_message, review_creation_date, review_answer_timestamp]
# Index: []

# %%
review_df.drop(['review_id', 'review_creation_date', 'review_answer_timestamp'], axis='columns', inplace=True)
review_df.columns
# Out:
# Index(['order_id', 'review_score', 'review_comment_title',
#        'review_comment_message'],
#       dtype='object')

# %%
for columns in ['review_comment_title', 'review_comment_message']:
    # replace present values with 1
    review_df.loc[review_df[columns].notnull(), columns] = 1
    # replace null values with 0
    review_df.loc[review_df[columns].isna(), columns] = 0
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
# order_id                  100000 non-null object
# review_score              100000 non-null int64
# review_comment_title      100000 non-null int64
# review_comment_message    100000 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 3.1+ MB

# %%
review_df.head()
# Out:
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  a548910a1c6147796b98fdf73dbeba33             5                     0
# 2  f9e4b658b201a9f2ecdecbb34bed034b             5                     0
# 3  658677c97b385a9be170737859d3511b             5                     0
# 4  8e6bfb81e283fa7e4f11123a3fb894f1             5                     0
#
#    review_comment_message
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       1

# %%
review_df.nunique()
# Out:
# order_id                  99441
# review_score                  5
# review_comment_title          2
# review_comment_message        2
# dtype: int64

# %%
review_df.review_score.value_counts(normalize=True)
# Out:
# 5    0.57420
# 4    0.19200
# 1    0.11858
# 3    0.08287
# 2    0.03235
# Name: review_score, dtype: float64

# %%
plt.bar(review_df.review_score.value_counts().index, review_df.review_score.value_counts().values)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Seller Dataset

# %%
seller_df = pd.read_csv('olist_sellers_dataset.csv')
seller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
# seller_id                 3095 non-null object
# seller_zip_code_prefix    3095 non-null int64
# seller_city               3095 non-null object
# seller_state              3095 non-null object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
seller_df.drop(['seller_zip_code_prefix', 'seller_city'], axis='columns', inplace=True)
seller_df.columns
# Out:
# Index(['seller_id', 'seller_state'], dtype='object')

# %% [markdown]
# # Join

# %%
oc_df = pd.merge(order_df, customer_df, how='left', on='customer_id')
oc_df.drop('customer_id', axis='columns', inplace=True)
oc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 0 to 99440
# Data columns (total 4 columns):
# order_id                    99441 non-null object
# order_purchase_timestamp    99441 non-null object
# customer_unique_id          99441 non-null object
# customer_state              99441 non-null object
# dtypes: object(4)
# memory usage: 3.8+ MB

# %%
ocp_df = pd.merge(oc_df, payment_df, how='left', on='order_id')
ocp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103887 entries, 0 to 103886
# Data columns (total 7 columns):
# order_id                    103887 non-null object
# order_purchase_timestamp    103887 non-null object
# customer_unique_id          103887 non-null object
# customer_state              103887 non-null object
# payment_type                103886 non-null object
# payment_installments        103886 non-null float64
# payment_value               103886 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 6.3+ MB

# %%
ocpr_df = pd.merge(ocp_df, review_df, how='left', on='order_id')
ocpr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104486 entries, 0 to 104485
# Data columns (total 10 columns):
# order_id                    104486 non-null object
# order_purchase_timestamp    104486 non-null object
# customer_unique_id          104486 non-null object
# customer_state              104486 non-null object
# payment_type                104485 non-null object
# payment_installments        104485 non-null float64
# payment_value               104485 non-null float64
# review_score                104486 non-null int64
# review_comment_title        104486 non-null int64
# review_comment_message      104486 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 8.8+ MB

# %%
ocpri_df = pd.merge(ocpr_df, item_df, how='left', on='order_id')
#ocpri_df.drop('order_id', axis='columns', inplace=True)
ocpri_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119151 entries, 0 to 119150
# Data columns (total 13 columns):
# order_id                    119151 non-null object
# order_purchase_timestamp    119151 non-null object
# customer_unique_id          119151 non-null object
# customer_state              119151 non-null object
# payment_type                119148 non-null object
# payment_installments        119148 non-null float64
# payment_value               119148 non-null float64
# review_score                119151 non-null int64
# review_comment_title        119151 non-null int64
# review_comment_message      119151 non-null int64
# product_id                  118318 non-null object
# price                       118318 non-null float64
# freight_value               118318 non-null float64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 12.7+ MB

# %%
ocprip_df = pd.merge(ocpri_df, product_df, how='left', on='product_id')
ocprip_df.drop('product_id', axis='columns', inplace=True)
ocprip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119151 entries, 0 to 119150
# Data columns (total 20 columns):
# order_id                      119151 non-null object
# order_purchase_timestamp      119151 non-null object
# customer_unique_id            119151 non-null object
# customer_state                119151 non-null object
# payment_type                  119148 non-null object
# payment_installments          119148 non-null float64
# payment_value                 119148 non-null float64
# review_score                  119151 non-null int64
# review_comment_title          119151 non-null int64
# review_comment_message        119151 non-null int64
# price                         118318 non-null float64
# freight_value                 118318 non-null float64
# product_category_name         118318 non-null object
# product_name_lenght           118318 non-null float64
# product_description_lenght    118318 non-null float64
# product_photos_qty            118318 non-null float64
# product_weight_g              118318 non-null float64
# product_length_cm             118318 non-null float64
# product_height_cm             118318 non-null float64
# product_width_cm              118318 non-null float64
# dtypes: float64(11), int64(3), object(6)
# memory usage: 19.1+ MB

# %%
ocprip_df.fillna(ocprip_df.median(), inplace=True)

# %%
for column in ['payment_type', 'product_category_name']:
    ocprip_df[column].fillna(ocprip_df[column].value_counts().index[0], inplace=True)

# %%
ocprip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119151 entries, 0 to 119150
# Data columns (total 20 columns):
# order_id                      119151 non-null object
# order_purchase_timestamp      119151 non-null object
# customer_unique_id            119151 non-null object
# customer_state                119151 non-null object
# payment_type                  119151 non-null object
# payment_installments          119151 non-null float64
# payment_value                 119151 non-null float64
# review_score                  119151 non-null int64
# review_comment_title          119151 non-null int64
# review_comment_message        119151 non-null int64
# price                         119151 non-null float64
# freight_value                 119151 non-null float64
# product_category_name         119151 non-null object
# product_name_lenght           119151 non-null float64
# product_description_lenght    119151 non-null float64
# product_photos_qty            119151 non-null float64
# product_weight_g              119151 non-null float64
# product_length_cm             119151 non-null float64
# product_height_cm             119151 non-null float64
# product_width_cm              119151 non-null float64
# dtypes: float64(11), int64(3), object(6)
# memory usage: 19.1+ MB

# %%
df = ocprip_df.groupby('customer_unique_id').agg({'order_purchase_timestamp': lambda x: min((max(ocprip_df.order_purchase_timestamp)-x).dt.days)})
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-2a4648b08ed6> in <module>
# ----> 1 df = ocprip_df.groupby('customer_unique_id').agg({'order_purchase_timestamp': lambda x: min((max(ocprip_df.order_purchase_timestamp)-x).dt.days)})
#       2 df
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# -> 1455         return super().aggregate(arg, *args, **kwargs)
#    1456
#    1457     agg = aggregate
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     227         func = _maybe_mangle_lambdas(func)
#     228
# --> 229         result, how = self._aggregate(func, _level=_level, *args, **kwargs)
#     230         if how is None:
#     231             return result
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     504
#     505                 try:
# --> 506                     result = _agg(arg, _agg_1dim)
#     507                 except SpecificationError:
#     508
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _agg(arg, func)
#     454                 result = OrderedDict()
#     455                 for fname, agg_how in arg.items():
# --> 456                     result[fname] = func(fname, agg_how)
#     457                 return result
#     458
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _agg_1dim(name, how, subset)
#     438                         "nested dictionary is ambiguous " "in aggregation"
#     439                     )
# --> 440                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     441
#     442             def _agg_2dim(name, how):
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     861
#     862             try:
# --> 863                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     864             except Exception:
#     865                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     898         for name, obj in self._iterate_slices():
#     899             try:
# --> 900                 result, counts = self.grouper.agg_series(obj, f)
#     901                 output[name] = self._try_cast(result, obj, numeric_only=True)
#     902             except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     661     def agg_series(self, obj, func):
#     662         try:
# --> 663             return self._aggregate_series_fast(obj, func)
#     664         except Exception:
#     665             return self._aggregate_series_pure_python(obj, func)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_fast(self, obj, func)
#     679         group_index = algorithms.take_nd(group_index, indexer, allow_fill=False)
#     680         grouper = reduction.SeriesGrouper(obj, func, group_index, ngroups, dummy)
# --> 681         result, counts = grouper.get_result()
#     682         return result, counts
#     683
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     892     def _python_agg_general(self, func, *args, **kwargs):
#     893         func = self._is_builtin_func(func)
# --> 894         f = lambda x: func(x, *args, **kwargs)
#     895
#     896         # iterate through "columns" ex exclusions to populate output dict
#
# <ipython-input-61-2a4648b08ed6> in <lambda>(x)
# ----> 1 df = ocprip_df.groupby('customer_unique_id').agg({'order_purchase_timestamp': lambda x: min((max(ocprip_df.order_purchase_timestamp)-x).dt.days)})
#       2 df
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     972         return missing.dispatch_fill_zeros(op, x, y, result)
#     973
# --> 974     def wrapper(left, right):
#     975         if isinstance(right, ABCDataFrame):
#     976             return NotImplemented
#
# KeyboardInterrupt:

# %%
df = ocprip_df.groupby('customer_unique_id').agg({'order_id': 'count',
                                                  'payment_value': 'sum',
                                                  'payment_installments': 'mean',
                                                  'review_score': 'mean',
                                                  'price': 'mean',
                                                  'freight_value': 'mean',
                                                  'product_name_lenght': 'mean',
                                                  'product_description_lenght': 'mean',
                                                  'product_photos_qty': 'mean',
                                                  'product_length_cm': 'mean',
                                                  'product_height_cm': 'mean',
                                                  'product_width_cm': 'mean',
                                                  'review_comment_title': 'mean',
                                                  'review_comment_message': 'mean',
                                                  'payment_type': lambda x: x.value_counts().index[0],
                                                  'product_category_name': lambda x: x.value_counts().index[0],
                                                  'customer_state': lambda x: x.value_counts().index[0],
                                                  'order_purchase_timestamp': lambda x: min((max(ocprip_df.order_purchase_timestamp)-x).dt.days)})
df
# Out:
#                                   order_id  payment_value  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                       160
# 0000b849f77a49e4a4ce2b2a4ca5be3f                       163
# 0000f46a3911fa3c0805444483337064                       586
# 0000f6ccb0745a6a4b88665a16c9f078                       370
# 0004aac84e0df4da2b147fca70cf8255                       337
# ...                                                    ...
# fffcf5a5ff07b0908bd4e2dbc735a684                       496
# fffea47cd6d3cc0a88bd621562a9d061                       311
# ffff371b4d645b6ecea244b27531430a                       617
# ffff5962728ec6157033ef9805bacc48                       168
# ffffd2657e2aad2907e67c3e9daecbeb                       533
#
# [96096 rows x 18 columns]

# %%
# df.to_csv('df.csv', index=True);
cust_ocprip_df = pd.read_csv('df.csv', index_col=0)
cust_ocprip_df
# Out:
#                                   order_id  payment_value  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2         1         141.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f         1          27.19
# 0000f46a3911fa3c0805444483337064         1          86.22
# 0000f6ccb0745a6a4b88665a16c9f078         1          43.62
# 0004aac84e0df4da2b147fca70cf8255         1         196.89
# ...                                    ...            ...
# fffcf5a5ff07b0908bd4e2dbc735a684         2        4134.84
# fffea47cd6d3cc0a88bd621562a9d061         1          84.58
# ffff371b4d645b6ecea244b27531430a         1         112.46
# ffff5962728ec6157033ef9805bacc48         1         133.69
# ffffd2657e2aad2907e67c3e9daecbeb         1          71.56
#
#                                   payment_installments  review_score   price  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                   8.0           5.0  129.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f                   1.0           4.0   18.90
# 0000f46a3911fa3c0805444483337064                   8.0           3.0   69.00
# 0000f6ccb0745a6a4b88665a16c9f078                   4.0           4.0   25.99
# 0004aac84e0df4da2b147fca70cf8255                   6.0           5.0  180.00
# ...                                                ...           ...     ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  10.0           5.0  785.00
# fffea47cd6d3cc0a88bd621562a9d061                   1.0           4.0   64.89
# ffff371b4d645b6ecea244b27531430a                   1.0           5.0   89.90
# ffff5962728ec6157033ef9805bacc48                   5.0           5.0  115.00
# ffffd2657e2aad2907e67c3e9daecbeb                   4.0           5.0   56.99
#
#                                   freight_value  product_name_lenght  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2          12.00                 60.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f           8.29                 56.0
# 0000f46a3911fa3c0805444483337064          17.22                 49.0
# 0000f6ccb0745a6a4b88665a16c9f078          17.63                 43.0
# 0004aac84e0df4da2b147fca70cf8255          16.89                 58.0
# ...                                         ...                  ...
# fffcf5a5ff07b0908bd4e2dbc735a684         248.71                 54.0
# fffea47cd6d3cc0a88bd621562a9d061          19.69                 37.0
# ffff371b4d645b6ecea244b27531430a          22.56                 57.0
# ffff5962728ec6157033ef9805bacc48          18.69                 35.0
# ffffd2657e2aad2907e67c3e9daecbeb          14.57                 45.0
#
#                                   product_description_lenght  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                       236.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                       635.0
# 0000f46a3911fa3c0805444483337064                       177.0
# 0000f6ccb0745a6a4b88665a16c9f078                      1741.0
# 0004aac84e0df4da2b147fca70cf8255                       794.0
# ...                                                      ...
# fffcf5a5ff07b0908bd4e2dbc735a684                       478.5
# fffea47cd6d3cc0a88bd621562a9d061                       506.0
# ffff371b4d645b6ecea244b27531430a                       716.0
# ffff5962728ec6157033ef9805bacc48                       591.0
# ffffd2657e2aad2907e67c3e9daecbeb                      1003.0
#
#                                   product_photos_qty  product_length_cm  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                 1.0               34.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                 1.0               26.0
# 0000f46a3911fa3c0805444483337064                 3.0               25.0
# 0000f6ccb0745a6a4b88665a16c9f078                 5.0               19.0
# 0004aac84e0df4da2b147fca70cf8255                 3.0               16.0
# ...                                              ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                 1.0               55.0
# fffea47cd6d3cc0a88bd621562a9d061                 2.0               33.0
# ffff371b4d645b6ecea244b27531430a                 5.0               17.0
# ffff5962728ec6157033ef9805bacc48                 3.0               20.0
# ffffd2657e2aad2907e67c3e9daecbeb                 2.0               18.0
#
#                                   product_height_cm  product_width_cm  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                7.0              32.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f               11.0              18.0
# 0000f46a3911fa3c0805444483337064               50.0              35.0
# 0000f6ccb0745a6a4b88665a16c9f078                5.0              11.0
# 0004aac84e0df4da2b147fca70cf8255                3.0              11.0
# ...                                             ...               ...
# fffcf5a5ff07b0908bd4e2dbc735a684               75.0              61.0
# fffea47cd6d3cc0a88bd621562a9d061               36.0              27.0
# ffff371b4d645b6ecea244b27531430a               15.0              13.0
# ffff5962728ec6157033ef9805bacc48               14.0              16.0
# ffffd2657e2aad2907e67c3e9daecbeb               11.0              11.0
#
#                                   review_comment_title  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                   1.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                   0.0
# 0000f46a3911fa3c0805444483337064                   0.0
# 0000f6ccb0745a6a4b88665a16c9f078                   0.0
# 0004aac84e0df4da2b147fca70cf8255                   0.0
# ...                                                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                   0.0
# fffea47cd6d3cc0a88bd621562a9d061                   0.0
# ffff371b4d645b6ecea244b27531430a                   0.0
# ffff5962728ec6157033ef9805bacc48                   1.0
# ffffd2657e2aad2907e67c3e9daecbeb                   0.0
#
#                                   review_comment_message payment_type  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                     1.0  credit_card
# 0000b849f77a49e4a4ce2b2a4ca5be3f                     0.0  credit_card
# 0000f46a3911fa3c0805444483337064                     0.0  credit_card
# 0000f6ccb0745a6a4b88665a16c9f078                     1.0  credit_card
# 0004aac84e0df4da2b147fca70cf8255                     0.0  credit_card
# ...                                                  ...          ...
# fffcf5a5ff07b0908bd4e2dbc735a684                     0.0  credit_card
# fffea47cd6d3cc0a88bd621562a9d061                     0.0  credit_card
# ffff371b4d645b6ecea244b27531430a                     0.0  credit_card
# ffff5962728ec6157033ef9805bacc48                     1.0  credit_card
# ffffd2657e2aad2907e67c3e9daecbeb                     0.0  credit_card
#
#                                  product_category_name customer_state  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2       cama_mesa_banho             SP
# 0000b849f77a49e4a4ce2b2a4ca5be3f          beleza_saude             SP
# 0000f46a3911fa3c0805444483337064             papelaria             SC
# 0000f6ccb0745a6a4b88665a16c9f078             telefonia             PA
# 0004aac84e0df4da2b147fca70cf8255             telefonia             SP
# ...                                                ...            ...
# fffcf5a5ff07b0908bd4e2dbc735a684          beleza_saude             PE
# fffea47cd6d3cc0a88bd621562a9d061                 bebes             BA
# ffff371b4d645b6ecea244b27531430a            automotivo             MT
# ffff5962728ec6157033ef9805bacc48    relogios_presentes             ES
# ffffd2657e2aad2907e67c3e9daecbeb            perfumaria             PR
#
#                                   order_purchase_timestamp
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                       160
# 0000b849f77a49e4a4ce2b2a4ca5be3f                       163
# 0000f46a3911fa3c0805444483337064                       586
# 0000f6ccb0745a6a4b88665a16c9f078                       370
# 0004aac84e0df4da2b147fca70cf8255                       337
# ...                                                    ...
# fffcf5a5ff07b0908bd4e2dbc735a684                       496
# fffea47cd6d3cc0a88bd621562a9d061                       311
# ffff371b4d645b6ecea244b27531430a                       617
# ffff5962728ec6157033ef9805bacc48                       168
# ffffd2657e2aad2907e67c3e9daecbeb                       533
#
# [96096 rows x 18 columns]

# %%
df = pd.get_dummies(cust_ocprip_df)
df
# Out:
#                                   order_id  payment_value  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2         1         141.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f         1          27.19
# 0000f46a3911fa3c0805444483337064         1          86.22
# 0000f6ccb0745a6a4b88665a16c9f078         1          43.62
# 0004aac84e0df4da2b147fca70cf8255         1         196.89
# ...                                    ...            ...
# fffcf5a5ff07b0908bd4e2dbc735a684         2        4134.84
# fffea47cd6d3cc0a88bd621562a9d061         1          84.58
# ffff371b4d645b6ecea244b27531430a         1         112.46
# ffff5962728ec6157033ef9805bacc48         1         133.69
# ffffd2657e2aad2907e67c3e9daecbeb         1          71.56
#
#                                   payment_installments  review_score   price  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                   8.0           5.0  129.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f                   1.0           4.0   18.90
# 0000f46a3911fa3c0805444483337064                   8.0           3.0   69.00
# 0000f6ccb0745a6a4b88665a16c9f078                   4.0           4.0   25.99
# 0004aac84e0df4da2b147fca70cf8255                   6.0           5.0  180.00
# ...                                                ...           ...     ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  10.0           5.0  785.00
# fffea47cd6d3cc0a88bd621562a9d061                   1.0           4.0   64.89
# ffff371b4d645b6ecea244b27531430a                   1.0           5.0   89.90
# ffff5962728ec6157033ef9805bacc48                   5.0           5.0  115.00
# ffffd2657e2aad2907e67c3e9daecbeb                   4.0           5.0   56.99
#
#                                   freight_value  product_name_lenght  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2          12.00                 60.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f           8.29                 56.0
# 0000f46a3911fa3c0805444483337064          17.22                 49.0
# 0000f6ccb0745a6a4b88665a16c9f078          17.63                 43.0
# 0004aac84e0df4da2b147fca70cf8255          16.89                 58.0
# ...                                         ...                  ...
# fffcf5a5ff07b0908bd4e2dbc735a684         248.71                 54.0
# fffea47cd6d3cc0a88bd621562a9d061          19.69                 37.0
# ffff371b4d645b6ecea244b27531430a          22.56                 57.0
# ffff5962728ec6157033ef9805bacc48          18.69                 35.0
# ffffd2657e2aad2907e67c3e9daecbeb          14.57                 45.0
#
#                                   product_description_lenght  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e
    inertia_dict[k] = km.inertia_
    
plt.scatter(inertia_dict.keys(), inertia_dict.values())
plt.xlabel('Clusters')
plt.ylabel('Inertia');

# %%
inertia_dict = {}
for k in range(1,15):
    km = KMeans(n_clusters=k).fit(X_scaled)
    inertia_dict[k] = km.inertia_
    
plt.scatter(inertia_dict.keys(), inertia_dict.values())
plt.xlabel('Clusters')
plt.ylabel('Inertia');

# %%
# principle component analysis
from sklearn.decomposition import PCA
n_components = 121
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X)

plt.plot(range(1,n_components+1), pca.explained_variance_ratio_.cumsum(),marker='.');
plt.xlabel('Number of PCs')
plt.ylabel('Proportion of Variance Explained')
# Out:
# Text(0, 0.5, 'Proportion of Variance Explained')

# %%
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X)
inertia_dict = {}
for k in range(1,15):
    km = KMeans(n_clusters=k).fit(X_pca)
    inertia_dict[k] = km.inertia_
    
plt.scatter(inertia_dict.keys(), inertia_dict.values())
plt.xlabel('Clusters')
plt.ylabel('Inertia');

# %%
plt.scatter(X_pca[:,0],X_pca[:,1])

# %% [markdown]
# ## K-means Clustering

# %%
km = KMeans(n_clusters=4).fit(X_pca)
plt.scatter(X_pca[:,1], X_pca[:,2], c=km.labels_)

# %%
np.bincount(km.labels_)
# Out:
# array([4205, 2698, 2156,  551], dtype=int64)

# %%
label_count_df = pd.DataFrame(labels)

# %%
km.cluster_centers_

# %%
km.cluster_centers_[1,1]

# %%
n_clusters

# %%
from scipy import stats
corr_array=[]
for i in range(df.shape[1]-1):  
    corr_array.append([df.columns[i],
                       np.abs(stats.pearsonr(df[df.columns[i]], X_pca[:,2])[0]),
                       stats.pearsonr(df[df.columns[i]], X_pca[:,2])[0],
                       stats.pearsonr(df[df.columns[i]], X_pca[:,2])[1]])
    
corr_df = pd.DataFrame(corr_array, columns = ['feature', 'abs_corr', 'corr', 'p_value'])
corr_df.sort_values(by='abs_corr', ascending=False, inplace=True)
corr_df.reset_index(drop=True, inplace=True)
corr_df
# Out:
#                                                feature  abs_corr      corr  \
# 0                      product_category_name_papelaria  0.026457  0.026457
# 1                product_category_name_eletroportateis  0.025682  0.025682
# 2                         product_category_name_musica  0.024735  0.024735
# 3             product_category_name_relogios_presentes  0.024232 -0.024232
# 4                     product_category_name_brinquedos  0.023635  0.023635
# ..                                                 ...       ...       ...
# 115                           payment_type_not_defined       NaN       NaN
# 116  product_category_name_fashion_roupa_infanto_ju...       NaN       NaN
# 117                   product_category_name_la_cuisine       NaN       NaN
# 118    product_category_name_moveis_colchao_e_estofado       NaN       NaN
# 119           product_category_name_seguros_e_servicos       NaN       NaN
#
#       p_value
# 0    0.009494
# 1    0.011812
# 2    0.015313
# 3    0.017524
# 4    0.020505
# ..        ...
# 115       NaN
# 116       NaN
# 117       NaN
# 118       NaN
# 119       NaN
#
# [120 rows x 4 columns]

# %%
X=df
y=X_pca[:,1]

# scale data with standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = pd.DataFrame(data=scaler.fit_transform(X), columns=X.columns)

# fit logit function 
import statsmodels.api as sm
X_withconstant = sm.add_constant(X)
logit = sm.OLS(y, X_withconstant).fit()
display(logit.summary()) 

# table of significant coefficinets sorted by absolute value
coef_table = logit.summary().tables[1]
coef_df = pd.DataFrame(data=coef_table.data[1:], columns=coef_table.data[0])
coef_df['coef'] = coef_df['coef'].astype(float)
coef_df['P>|t|'] = coef_df['P>|t|'].astype(float)
coef_df['abs_coef'] = np.abs(coef_df['coef'])
coef_df.drop(0, axis='index', inplace=True)
coefs_by_mag = coef_df.sort_values(by='abs_coef', ascending=False)
coefs_by_mag = coefs_by_mag[coefs_by_mag['P>|t|'] <= 0.05]

# bar chart of feature coefficients
bar_names = coefs_by_mag['']
bar_heights = coefs_by_mag['coef']
bar_colors = np.where(bar_heights>0, 'blue', 'red')
plt.figure(figsize=(5.0, 4.0))
plt.barh(bar_names, bar_heights, color=bar_colors)
plt.xlabel('normalized coefficient')
# Out:
# C:\Users\arali\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9603
# Date:                Wed, 18 Mar 2020   Prob (F-statistic):              0.602
# Time:                        14:24:51   Log-Likelihood:                -17258.
# No. Observations:                9610   AIC:                         3.474e+04
# Df Residuals:                    9496   BIC:                         3.556e+04
# Df Model:                         113
# Covariance Type:            nonrobust
# ========================================================================================================================================
#                                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 -3.27e-16      0.015  -2.19e-14      1.000      -0.029       0.029
# order_id                                                                 0.0179      0.019      0.934      0.350      -0.020       0.056
# payment_value                                                           -0.0180      0.021     -0.871      0.384      -0.058       0.022
# payment_installments                                                    -0.0210      0.018     -1.176      0.240      -0.056       0.014
# review_score                                                            -0.0159      0.016     -1.011      0.312      -0.047       0.015
# price                                                                    0.0125      0.021      0.598      0.550      -0.028       0.053
# freight_value                                                            0.0026      0.021      0.126      0.900      -0.038       0.043
# product_name_lenght                                                      0.0090      0.016      0.570      0.569      -0.022       0.040
# product_description_lenght                                               0.0116      0.017      0.689      0.491      -0.021       0.045
# product_photos_qty                                                       0.0271      0.016      1.676      0.094      -0.005       0.059
# product_length_cm                                                       -0.0560      0.020     -2.845      0.004      -0.095      -0.017
# product_height_cm                                                        0.0092      0.019      0.482      0.630      -0.028       0.046
# product_width_cm                                                         0.0042      0.020      0.210      0.834      -0.035       0.044
# review_comment_title                                                     0.0106      0.018      0.600      0.548      -0.024       0.045
# review_comment_message                                                  -0.0021      0.017     -0.124      0.902      -0.035       0.031
# order_purchase_timestamp                                                 0.0086      0.017      0.501      0.616      -0.025       0.042
# payment_type_boleto                                                      0.0032      0.010      0.336      0.737      -0.016       0.022
# payment_type_credit_card                                                -0.0004      0.009     -0.043      0.966      -0.017       0.017
# payment_type_debit_card                                                  0.0099      0.014      0.683      0.494      -0.018       0.038
# payment_type_not_defined                                              2.028e-18   1.65e-17      0.123      0.902   -3.03e-17    3.44e-17
# payment_type_voucher                                                    -0.0177      0.015     -1.185      0.236      -0.047       0.012
# product_category_name_agro_industria_e_comercio                          0.0133      0.015      0.885      0.376      -0.016       0.043
# product_category_name_alimentos                                         -0.0115      0.015     -0.767      0.443      -0.041       0.018
# product_category_name_alimentos_bebidas                                  0.0107      0.015      0.718      0.473      -0.019       0.040
# product_category_name_artes                                              0.0048      0.015      0.317      0.751      -0.025       0.035
# product_category_name_artes_e_artesanato                                -0.0068      0.015     -0.455      0.649      -0.036       0.023
# product_category_name_artigos_de_festas                                 -0.0062      0.015     -0.417      0.677      -0.036       0.023
# product_category_name_artigos_de_natal                                  -0.0048      0.015     -0.319      0.750      -0.034       0.025
# product_category_name_audio                                              0.0088      0.015      0.589      0.556      -0.021       0.038
# product_category_name_automotivo                                        -0.0096      0.014     -0.664      0.507      -0.038       0.019
# product_category_name_bebes                                             -0.0032      0.015     -0.220      0.826      -0.032       0.026
# product_category_name_bebidas                                           -0.0117      0.015     -0.783      0.433      -0.041       0.018
# product_category_name_beleza_saude                                      -0.0080      0.014     -0.562      0.574      -0.036       0.020
# product_category_name_brinquedos                                        -0.0163      0.015     -1.122      0.262      -0.045       0.012
# product_category_name_cama_mesa_banho                                    0.0047      0.015      0.316      0.752      -0.024       0.034
# product_category_name_casa_conforto                                      0.0035      0.015      0.235      0.814      -0.026       0.033
# product_category_name_casa_conforto_2                                    0.0089      0.015      0.595      0.552      -0.020       0.038
# product_category_name_casa_construcao                                   -0.0124      0.015     -0.830      0.407      -0.042       0.017
# product_category_name_cds_dvds_musicais                                  0.0176      0.015      1.175      0.240      -0.012       0.047
# product_category_name_cine_foto                                         -0.0007      0.015     -0.045      0.964      -0.030       0.029
# product_category_name_climatizacao                                      -0.0024      0.015     -0.160      0.873      -0.032       0.027
# product_category_name_consoles_games                                    -0.0163      0.015     -1.091      0.275      -0.045       0.013
# product_category_name_construcao_ferramentas_construcao                  0.0060      0.015      0.400      0.689      -0.023       0.035
# product_category_name_construcao_ferramentas_ferramentas                -0.0179      0.015     -1.198      0.231      -0.047       0.011
# product_category_name_construcao_ferramentas_iluminacao                 -0.0001      0.015     -0.009      0.993      -0.029       0.029
# product_category_name_construcao_ferramentas_jardim                      0.0103      0.015      0.690      0.490      -0.019       0.040
# product_category_name_construcao_ferramentas_seguranca                   0.0080      0.015      0.532      0.595      -0.021       0.037
# product_category_name_cool_stuff                                         0.0177      0.015      1.206      0.228      -0.011       0.046
# product_category_name_dvds_blu_ray                                       0.0203      0.015      1.355      0.175      -0.009       0.050
# product_category_name_eletrodomesticos                                  -0.0221      0.015     -1.480      0.139      -0.051       0.007
# product_category_name_eletrodomesticos_2                                 0.0135      0.015      0.892      0.372      -0.016       0.043
# product_category_name_eletronicos                                       -0.0024      0.015     -0.160      0.873      -0.031       0.027
# product_category_name_eletroportateis                                    0.0148      0.015      0.986      0.324      -0.015       0.044
# product_category_name_esporte_lazer                                      0.0363      0.014      2.565      0.010       0.009       0.064
# product_category_name_fashion_bolsas_e_acessorios                       -0.0060      0.015     -0.397      0.691      -0.036       0.024
# product_category_name_fashion_calcados                                  -0.0005      0.015     -0.034      0.973      -0.030       0.029
# product_category_name_fashion_esporte                                   -0.0181      0.015     -1.210      0.226      -0.047       0.011
# product_category_name_fashion_roupa_feminina                            -0.0252      0.015     -1.685      0.092      -0.055       0.004
# product_category_name_fashion_roupa_infanto_juvenil                  -1.217e-17    1.1e-17     -1.107      0.269   -3.37e-17    9.39e-18
# product_category_name_fashion_roupa_masculina                           -0.0280      0.015     -1.871      0.061      -0.057       0.001
# product_category_name_fashion_underwear_e_moda_praia                     0.0370      0.015      2.473      0.013       0.008       0.066
# product_category_name_ferramentas_jardim                                 0.0021      0.015      0.143      0.886      -0.027       0.031
# product_category_name_flores                                            -0.0099      0.015     -0.659      0.510      -0.039       0.019
# product_category_name_fraldas_higiene                                   -0.0133      0.015     -0.890      0.374      -0.043       0.016
# product_category_name_industria_comercio_e_negocios                     -0.0162      0.015     -1.060      0.289      -0.046       0.014
# product_category_name_informatica_acessorios                            -0.0273      0.014     -1.910      0.056      -0.055       0.001
# product_category_name_instrumentos_musicais                              0.0134      0.015      0.894      0.371      -0.016       0.043
# product_category_name_la_cuisine                                     -2.254e-17    1.1e-17     -2.048      0.041   -4.41e-17   -9.65e-19
# product_category_name_livros_importados                                 -0.0178      0.015     -1.191      0.234      -0.047       0.012
# product_category_name_livros_interesse_geral                             0.0284      0.015      1.897      0.058      -0.001       0.058
# product_category_name_livros_tecnicos                                   -0.0003      0.015     -0.019      0.985      -0.030       0.029
# product_category_name_malas_acessorios                                  -0.0076      0.015     -0.506      0.613      -0.037       0.022
# product_category_name_market_place                                       0.0127      0.015      0.849      0.396      -0.017       0.042
# product_category_name_moveis_colchao_e_estofado                       -4.66e-18   1.13e-17     -0.411      0.681   -2.69e-17    1.76e-17
# product_category_name_moveis_cozinha_area_de_servico_jantar_e_jardim     0.0018      0.015      0.118      0.906      -0.028       0.031
# product_category_name_moveis_decoracao                                   0.0062      0.015      0.423      0.672      -0.022       0.035
# product_category_name_moveis_escritorio                                  0.0094      0.016      0.589      0.556      -0.022       0.041
# product_category_name_moveis_quarto                                      0.0125      0.015      0.828      0.408      -0.017       0.042
# product_category_name_moveis_sala                                       -0.0010      0.015     -0.065      0.948      -0.031       0.029
# product_category_name_musica                                            -0.0152      0.015     -1.015      0.310      -0.045       0.014
# product_category_name_other                                             -0.0108      0.015     -0.724      0.469      -0.040       0.018
# product_category_name_papelaria                                          0.0053      0.015      0.354      0.724      -0.024       0.034
# product_category_name_pc_gamer                                          -0.0148      0.015     -0.988      0.323      -0.044       0.015
# product_category_name_pcs                                                0.0184      0.016      1.143      0.253      -0.013       0.050
# product_category_name_perfumaria                                         0.0103      0.015      0.699      0.484      -0.019       0.039
# product_category_name_pet_shop                                           0.0044      0.015      0.297      0.767      -0.025       0.033
# product_category_name_portateis_casa_forno_e_cafe                        0.0173      0.015      1.158      0.247      -0.012       0.047
# product_category_name_portateis_cozinha_e_preparadores_de_alimentos     -0.0167      0.015     -1.114      0.265      -0.046       0.013
# product_category_name_relogios_presentes                                -0.0093      0.015     -0.615      0.538      -0.039       0.020
# product_category_name_seguros_e_servicos                              2.421e-18   1.02e-17      0.237      0.812   -1.76e-17    2.24e-17
# product_category_name_sinalizacao_e_seguranca                           -0.0199      0.015     -1.326      0.185      -0.049       0.009
# product_category_name_tablets_impressao_imagem                           0.0162      0.015      1.078      0.281      -0.013       0.046
# product_category_name_telefonia                                         -0.0116      0.015     -0.774      0.439      -0.041       0.018
# product_category_name_telefonia_fixa                                    -0.0097      0.015     -0.648      0.517      -0.039       0.020
# product_category_name_utilidades_domesticas                              0.0098      0.014      0.680      0.496      -0.018       0.038
# customer_state_AC                                                       -0.0159      0.015     -1.061      0.289      -0.045       0.013
# customer_state_AL                                                        0.0082      0.015      0.545      0.586      -0.021       0.038
# customer_state_AM                                                        0.0122      0.015      0.812      0.417      -0.017       0.042
# customer_state_AP                                                       -0.0196      0.015     -1.304      0.192      -0.049       0.010
# customer_state_BA                                                        0.0064      0.014      0.445      0.656      -0.022       0.035
# customer_state_CE                                                       -0.0089      0.015     -0.596      0.551      -0.038       0.020
# customer_state_DF                                                       -0.0048      0.015     -0.328      0.743      -0.033       0.024
# customer_state_ES                                                        0.0148      0.015      1.007      0.314      -0.014       0.044
# customer_state_GO                                                       -0.0264      0.015     -1.800      0.072      -0.055       0.002
# customer_state_MA                                                       -0.0166      0.015     -1.106      0.269      -0.046       0.013
# customer_state_MG                                                        0.0161      0.013      1.226      0.220      -0.010       0.042
# customer_state_MS                                                        0.0017      0.015      0.112      0.911      -0.028       0.031
# customer_state_MT                                                       -0.0108      0.015     -0.725      0.468      -0.040       0.018
# customer_state_PA                                                       -0.0033      0.015     -0.220      0.826      -0.033       0.026
# customer_state_PB                                                       -0.0255      0.015     -1.702      0.089      -0.055       0.004
# customer_state_PE                                                       -0.0117      0.015     -0.784      0.433      -0.041       0.018
# customer_state_PI                                                        0.0331      0.015      2.194      0.028       0.004       0.063
# customer_state_PR                                                        0.0207      0.014      1.464      0.143      -0.007       0.049
# customer_state_RJ                                                       -0.0098      0.013     -0.752      0.452      -0.035       0.016
# customer_state_RN                                                       -0.0056      0.015     -0.373      0.710      -0.035       0.024
# customer_state_RO                                                       -0.0177      0.015     -1.182      0.237      -0.047       0.012
# customer_state_RR                                                        0.0190      0.015      1.270      0.204      -0.010       0.048
# customer_state_RS                                                        0.0183      0.014      1.306      0.192      -0.009       0.046
# customer_state_SC                                                       -0.0053      0.014     -0.367      0.714      -0.033       0.023
# customer_state_SE                                                        0.0070      0.015      0.468      0.640      -0.022       0.036
# customer_state_SP                                                       -0.0072      0.011     -0.647      0.517      -0.029       0.015
# customer_state_TO                                                        0.0080      0.015      0.533      0.594      -0.021       0.037
# ==============================================================================
# Omnibus:                      917.277   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1208.772
# Skew:                           0.869   Prob(JB):                    3.30e-263
# Kurtosis:                       3.003   Cond. No.                     1.76e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.17e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
# Text(0.5, 0, 'normalized coefficient')

# %%
translation_df
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
translation_df[translation_df['product_category_name']=='musica']
# Out:
#    product_category_name product_category_name_english
# 61                musica                         music

# %%
coef_df
# Out:
#                                    coef    std err          t   P>|t|  \
# 0                   const  3.066000e-16      0.017   1.78e-14   1.000
# 1                order_id  3.100000e-03      0.022      0.143   0.887
# 2           payment_value -6.800000e-03      0.024     -0.286   0.775
# 3    payment_installments  1.600000e-02      0.021      0.778   0.437
# 4            review_score  2.200000e-03      0.018      0.121   0.904
# ..                    ...           ...        ...        ...     ...
# 117     customer_state_RS -1.830000e-02      0.016     -1.137   0.256
# 118     customer_state_SC  3.700000e-03      0.017      0.226   0.821
# 119     customer_state_SE -3.020000e-02      0.017     -1.749   0.080
# 120     customer_state_SP -2.350000e-02      0.013     -1.847   0.065
# 121     customer_state_TO -8.500000e-03      0.017     -0.490   0.624
#
#         [0.025     0.975]
# 0       -0.034      0.034
# 1       -0.040      0.046
# 2       -0.053      0.040
# 3       -0.024      0.056
# 4       -0.033      0.038
# ..         ...        ...
# 117     -0.050      0.013
# 118     -0.029      0.036
# 119     -0.064      0.004
# 120     -0.048      0.001
# 121     -0.042      0.025
#
# [122 rows x 7 columns]

# %%
customer_segment_list = []
for cluster in range(n_clusters):
    if km.cluster_centers_[cluster, 0] > 0:
        customer_segment_list.append('current | ')
    else:
        customer_segment_list.append('churned | ')
    if km.cluster_centers_[cluster, 1] > 0:
        customer_segment_list[cluster] += 'regular | '
    else:
        customer_segment_list[cluster] += 'one time | '
    if km.cluster_centers_[cluster, 2] > 0:
        customer_segment_list[cluster] += 'high value'
    else:
        customer_segment_list[cluster] += 'low value'

customer_segment_list

# %%
import seaborn as sns
import string
sns.heatmap(km.cluster_centers_, cmap='GnBu', 
            xticklabels=rfm_df.columns,
            yticklabels=customer_segment_list)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X_scaled)

# %%
plt.scatter(X_tsne[:,0], X_tsne[:,1], c=labels)
plt.xlabel('TSNE 1')
plt.ylabel('TSNE 2')

# %%
poc3m_df = pay_order_cust_df[(date(2017,4,1) <= pay_order_cust_df.purchase_date) &
                              (pay_order_cust_df.purchase_date < date(2017,7,1))]
poc6m_df = pay_order_cust_df[(date(2017,7,1) <= pay_order_cust_df.purchase_date) & 
                              (pay_order_cust_df.purchase_date < date(2018,2,1))]

# %%
rfm3m_df = poc3m_df.groupby('customer_unique_id').agg({'purchase_date':'max', 'order_id':'count', 'payment_value':'sum'})
rfm3m_df.purchase_date = rfm3m_df.purchase_date.apply(lambda x: max(rfm3m_df.purchase_date)-x)
rfm3m_df.columns = ['recency', 'frequency', 'monetary']
rfm3m_df.head()

# %%
rfm3m_df.info()

# %%
rfm3m_df.head()

# %%
m6m_df = poc6m_df.groupby('customer_unique_id')['payment_value'].sum()
m6m_df

# %%
rfm3m_m6m_df = pd.merge(rfm3m_df, m6m_df)
rfm3m_m6m_df
