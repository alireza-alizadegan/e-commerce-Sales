# %% [markdown]
# <h1 id='tocheading'>Table of Content</h1>
# <div id='toc'></div>

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %% [markdown]
# # Data Cleaning

# %%
# frequently used python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from datetime import date

# %% [markdown]
# ## Order Dataset

# %%
order_df = pd.read_csv('olist_orders_dataset.csv')
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
# order_id                         99441 non-null object
# customer_id                      99441 non-null object
# order_status                     99441 non-null object
# order_purchase_timestamp         99441 non-null object
# order_approved_at                99281 non-null object
# order_delivered_carrier_date     97658 non-null object
# order_delivered_customer_date    96476 non-null object
# order_estimated_delivery_date    99441 non-null object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
order_df[order_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# Index: []

# %%
order_df.drop(['order_status',
               'order_delivered_carrier_date',
               'order_approved_at',
               'order_delivered_customer_date',
               'order_estimated_delivery_date'], axis='columns', inplace=True)

order_df.order_purchase_timestamp = pd.to_datetime(order_df.order_purchase_timestamp).dt.date
#pocipr_df['order_purchase_timestamp'] = pocipr_df['order_purchase_timestamp'].dt.date

# %%
order_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_purchase_timestamp
# 0               2017-10-02
# 1               2018-07-24
# 2               2018-08-08
# 3               2017-11-18
# 4               2018-02-13

# %% [markdown]
# ## Customer Dataset

# %%
customer_df = pd.read_csv('olist_customers_dataset.csv')
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
# customer_id                 99441 non-null object
# customer_unique_id          99441 non-null object
# customer_zip_code_prefix    99441 non-null int64
# customer_city               99441 non-null object
# customer_state              99441 non-null object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customer_df[customer_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state]
# Index: []

# %%
customer_df.drop(['customer_zip_code_prefix', 'customer_city'], axis='columns', inplace=True)

# %%
customer_df.nunique()
# Out:
# customer_id           99441
# customer_unique_id    96096
# customer_state           27
# dtype: int64

# %%
customer_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#   customer_state
# 0             SP
# 1             SP
# 2             SP
# 3             SP
# 4             SP

# %% [markdown]
# ## Payment Dataset

# %%
payment_df = pd.read_csv('olist_order_payments_dataset.csv')
payment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
# order_id                103886 non-null object
# payment_sequential      103886 non-null int64
# payment_type            103886 non-null object
# payment_installments    103886 non-null int64
# payment_value           103886 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
payment_df.drop('payment_sequential', axis='columns', inplace=True)

# %%
payment_df[payment_df.duplicated()]
# Out:
#                                 order_id payment_type  payment_installments  \
# 3675    8ca5bdac5ebe8f2d6fc9171d5ebc906a      voucher                     1
# 4829    59d02be1c50fb6e6930cafd6ff6a31e5      voucher                     1
# 5091    4689b1816de42507a7d63a4617383c59      voucher                     1
# 6940    cf101c3abd3c061ca9f78c1bbb1125af      voucher                     1
# 7441    d744783ed2ace06cac647a9e64dcbcfd      voucher                     1
# ...                                  ...          ...                   ...
# 102942  dbc097913df341f30b9f9e92f459cee2      voucher                     1
# 103046  c5fd5386640ddd76adc482b72d24a02b      voucher                     1
# 103216  4d9190887b47ff1b89c657c788c038f6      voucher                     1
# 103551  1ea11b975aea60ca92fa0559184d3d34      voucher                     1
# 103747  cf101c3abd3c061ca9f78c1bbb1125af      voucher                     1
#
#         payment_value
# 3675            15.00
# 4829            20.00
# 5091            56.42
# 6940             8.46
# 7441             1.47
# ...               ...
# 102942          50.00
# 103046           5.79
# 103216          12.80
# 103551          12.69
# 103747           8.46
#
# [614 rows x 4 columns]

# %%
payment_df.head()
# Out:
#                            order_id payment_type  payment_installments  \
# 0  b81ef226f3fe1789b1e8b2acac839d17  credit_card                     8
# 1  a9810da82917af2d9aefd1278f1dcfa0  credit_card                     1
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd  credit_card                     1
# 3  ba78997921bbcdc1373bb41e913ab953  credit_card                     8
# 4  42fdf880ba16b47b59251dd489d4441a  credit_card                     2
#
#    payment_value
# 0          99.33
# 1          24.39
# 2          65.71
# 3         107.78
# 4         128.45

# %%
payment_df.nunique()
# Out:
# order_id                99440
# payment_type                5
# payment_installments       24
# payment_value           29077
# dtype: int64

# %% [markdown]
# ## Item Dataset

# %%
item_df = pd.read_csv('olist_order_items_dataset.csv')

# %%
item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
# order_id               112650 non-null object
# order_item_id          112650 non-null int64
# product_id             112650 non-null object
# seller_id              112650 non-null object
# shipping_limit_date    112650 non-null object
# price                  112650 non-null float64
# freight_value          112650 non-null float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
item_df.drop('order_item_id', axis='columns', inplace=True)

# %%
item_df[item_df.duplicated()]
# Out:
#                                 order_id                        product_id  \
# 14      0008288aa423d2a3f00fcb17cd7d8719  368c6c730842d78016ad823897a372db
# 33      00143d0f86d6fbd9f9b38ab440ac16f5  e95ee6822b66ac6058e2e4aff656071a
# 34      00143d0f86d6fbd9f9b38ab440ac16f5  e95ee6822b66ac6058e2e4aff656071a
# 43      001ab0a7578dd66cd4b0a71f5b6e1e41  0b0172eb0fd18479d29c3bc122c058c2
# 44      001ab0a7578dd66cd4b0a71f5b6e1e41  0b0172eb0fd18479d29c3bc122c058c2
# ...                                  ...                               ...
# 112617  ffecd5a79a0084f6a592288c67e3c298  50fd2b788dc166edd20512370dac54df
# 112635  fff8287bbae429a99bb7e8c21d151c41  bee2e070c39f3dd2f6883a17a5f0da45
# 112641  fffb9224b6fc7c43ebb0904318b10b5f  43423cdffde7fda63d0414ed38c11a73
# 112642  fffb9224b6fc7c43ebb0904318b10b5f  43423cdffde7fda63d0414ed38c11a73
# 112643  fffb9224b6fc7c43ebb0904318b10b5f  43423cdffde7fda63d0414ed38c11a73
#
#                                seller_id  shipping_limit_date   price  \
# 14      1f50f920176fa81dab994f9023523100  2018-02-21 02:55:52   49.90
# 33      a17f621c590ea0fab3d5d883e1630ec6  2017-10-20 16:07:52   21.33
# 34      a17f621c590ea0fab3d5d883e1630ec6  2017-10-20 16:07:52   21.33
# 43      5656537e588803a555b8eb41f07a944b  2018-01-04 02:33:42   24.89
# 44      5656537e588803a555b8eb41f07a944b  2018-01-04 02:33:42   24.89
# ...                                  ...                  ...     ...
# 112617  8b321bb669392f5163d04c59e235e066  2018-03-05 20:15:27   21.90
# 112635  4e922959ae960d389249c378d1c939f5  2018-03-27 12:29:22  180.00
# 112641  b1fc4f64df5a0e8b6913ab38803c57a9  2017-11-03 02:55:58   55.00
# 112642  b1fc4f64df5a0e8b6913ab38803c57a9  2017-11-03 02:55:58   55.00
# 112643  b1fc4f64df5a0e8b6913ab38803c57a9  2017-11-03 02:55:58   55.00
#
#         freight_value
# 14              13.37
# 33              15.10
# 34              15.10
# 43              17.63
# 44              17.63
# ...               ...
# 112617          15.79
# 112635          48.14
# 112641          34.19
# 112642          34.19
# 112643          34.19
#
# [10225 rows x 6 columns]

# %%
item_df.drop(['seller_id', 'shipping_limit_date'], axis='columns', inplace=True)
item_df.columns
# Out:
# Index(['order_id', 'product_id', 'price', 'freight_value'], dtype='object')

# %%
item_df.head()
# Out:
#                            order_id                        product_id   price  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61   58.90
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f  239.90
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd  199.00
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc   12.99
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089  199.90
#
#    freight_value
# 0          13.29
# 1          19.93
# 2          17.87
# 3          12.79
# 4          18.14

# %% [markdown]
# ## Product Dataset

# %%
product_df = pd.read_csv('olist_products_dataset.csv')

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
# product_id                    32951 non-null object
# product_category_name         32341 non-null object
# product_name_lenght           32341 non-null float64
# product_description_lenght    32341 non-null float64
# product_photos_qty            32341 non-null float64
# product_weight_g              32949 non-null float64
# product_length_cm             32949 non-null float64
# product_height_cm             32949 non-null float64
# product_width_cm              32949 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.product_category_name.nunique()
# Out:
# 73

# %%
product_df[product_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm]
# Index: []

# %%
product_df.fillna(product_df.median(), inplace=True)
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
# product_id                    32951 non-null object
# product_category_name         32341 non-null object
# product_name_lenght           32951 non-null float64
# product_description_lenght    32951 non-null float64
# product_photos_qty            32951 non-null float64
# product_weight_g              32951 non-null float64
# product_length_cm             32951 non-null float64
# product_height_cm             32951 non-null float64
# product_width_cm              32951 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.fillna('other', inplace=True)
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
# product_id                    32951 non-null object
# product_category_name         32951 non-null object
# product_name_lenght           32951 non-null float64
# product_description_lenght    32951 non-null float64
# product_photos_qty            32951 non-null float64
# product_weight_g              32951 non-null float64
# product_length_cm             32951 non-null float64
# product_height_cm             32951 non-null float64
# product_width_cm              32951 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
product_df.product_category_name.nunique()
# Out:
# 74

# %% [markdown]
# ## Translation Dataset

# %%
translation_df = pd.read_csv('product_category_name_translation.csv')
translation_df.info()
translation_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
# product_category_name            71 non-null object
# product_category_name_english    71 non-null object
# dtypes: object(2)
# memory usage: 1.2+ KB
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# ## Review Dataset

# %%
review_df = pd.read_csv('olist_order_reviews_dataset.csv')
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
# review_id                  100000 non-null object
# order_id                   100000 non-null object
# review_score               100000 non-null int64
# review_comment_title       11715 non-null object
# review_comment_message     41753 non-null object
# review_creation_date       100000 non-null object
# review_answer_timestamp    100000 non-null object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
review_df[review_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [review_id, order_id, review_score, review_comment_title, review_comment_message, review_creation_date, review_answer_timestamp]
# Index: []

# %%
review_df.drop(['review_id', 'review_creation_date', 'review_answer_timestamp'], axis='columns', inplace=True)
review_df.columns
# Out:
# Index(['order_id', 'review_score', 'review_comment_title',
#        'review_comment_message'],
#       dtype='object')

# %%
for columns in ['review_comment_title', 'review_comment_message']:
    # replace present values with 1
    review_df.loc[review_df[columns].notnull(), columns] = 1
    # replace null values with 0
    review_df.loc[review_df[columns].isna(), columns] = 0
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
# order_id                  100000 non-null object
# review_score              100000 non-null int64
# review_comment_title      100000 non-null int64
# review_comment_message    100000 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 3.1+ MB

# %%
review_df.head()
# Out:
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  a548910a1c6147796b98fdf73dbeba33             5                     0
# 2  f9e4b658b201a9f2ecdecbb34bed034b             5                     0
# 3  658677c97b385a9be170737859d3511b             5                     0
# 4  8e6bfb81e283fa7e4f11123a3fb894f1             5                     0
#
#    review_comment_message
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       1

# %%
review_df.nunique()
# Out:
# order_id                  99441
# review_score                  5
# review_comment_title          2
# review_comment_message        2
# dtype: int64

# %%
review_df.review_score.value_counts(normalize=True)
# Out:
# 5    0.57420
# 4    0.19200
# 1    0.11858
# 3    0.08287
# 2    0.03235
# Name: review_score, dtype: float64

# %%
plt.bar(review_df.review_score.value_counts().index, review_df.review_score.value_counts().values)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Seller Dataset

# %%
seller_df = pd.read_csv('olist_sellers_dataset.csv')
seller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
# seller_id                 3095 non-null object
# seller_zip_code_prefix    3095 non-null int64
# seller_city               3095 non-null object
# seller_state              3095 non-null object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
seller_df.drop(['seller_zip_code_prefix', 'seller_city'], axis='columns', inplace=True)
seller_df.columns
# Out:
# Index(['seller_id', 'seller_state'], dtype='object')

# %% [markdown]
# ## Dataset Joins

# %%
oc_df = pd.merge(order_df, customer_df, how='left', on='customer_id')
oc_df.drop('customer_id', axis='columns', inplace=True)
oc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 0 to 99440
# Data columns (total 4 columns):
# order_id                    99441 non-null object
# order_purchase_timestamp    99441 non-null object
# customer_unique_id          99441 non-null object
# customer_state              99441 non-null object
# dtypes: object(4)
# memory usage: 3.8+ MB

# %%
ocp_df = pd.merge(oc_df, payment_df, how='left', on='order_id')
ocp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103887 entries, 0 to 103886
# Data columns (total 7 columns):
# order_id                    103887 non-null object
# order_purchase_timestamp    103887 non-null object
# customer_unique_id          103887 non-null object
# customer_state              103887 non-null object
# payment_type                103886 non-null object
# payment_installments        103886 non-null float64
# payment_value               103886 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 6.3+ MB

# %%
ocpr_df = pd.merge(ocp_df, review_df, how='left', on='order_id')
ocpr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104486 entries, 0 to 104485
# Data columns (total 10 columns):
# order_id                    104486 non-null object
# order_purchase_timestamp    104486 non-null object
# customer_unique_id          104486 non-null object
# customer_state              104486 non-null object
# payment_type                104485 non-null object
# payment_installments        104485 non-null float64
# payment_value               104485 non-null float64
# review_score                104486 non-null int64
# review_comment_title        104486 non-null int64
# review_comment_message      104486 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 8.8+ MB

# %%
ocpri_df = pd.merge(ocpr_df, item_df, how='left', on='order_id')
#ocpri_df.drop('order_id', axis='columns', inplace=True)
ocpri_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119151 entries, 0 to 119150
# Data columns (total 13 columns):
# order_id                    119151 non-null object
# order_purchase_timestamp    119151 non-null object
# customer_unique_id          119151 non-null object
# customer_state              119151 non-null object
# payment_type                119148 non-null object
# payment_installments        119148 non-null float64
# payment_value               119148 non-null float64
# review_score                119151 non-null int64
# review_comment_title        119151 non-null int64
# review_comment_message      119151 non-null int64
# product_id                  118318 non-null object
# price                       118318 non-null float64
# freight_value               118318 non-null float64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 12.7+ MB

# %%
ocprip_df = pd.merge(ocpri_df, product_df, how='left', on='product_id')
ocprip_df.drop('product_id', axis='columns', inplace=True)
ocprip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119151 entries, 0 to 119150
# Data columns (total 20 columns):
# order_id                      119151 non-null object
# order_purchase_timestamp      119151 non-null object
# customer_unique_id            119151 non-null object
# customer_state                119151 non-null object
# payment_type                  119148 non-null object
# payment_installments          119148 non-null float64
# payment_value                 119148 non-null float64
# review_score                  119151 non-null int64
# review_comment_title          119151 non-null int64
# review_comment_message        119151 non-null int64
# price                         118318 non-null float64
# freight_value                 118318 non-null float64
# product_category_name         118318 non-null object
# product_name_lenght           118318 non-null float64
# product_description_lenght    118318 non-null float64
# product_photos_qty            118318 non-null float64
# product_weight_g              118318 non-null float64
# product_length_cm             118318 non-null float64
# product_height_cm             118318 non-null float64
# product_width_cm              118318 non-null float64
# dtypes: float64(11), int64(3), object(6)
# memory usage: 19.1+ MB

# %%
ocprip_df.fillna(ocprip_df.median(), inplace=True)

# %%
for column in ['payment_type', 'product_category_name']:
    ocprip_df[column].fillna(ocprip_df[column].value_counts().index[0], inplace=True)

# %%
ocprip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119151 entries, 0 to 119150
# Data columns (total 20 columns):
# order_id                      119151 non-null object
# order_purchase_timestamp      119151 non-null object
# customer_unique_id            119151 non-null object
# customer_state                119151 non-null object
# payment_type                  119151 non-null object
# payment_installments          119151 non-null float64
# payment_value                 119151 non-null float64
# review_score                  119151 non-null int64
# review_comment_title          119151 non-null int64
# review_comment_message        119151 non-null int64
# price                         119151 non-null float64
# freight_value                 119151 non-null float64
# product_category_name         119151 non-null object
# product_name_lenght           119151 non-null float64
# product_description_lenght    119151 non-null float64
# product_photos_qty            119151 non-null float64
# product_weight_g              119151 non-null float64
# product_length_cm             119151 non-null float64
# product_height_cm             119151 non-null float64
# product_width_cm              119151 non-null float64
# dtypes: float64(11), int64(3), object(6)
# memory usage: 19.1+ MB

# %%
ocpript_df = pd.merge(ocprip_df, translation_df, how='left', on='product_id')
ocpript_df.drop('product_category_name', axis='columns', inplace=True)
ocprip_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-9742cc42a552> in <module>
# ----> 1 ocpript_df = pd.merge(ocprip_df, translation_df, how='left', on='product_id')
#       2 ocpript_df.drop('product_category_name', axis='columns', inplace=True)
#       3 ocprip_df.info()
#
# NameError: name 'ocprip_df' is not defined

# %%
df = ocprip_df.groupby('customer_unique_id').agg({'order_id': 'count',
                                                  'payment_value': 'sum',
                                                  'payment_installments': 'mean',
                                                  'review_score': 'mean',
                                                  'price': 'mean',
                                                  'freight_value': 'mean',
                                                  'product_name_lenght': 'mean',
                                                  'product_description_lenght': 'mean',
                                                  'product_photos_qty': 'mean',
                                                  'product_length_cm': 'mean',
                                                  'product_height_cm': 'mean',
                                                  'product_width_cm': 'mean',
                                                  'review_comment_title': 'mean',
                                                  'review_comment_message': 'mean',
                                                  'payment_type': lambda x: x.value_counts().index[0],
                                                  'product_category_name': lambda x: x.value_counts().index[0],
                                                  'customer_state': lambda x: x.value_counts().index[0],
                                                  'order_purchase_timestamp': lambda x: min((max(ocprip_df.order_purchase_timestamp)-x).dt.days)})
df
# Out:
#                                   order_id  payment_value  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2         1         141.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f         1          27.19
# 0000f46a3911fa3c0805444483337064         1          86.22
# 0000f6ccb0745a6a4b88665a16c9f078         1          43.62
# 0004aac84e0df4da2b147fca70cf8255         1         196.89
# ...                                    ...            ...
# fffcf5a5ff07b0908bd4e2dbc735a684         2        4134.84
# fffea47cd6d3cc0a88bd621562a9d061         1          84.58
# ffff371b4d645b6ecea244b27531430a         1         112.46
# ffff5962728ec6157033ef9805bacc48         1         133.69
# ffffd2657e2aad2907e67c3e9daecbeb         1          71.56
#
#                                   payment_installments  review_score   price  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                   8.0           5.0  129.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f                   1.0           4.0   18.90
# 0000f46a3911fa3c0805444483337064                   8.0           3.0   69.00
# 0000f6ccb0745a6a4b88665a16c9f078                   4.0           4.0   25.99
# 0004aac84e0df4da2b147fca70cf8255                   6.0           5.0  180.00
# ...                                                ...           ...     ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  10.0           5.0  785.00
# fffea47cd6d3cc0a88bd621562a9d061                   1.0           4.0   64.89
# ffff371b4d645b6ecea244b27531430a                   1.0           5.0   89.90
# ffff5962728ec6157033ef9805bacc48                   5.0           5.0  115.00
# ffffd2657e2aad2907e67c3e9daecbeb                   4.0           5.0   56.99
#
#                                   freight_value  product_name_lenght  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2          12.00                 60.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f           8.29                 56.0
# 0000f46a3911fa3c0805444483337064          17.22                 49.0
# 0000f6ccb0745a6a4b88665a16c9f078          17.63                 43.0
# 0004aac84e0df4da2b147fca70cf8255          16.89                 58.0
# ...                                         ...                  ...
# fffcf5a5ff07b0908bd4e2dbc735a684         248.71                 54.0
# fffea47cd6d3cc0a88bd621562a9d061          19.69                 37.0
# ffff371b4d645b6ecea244b27531430a          22.56                 57.0
# ffff5962728ec6157033ef9805bacc48          18.69                 35.0
# ffffd2657e2aad2907e67c3e9daecbeb          14.57                 45.0
#
#                                   product_description_lenght  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                       236.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                       635.0
# 0000f46a3911fa3c0805444483337064                       177.0
# 0000f6ccb0745a6a4b88665a16c9f078                      1741.0
# 0004aac84e0df4da2b147fca70cf8255                       794.0
# ...                                                      ...
# fffcf5a5ff07b0908bd4e2dbc735a684                       478.5
# fffea47cd6d3cc0a88bd621562a9d061                       506.0
# ffff371b4d645b6ecea244b27531430a                       716.0
# ffff5962728ec6157033ef9805bacc48                       591.0
# ffffd2657e2aad2907e67c3e9daecbeb                      1003.0
#
#                                   product_photos_qty  product_length_cm  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                 1.0               34.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                 1.0               26.0
# 0000f46a3911fa3c0805444483337064                 3.0               25.0
# 0000f6ccb0745a6a4b88665a16c9f078                 5.0               19.0
# 0004aac84e0df4da2b147fca70cf8255                 3.0               16.0
# ...                                              ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                 1.0               55.0
# fffea47cd6d3cc0a88bd621562a9d061                 2.0               33.0
# ffff371b4d645b6ecea244b27531430a                 5.0               17.0
# ffff5962728ec6157033ef9805bacc48                 3.0               20.0
# ffffd2657e2aad2907e67c3e9daecbeb                 2.0               18.0
#
#                                   product_height_cm  product_width_cm  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                7.0              32.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f               11.0              18.0
# 0000f46a3911fa3c0805444483337064               50.0              35.0
# 0000f6ccb0745a6a4b88665a16c9f078                5.0              11.0
# 0004aac84e0df4da2b147fca70cf8255                3.0              11.0
# ...                                             ...               ...
# fffcf5a5ff07b0908bd4e2dbc735a684               75.0              61.0
# fffea47cd6d3cc0a88bd621562a9d061               36.0              27.0
# ffff371b4d645b6ecea244b27531430a               15.0              13.0
# ffff5962728ec6157033ef9805bacc48               14.0              16.0
# ffffd2657e2aad2907e67c3e9daecbeb               11.0              11.0
#
#                                   review_comment_title  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                   1.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                   0.0
# 0000f46a3911fa3c0805444483337064                   0.0
# 0000f6ccb0745a6a4b88665a16c9f078                   0.0
# 0004aac84e0df4da2b147fca70cf8255                   0.0
# ...                                                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                   0.0
# fffea47cd6d3cc0a88bd621562a9d061                   0.0
# ffff371b4d645b6ecea244b27531430a                   0.0
# ffff5962728ec6157033ef9805bacc48                   1.0
# ffffd2657e2aad2907e67c3e9daecbeb                   0.0
#
#                                   review_comment_message payment_type  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                     1.0  credit_card
# 0000b849f77a49e4a4ce2b2a4ca5be3f                     0.0  credit_card
# 0000f46a3911fa3c0805444483337064                     0.0  credit_card
# 0000f6ccb0745a6a4b88665a16c9f078                     1.0  credit_card
# 0004aac84e0df4da2b147fca70cf8255                     0.0  credit_card
# ...                                                  ...          ...
# fffcf5a5ff07b0908bd4e2dbc735a684                     0.0  credit_card
# fffea47cd6d3cc0a88bd621562a9d061                     0.0  credit_card
# ffff371b4d645b6ecea244b27531430a                     0.0  credit_card
# ffff5962728ec6157033ef9805bacc48                     1.0  credit_card
# ffffd2657e2aad2907e67c3e9daecbeb                     0.0  credit_card
#
#                                  product_category_name customer_state  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2       cama_mesa_banho             SP
# 0000b849f77a49e4a4ce2b2a4ca5be3f          beleza_saude             SP
# 0000f46a3911fa3c0805444483337064             papelaria             SC
# 0000f6ccb0745a6a4b88665a16c9f078             telefonia             PA
# 0004aac84e0df4da2b147fca70cf8255             telefonia             SP
# ...                                                ...            ...
# fffcf5a5ff07b0908bd4e2dbc735a684          beleza_saude             PE
# fffea47cd6d3cc0a88bd621562a9d061                 bebes             BA
# ffff371b4d645b6ecea244b27531430a            automotivo             MT
# ffff5962728ec6157033ef9805bacc48    relogios_presentes             ES
# ffffd2657e2aad2907e67c3e9daecbeb            perfumaria             PR
#
#                                   order_purchase_timestamp
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                       160
# 0000b849f77a49e4a4ce2b2a4ca5be3f                       163
# 0000f46a3911fa3c0805444483337064                       586
# 0000f6ccb0745a6a4b88665a16c9f078                       370
# 0004aac84e0df4da2b147fca70cf8255                       337
# ...                                                    ...
# fffcf5a5ff07b0908bd4e2dbc735a684                       496
# fffea47cd6d3cc0a88bd621562a9d061                       311
# ffff371b4d645b6ecea244b27531430a                       617
# ffff5962728ec6157033ef9805bacc48                       168
# ffffd2657e2aad2907e67c3e9daecbeb                       533
#
# [96096 rows x 18 columns]

# %%
# df.to_csv('df.csv', index=True);
cust_ocprip_df = pd.read_csv('df.csv', index_col=0)
cust_ocprip_df
# Out:
#                                   order_id  payment_value  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2         1         141.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f         1          27.19
# 0000f46a3911fa3c0805444483337064         1          86.22
# 0000f6ccb0745a6a4b88665a16c9f078         1          43.62
# 0004aac84e0df4da2b147fca70cf8255         1         196.89
# ...                                    ...            ...
# fffcf5a5ff07b0908bd4e2dbc735a684         2        4134.84
# fffea47cd6d3cc0a88bd621562a9d061         1          84.58
# ffff371b4d645b6ecea244b27531430a         1         112.46
# ffff5962728ec6157033ef9805bacc48         1         133.69
# ffffd2657e2aad2907e67c3e9daecbeb         1          71.56
#
#                                   payment_installments  review_score   price  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                   8.0           5.0  129.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f                   1.0           4.0   18.90
# 0000f46a3911fa3c0805444483337064                   8.0           3.0   69.00
# 0000f6ccb0745a6a4b88665a16c9f078                   4.0           4.0   25.99
# 0004aac84e0df4da2b147fca70cf8255                   6.0           5.0  180.00
# ...                                                ...           ...     ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  10.0           5.0  785.00
# fffea47cd6d3cc0a88bd621562a9d061                   1.0           4.0   64.89
# ffff371b4d645b6ecea244b27531430a                   1.0           5.0   89.90
# ffff5962728ec6157033ef9805bacc48                   5.0           5.0  115.00
# ffffd2657e2aad2907e67c3e9daecbeb                   4.0           5.0   56.99
#
#                                   freight_value  product_name_lenght  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2          12.00                 60.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f           8.29                 56.0
# 0000f46a3911fa3c0805444483337064          17.22                 49.0
# 0000f6ccb0745a6a4b88665a16c9f078          17.63                 43.0
# 0004aac84e0df4da2b147fca70cf8255          16.89                 58.0
# ...                                         ...                  ...
# fffcf5a5ff07b0908bd4e2dbc735a684         248.71                 54.0
# fffea47cd6d3cc0a88bd621562a9d061          19.69                 37.0
# ffff371b4d645b6ecea244b27531430a          22.56                 57.0
# ffff5962728ec6157033ef9805bacc48          18.69                 35.0
# ffffd2657e2aad2907e67c3e9daecbeb          14.57                 45.0
#
#                                   product_description_lenght  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                       236.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                       635.0
# 0000f46a3911fa3c0805444483337064                       177.0
# 0000f6ccb0745a6a4b88665a16c9f078                      1741.0
# 0004aac84e0df4da2b147fca70cf8255                       794.0
# ...                                                      ...
# fffcf5a5ff07b0908bd4e2dbc735a684                       478.5
# fffea47cd6d3cc0a88bd621562a9d061                       506.0
# ffff371b4d645b6ecea244b27531430a                       716.0
# ffff5962728ec6157033ef9805bacc48                       591.0
# ffffd2657e2aad2907e67c3e9daecbeb                      1003.0
#
#                                   product_photos_qty  product_length_cm  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                 1.0               34.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                 1.0               26.0
# 0000f46a3911fa3c0805444483337064                 3.0               25.0
# 0000f6ccb0745a6a4b88665a16c9f078                 5.0               19.0
# 0004aac84e0df4da2b147fca70cf8255                 3.0               16.0
# ...                                              ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                 1.0               55.0
# fffea47cd6d3cc0a88bd621562a9d061                 2.0               33.0
# ffff371b4d645b6ecea244b27531430a                 5.0               17.0
# ffff5962728ec6157033ef9805bacc48                 3.0               20.0
# ffffd2657e2aad2907e67c3e9daecbeb                 2.0               18.0
#
#                                   product_height_cm  product_width_cm  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                7.0              32.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f               11.0              18.0
# 0000f46a3911fa3c0805444483337064               50.0              35.0
# 0000f6ccb0745a6a4b88665a16c9f078                5.0              11.0
# 0004aac84e0df4da2b147fca70cf8255                3.0              11.0
# ...                                             ...               ...
# fffcf5a5ff07b0908bd4e2dbc735a684               75.0              61.0
# fffea47cd6d3cc0a88bd621562a9d061               36.0              27.0
# ffff371b4d645b6ecea244b27531430a               15.0              13.0
# ffff5962728ec6157033ef9805bacc48               14.0              16.0
# ffffd2657e2aad2907e67c3e9daecbeb               11.0              11.0
#
#                                   review_comment_title  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                   1.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                   0.0
# 0000f46a3911fa3c0805444483337064                   0.0
# 0000f6ccb0745a6a4b88665a16c9f078                   0.0
# 0004aac84e0df4da2b147fca70cf8255                   0.0
# ...                                                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                   0.0
# fffea47cd6d3cc0a88bd621562a9d061                   0.0
# ffff371b4d645b6ecea244b27531430a                   0.0
# ffff5962728ec6157033ef9805bacc48                   1.0
# ffffd2657e2aad2907e67c3e9daecbeb                   0.0
#
#                                   review_comment_message payment_type  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                     1.0  credit_card
# 0000b849f77a49e4a4ce2b2a4ca5be3f                     0.0  credit_card
# 0000f46a3911fa3c0805444483337064                     0.0  credit_card
# 0000f6ccb0745a6a4b88665a16c9f078                     1.0  credit_card
# 0004aac84e0df4da2b147fca70cf8255                     0.0  credit_card
# ...                                                  ...          ...
# fffcf5a5ff07b0908bd4e2dbc735a684                     0.0  credit_card
# fffea47cd6d3cc0a88bd621562a9d061                     0.0  credit_card
# ffff371b4d645b6ecea244b27531430a                     0.0  credit_card
# ffff5962728ec6157033ef9805bacc48                     1.0  credit_card
# ffffd2657e2aad2907e67c3e9daecbeb                     0.0  credit_card
#
#                                  product_category_name customer_state  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2       cama_mesa_banho             SP
# 0000b849f77a49e4a4ce2b2a4ca5be3f          beleza_saude             SP
# 0000f46a3911fa3c0805444483337064             papelaria             SC
# 0000f6ccb0745a6a4b88665a16c9f078             telefonia             PA
# 0004aac84e0df4da2b147fca70cf8255             telefonia             SP
# ...                                                ...            ...
# fffcf5a5ff07b0908bd4e2dbc735a684          beleza_saude             PE
# fffea47cd6d3cc0a88bd621562a9d061                 bebes             BA
# ffff371b4d645b6ecea244b27531430a            automotivo             MT
# ffff5962728ec6157033ef9805bacc48    relogios_presentes             ES
# ffffd2657e2aad2907e67c3e9daecbeb            perfumaria             PR
#
#                                   order_purchase_timestamp
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                       160
# 0000b849f77a49e4a4ce2b2a4ca5be3f                       163
# 0000f46a3911fa3c0805444483337064                       586
# 0000f6ccb0745a6a4b88665a16c9f078                       370
# 0004aac84e0df4da2b147fca70cf8255                       337
# ...                                                    ...
# fffcf5a5ff07b0908bd4e2dbc735a684                       496
# fffea47cd6d3cc0a88bd621562a9d061                       311
# ffff371b4d645b6ecea244b27531430a                       617
# ffff5962728ec6157033ef9805bacc48                       168
# ffffd2657e2aad2907e67c3e9daecbeb                       533
#
# [96096 rows x 18 columns]

# %%
df = pd.get_dummies(cust_ocprip_df)
df
# Out:
#                                   order_id  payment_value  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2         1         141.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f         1          27.19
# 0000f46a3911fa3c0805444483337064         1          86.22
# 0000f6ccb0745a6a4b88665a16c9f078         1          43.62
# 0004aac84e0df4da2b147fca70cf8255         1         196.89
# ...                                    ...            ...
# fffcf5a5ff07b0908bd4e2dbc735a684         2        4134.84
# fffea47cd6d3cc0a88bd621562a9d061         1          84.58
# ffff371b4d645b6ecea244b27531430a         1         112.46
# ffff5962728ec6157033ef9805bacc48         1         133.69
# ffffd2657e2aad2907e67c3e9daecbeb         1          71.56
#
#                                   payment_installments  review_score   price  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                   8.0           5.0  129.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f                   1.0           4.0   18.90
# 0000f46a3911fa3c0805444483337064                   8.0           3.0   69.00
# 0000f6ccb0745a6a4b88665a16c9f078                   4.0           4.0   25.99
# 0004aac84e0df4da2b147fca70cf8255                   6.0           5.0  180.00
# ...                                                ...           ...     ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  10.0           5.0  785.00
# fffea47cd6d3cc0a88bd621562a9d061                   1.0           4.0   64.89
# ffff371b4d645b6ecea244b27531430a                   1.0           5.0   89.90
# ffff5962728ec6157033ef9805bacc48                   5.0           5.0  115.00
# ffffd2657e2aad2907e67c3e9daecbeb                   4.0           5.0   56.99
#
#                                   freight_value  product_name_lenght  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2          12.00                 60.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f           8.29                 56.0
# 0000f46a3911fa3c0805444483337064          17.22                 49.0
# 0000f6ccb0745a6a4b88665a16c9f078          17.63                 43.0
# 0004aac84e0df4da2b147fca70cf8255          16.89                 58.0
# ...                                         ...                  ...
# fffcf5a5ff07b0908bd4e2dbc735a684         248.71                 54.0
# fffea47cd6d3cc0a88bd621562a9d061          19.69                 37.0
# ffff371b4d645b6ecea244b27531430a          22.56                 57.0
# ffff5962728ec6157033ef9805bacc48          18.69                 35.0
# ffffd2657e2aad2907e67c3e9daecbeb          14.57                 45.0
#
#                                   product_description_lenght  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                       236.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                       635.0
# 0000f46a3911fa3c0805444483337064                       177.0
# 0000f6ccb0745a6a4b88665a16c9f078                      1741.0
# 0004aac84e0df4da2b147fca70cf8255                       794.0
# ...                                                      ...
# fffcf5a5ff07b0908bd4e2dbc735a684                       478.5
# fffea47cd6d3cc0a88bd621562a9d061                       506.0
# ffff371b4d645b6ecea244b27531430a                       716.0
# ffff5962728ec6157033ef9805bacc48                       591.0
# ffffd2657e2aad2907e67c3e9daecbeb                      1003.0
#
#                                   product_photos_qty  product_length_cm  ...  \
# customer_unique_id                                                       ...
# 0000366f3b9a7992bf8c76cfdf3221e2                 1.0               34.0  ...
# 0000b849f77a49e4a4ce2b2a4ca5be3f                 1.0               26.0  ...
# 0000f46a3911fa3c0805444483337064                 3.0               25.0  ...
# 0000f6ccb0745a6a4b88665a16c9f078                 5.0               19.0  ...
# 0004aac84e0df4da2b147fca70cf8255                 3.0               16.0  ...
# ...                                              ...                ...  ...
# fffcf5a5ff07b0908bd4e2dbc735a684                 1.0               55.0  ...
# fffea47cd6d3cc0a88bd621562a9d061                 2.0               33.0  ...
# ffff371b4d645b6ecea244b27531430a                 5.0               17.0  ...
# ffff5962728ec6157033ef9805bacc48                 3.0               20.0  ...
# ffffd2657e2aad2907e67c3e9daecbeb                 2.0               18.0  ...
#
#                                   customer_state_PR  customer_state_RJ  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                  0                  0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                  0                  0
# 0000f46a3911fa3c0805444483337064                  0                  0
# 0000f6ccb0745a6a4b88665a16c9f078                  0                  0
# 0004aac84e0df4da2b147fca70cf8255                  0                  0
# ...                                             ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  0                  0
# fffea47cd6d3cc0a88bd621562a9d061                  0                  0
# ffff371b4d645b6ecea244b27531430a                  0                  0
# ffff5962728ec6157033ef9805bacc48                  0                  0
# ffffd2657e2aad2907e67c3e9daecbeb                  1                  0
#
#                                   customer_state_RN  customer_state_RO  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                  0                  0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                  0                  0
# 0000f46a3911fa3c0805444483337064                  0                  0
# 0000f6ccb0745a6a4b88665a16c9f078                  0                  0
# 0004aac84e0df4da2b147fca70cf8255                  0                  0
# ...                                             ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  0                  0
# fffea47cd6d3cc0a88bd621562a9d061                  0                  0
# ffff371b4d645b6ecea244b27531430a                  0                  0
# ffff5962728ec6157033ef9805bacc48                  0                  0
# ffffd2657e2aad2907e67c3e9daecbeb                  0                  0
#
#                                   customer_state_RR  customer_state_RS  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                  0                  0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                  0                  0
# 0000f46a3911fa3c0805444483337064                  0                  0
# 0000f6ccb0745a6a4b88665a16c9f078                  0                  0
# 0004aac84e0df4da2b147fca70cf8255                  0                  0
# ...                                             ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  0                  0
# fffea47cd6d3cc0a88bd621562a9d061                  0                  0
# ffff371b4d645b6ecea244b27531430a                  0                  0
# ffff5962728ec6157033ef9805bacc48                  0                  0
# ffffd2657e2aad2907e67c3e9daecbeb                  0                  0
#
#                                   customer_state_SC  customer_state_SE  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                  0                  0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                  0                  0
# 0000f46a3911fa3c0805444483337064                  1                  0
# 0000f6ccb0745a6a4b88665a16c9f078                  0                  0
# 0004aac84e0df4da2b147fca70cf8255                  0                  0
# ...                                             ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  0                  0
# fffea47cd6d3cc0a88bd621562a9d061                  0                  0
# ffff371b4d645b6ecea244b27531430a                  0                  0
# ffff5962728ec6157033ef9805bacc48                  0                  0
# ffffd2657e2aad2907e67c3e9daecbeb                  0                  0
#
#                                   customer_state_SP  customer_state_TO
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                  1                  0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                  1                  0
# 0000f46a3911fa3c0805444483337064                  0                  0
# 0000f6ccb0745a6a4b88665a16c9f078                  0                  0
# 0004aac84e0df4da2b147fca70cf8255                  1                  0
# ...                                             ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  0                  0
# fffea47cd6d3cc0a88bd621562a9d061                  0                  0
# ffff371b4d645b6ecea244b27531430a                  0                  0
# ffff5962728ec6157033ef9805bacc48                  0                  0
# ffffd2657e2aad2907e67c3e9daecbeb                  0                  0
#
# [96096 rows x 121 columns]

# %% [markdown]
# # Exploratory Data Analytics

# %%
plt.hist(cust_ocprip_df.payment_value, bins=100);

# %%
cust_ocprip_df.payment_installments.value_counts()
# Out:
# 1.000000    46466
# 2.000000    11825
# 3.000000     9858
# 4.000000     6695
# 5.000000     4887
#             ...
# 5.363636        1
# 4.571429        1
# 1.142857        1
# 4.250000        1
# 1.114286        1
# Name: payment_installments, Length: 128, dtype: int64

# %%
plt.bar(cust_ocprip_df.payment_installments.value_counts().index, cust_ocprip_df.payment_installments.value_counts().values);

# %%
plt.bar(cust_ocprip_df.review_score.value_counts().index, cust_ocprip_df.review_score.value_counts().values);

# %%
plt.hist(cust_ocprip_df.price, bins=100);

# %%
plt.hist(cust_ocprip_df.freight_value, bins=50);

# %%
plt.hist(cust_ocprip_df.product_name_lenght, bins=50);

# %%
plt.hist(np.power(cust_ocprip_df.product_name_lenght, 3), bins=50);

# %%
cust_ocprip_df.product_name_lenght.sort_values()
# Out:
# customer_unique_id
# ce035dc4c675ac090c8a0ea03097d1f0     5.0
# eec90aa06e8887c2a5937f17d0d03d4e     5.0
# 69b7eeb81420bf2537b4e408c6bfe219     5.0
# c9a4d3ed04279264e926a98f98502fe6     5.0
# 88d6f82c6e7cfdc3313f53a6836f3138     5.0
#                                     ...
# 2f3c23d155ce288b4f27feabf58f8b03    72.0
# ac6b61f2d1d53bbe79898f3b9b522d09    72.0
# 16a80e00832b1f2f7dbdb8073f8e2ed1    72.0
# 1772de5c8b22d6970d4d4c91277a7796    72.0
# f7c5756a1a6307abaf212591d0d037b0    76.0
# Name: product_name_lenght, Length: 96096, dtype: float64

# %%
plt.hist(cust_ocprip_df.product_description_lenght, bins=50);

# %%
plt.bar(cust_ocprip_df.product_photos_qty.value_counts().index, cust_ocprip_df.product_photos_qty.value_counts().values);

# %%
plt.hist(cust_ocprip_df.product_length_cm, bins=50);

# %%
plt.hist(cust_ocprip_df.product_height_cm, bins=50);

# %%
plt.hist(cust_ocprip_df.product_width_cm, bins=50);

# %%
plt.hist(np.log(cust_ocprip_df.product_width_cm), bins=50);

# %% [markdown]
# # K-means Clustering

# %%
skewed_features = ['payment_value', 'payment_installments', 'price', 'freight_value', 'product_description_lenght', 
                   'product_photos_qty', 'product_length_cm', 'product_height_cm', 'product_width_cm']
log_cust_ocprip_df = cust_ocprip_df
log_cust_ocprip_df[skewed_features] = np.log(cust_ocprip_df[skewed_features])

# %%
df = pd.get_dummies(log_cust_ocprip_df)
df
# Out:
#                                   order_id  payment_value  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2         1       4.955123
# 0000b849f77a49e4a4ce2b2a4ca5be3f         1       3.302849
# 0000f46a3911fa3c0805444483337064         1       4.456902
# 0000f6ccb0745a6a4b88665a16c9f078         1       3.775516
# 0004aac84e0df4da2b147fca70cf8255         1       5.282645
# ...                                    ...            ...
# fffcf5a5ff07b0908bd4e2dbc735a684         2       8.327204
# fffea47cd6d3cc0a88bd621562a9d061         1       4.437698
# ffff371b4d645b6ecea244b27531430a         1       4.722598
# ffff5962728ec6157033ef9805bacc48         1       4.895524
# ffffd2657e2aad2907e67c3e9daecbeb         1       4.270536
#
#                                   payment_installments  review_score  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2              2.079442           5.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f              0.000000           4.0
# 0000f46a3911fa3c0805444483337064              2.079442           3.0
# 0000f6ccb0745a6a4b88665a16c9f078              1.386294           4.0
# 0004aac84e0df4da2b147fca70cf8255              1.791759           5.0
# ...                                                ...           ...
# fffcf5a5ff07b0908bd4e2dbc735a684              2.302585           5.0
# fffea47cd6d3cc0a88bd621562a9d061              0.000000           4.0
# ffff371b4d645b6ecea244b27531430a              0.000000           5.0
# ffff5962728ec6157033ef9805bacc48              1.609438           5.0
# ffffd2657e2aad2907e67c3e9daecbeb              1.386294           5.0
#
#                                      price  freight_value  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2  4.866765       2.484907
# 0000b849f77a49e4a4ce2b2a4ca5be3f  2.939162       2.115050
# 0000f46a3911fa3c0805444483337064  4.234107       2.846071
# 0000f6ccb0745a6a4b88665a16c9f078  3.257712       2.869602
# 0004aac84e0df4da2b147fca70cf8255  5.192957       2.826722
# ...                                    ...            ...
# fffcf5a5ff07b0908bd4e2dbc735a684  6.665684       5.516288
# fffea47cd6d3cc0a88bd621562a9d061  4.172694       2.980111
# ffff371b4d645b6ecea244b27531430a  4.498698       3.116178
# ffff5962728ec6157033ef9805bacc48  4.744932       2.927989
# ffffd2657e2aad2907e67c3e9daecbeb  4.042876       2.678965
#
#                                   product_name_lenght  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                 60.0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                 56.0
# 0000f46a3911fa3c0805444483337064                 49.0
# 0000f6ccb0745a6a4b88665a16c9f078                 43.0
# 0004aac84e0df4da2b147fca70cf8255                 58.0
# ...                                               ...
# fffcf5a5ff07b0908bd4e2dbc735a684                 54.0
# fffea47cd6d3cc0a88bd621562a9d061                 37.0
# ffff371b4d645b6ecea244b27531430a                 57.0
# ffff5962728ec6157033ef9805bacc48                 35.0
# ffffd2657e2aad2907e67c3e9daecbeb                 45.0
#
#                                   product_description_lenght  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                    5.463832
# 0000b849f77a49e4a4ce2b2a4ca5be3f                    6.453625
# 0000f46a3911fa3c0805444483337064                    5.176150
# 0000f6ccb0745a6a4b88665a16c9f078                    7.462215
# 0004aac84e0df4da2b147fca70cf8255                    6.677083
# ...                                                      ...
# fffcf5a5ff07b0908bd4e2dbc735a684                    6.170656
# fffea47cd6d3cc0a88bd621562a9d061                    6.226537
# ffff371b4d645b6ecea244b27531430a                    6.573680
# ffff5962728ec6157033ef9805bacc48                    6.381816
# ffffd2657e2aad2907e67c3e9daecbeb                    6.910751
#
#                                   product_photos_qty  product_length_cm  ...  \
# customer_unique_id                                                       ...
# 0000366f3b9a7992bf8c76cfdf3221e2            0.000000           3.526361  ...
# 0000b849f77a49e4a4ce2b2a4ca5be3f            0.000000           3.258097  ...
# 0000f46a3911fa3c0805444483337064            1.098612           3.218876  ...
# 0000f6ccb0745a6a4b88665a16c9f078            1.609438           2.944439  ...
# 0004aac84e0df4da2b147fca70cf8255            1.098612           2.772589  ...
# ...                                              ...                ...  ...
# fffcf5a5ff07b0908bd4e2dbc735a684            0.000000           4.007333  ...
# fffea47cd6d3cc0a88bd621562a9d061            0.693147           3.496508  ...
# ffff371b4d645b6ecea244b27531430a            1.609438           2.833213  ...
# ffff5962728ec6157033ef9805bacc48            1.098612           2.995732  ...
# ffffd2657e2aad2907e67c3e9daecbeb            0.693147           2.890372  ...
#
#                                   customer_state_PR  customer_state_RJ  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                  0                  0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                  0                  0
# 0000f46a3911fa3c0805444483337064                  0                  0
# 0000f6ccb0745a6a4b88665a16c9f078                  0                  0
# 0004aac84e0df4da2b147fca70cf8255                  0                  0
# ...                                             ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  0                  0
# fffea47cd6d3cc0a88bd621562a9d061                  0                  0
# ffff371b4d645b6ecea244b27531430a                  0                  0
# ffff5962728ec6157033ef9805bacc48                  0                  0
# ffffd2657e2aad2907e67c3e9daecbeb                  1                  0
#
#                                   customer_state_RN  customer_state_RO  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                  0                  0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                  0                  0
# 0000f46a3911fa3c0805444483337064                  0                  0
# 0000f6ccb0745a6a4b88665a16c9f078                  0                  0
# 0004aac84e0df4da2b147fca70cf8255                  0                  0
# ...                                             ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  0                  0
# fffea47cd6d3cc0a88bd621562a9d061                  0                  0
# ffff371b4d645b6ecea244b27531430a                  0                  0
# ffff5962728ec6157033ef9805bacc48                  0                  0
# ffffd2657e2aad2907e67c3e9daecbeb                  0                  0
#
#                                   customer_state_RR  customer_state_RS  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                  0                  0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                  0                  0
# 0000f46a3911fa3c0805444483337064                  0                  0
# 0000f6ccb0745a6a4b88665a16c9f078                  0                  0
# 0004aac84e0df4da2b147fca70cf8255                  0                  0
# ...                                             ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  0                  0
# fffea47cd6d3cc0a88bd621562a9d061                  0                  0
# ffff371b4d645b6ecea244b27531430a                  0                  0
# ffff5962728ec6157033ef9805bacc48                  0                  0
# ffffd2657e2aad2907e67c3e9daecbeb                  0                  0
#
#                                   customer_state_SC  customer_state_SE  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                  0                  0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                  0                  0
# 0000f46a3911fa3c0805444483337064                  1                  0
# 0000f6ccb0745a6a4b88665a16c9f078                  0                  0
# 0004aac84e0df4da2b147fca70cf8255                  0                  0
# ...                                             ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  0                  0
# fffea47cd6d3cc0a88bd621562a9d061                  0                  0
# ffff371b4d645b6ecea244b27531430a                  0                  0
# ffff5962728ec6157033ef9805bacc48                  0                  0
# ffffd2657e2aad2907e67c3e9daecbeb                  0                  0
#
#                                   customer_state_SP  customer_state_TO
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                  1                  0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                  1                  0
# 0000f46a3911fa3c0805444483337064                  0                  0
# 0000f6ccb0745a6a4b88665a16c9f078                  0                  0
# 0004aac84e0df4da2b147fca70cf8255                  1                  0
# ...                                             ...                ...
# fffcf5a5ff07b0908bd4e2dbc735a684                  0                  0
# fffea47cd6d3cc0a88bd621562a9d061                  0                  0
# ffff371b4d645b6ecea244b27531430a                  0                  0
# ffff5962728ec6157033ef9805bacc48                  0                  0
# ffffd2657e2aad2907e67c3e9daecbeb                  0                  0
#
# [96096 rows x 121 columns]

# %%
df.isna().sum()
# Out:
# order_id                0
# payment_value           0
# payment_installments    0
# review_score            0
# price                   0
#                        ..
# customer_state_RS       0
# customer_state_SC       0
# customer_state_SE       0
# customer_state_SP       0
# customer_state_TO       0
# Length: 121, dtype: int64

# %% [markdown]
# ## Standard Scaler

# %%
df = df.sample(frac=0.1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(df)
print('Mean:', scaler.mean_)
print('Std:', np.sqrt(scaler.var_))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-96c225c9b9c9> in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler = StandardScaler()
# ----> 3 X = scaler.fit_transform(df)
#       4 print('Mean:', scaler.mean_)
#       5 print('Std:', np.sqrt(scaler.var_))
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     551         if y is None:
#     552             # fit method of arity 1 (unsupervised transformation)
# --> 553             return self.fit(X, **fit_params).transform(X)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     637         # Reset internal state before fitting
#     638         self._reset()
# --> 639         return self.partial_fit(X, y)
#     640
#     641     def partial_fit(self, X, y=None):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in partial_fit(self, X, y)
#     661         X = check_array(X, accept_sparse=('csr', 'csc'), copy=self.copy,
#     662                         estimator=self, dtype=FLOAT_DTYPES,
# --> 663                         force_all_finite='allow-nan')
#     664
#     665         # Even in the case of `with_mean=False`, we update the mean anyway
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
# --> 542                                allow_nan=force_all_finite == 'allow-nan')
#     543
#     544     if ensure_min_samples > 0:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains infinity or a value too large for dtype('float64').

# %%
df.shape
# Out:
# (96096, 121)

# %% [markdown]
# # K-means Clustering

# %% [markdown]
# ## Standard Scaler

# %%
df = df.sample(frac=0.1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(df)
print('Mean:', scaler.mean_)
print('Std:', np.sqrt(scaler.var_))
# Out:
# Mean: [1.23038502e+00 2.13625923e+02 2.91337569e+00 4.07449129e+00
#  1.27455007e+02 2.02440125e+01 4.88993633e+01 8.01705066e+02
#  2.27304458e+00 3.02402654e+01 1.65097734e+01 2.28969678e+01
#  1.15682738e-01 4.17912370e-01 2.87679501e+02 1.96670135e-01
#  7.69510926e-01 1.58168574e-02 0.00000000e+00 1.80020812e-02
#  2.08116545e-03 3.32986472e-03 2.60145682e-03 2.70551509e-03
#  2.08116545e-04 2.08116545e-04 1.14464100e-03 4.37044745e-03
#  4.02705515e-02 2.87200832e-02 3.53798127e-03 8.77211238e-02
#  3.54838710e-02 1.01040583e-01 4.05827263e-03 0.00000000e+00
#  5.61914672e-03 1.04058273e-04 6.24349636e-04 2.91363163e-03
#  9.78147763e-03 6.76378772e-03 1.14464100e-03 2.28928200e-03
#  1.45681582e-03 1.76899063e-03 3.62122789e-02 5.20291363e-04
#  5.72320499e-03 2.18522373e-03 2.55983351e-02 6.65972945e-03
#  7.90842872e-02 1.97710718e-02 1.56087409e-03 4.16233091e-04
#  4.16233091e-04 0.00000000e+00 1.14464100e-03 8.32466181e-04
#  3.57960458e-02 2.08116545e-04 3.12174818e-04 1.66493236e-03
#  6.42039542e-02 7.28407908e-03 1.04058273e-04 4.16233091e-04
#  6.24349636e-03 3.74609781e-03 1.07180021e-02 1.97710718e-03
#  1.04058273e-04 3.01768991e-03 6.16024974e-02 1.27991675e-02
#  7.28407908e-04 3.32986472e-03 3.12174818e-04 1.47762747e-02
#  2.20603538e-02 1.04058273e-04 1.97710718e-03 3.22580645e-02
#  1.72736733e-02 4.16233091e-04 3.12174818e-04 5.92091571e-02
#  0.00000000e+00 9.36524454e-04 5.20291363e-04 4.29760666e-02
#  2.80957336e-03 5.97294485e-02 8.32466181e-04 4.89073881e-03
#  1.14464100e-03 5.20291363e-04 3.43392300e-02 1.46722164e-02
#  2.32049948e-02 2.02913632e-02 1.82101977e-02 7.18002081e-03
#  1.16441207e-01 6.65972945e-03 8.11654527e-03 9.78147763e-03
#  5.51508845e-03 1.67533819e-02 5.41103018e-03 5.09885536e-02
#  1.27471384e-01 3.95421436e-03 3.43392300e-03 7.28407908e-04
#  5.46305931e-02 3.34027055e-02 3.12174818e-03 4.25390219e-01
#  2.91363163e-03]
# Std: [7.60218462e-01 5.25221668e+02 2.70455225e+00 1.34204713e+00
#  1.91217058e+02 1.67662228e+01 9.78344706e+00 6.55848075e+02
#  1.76424851e+00 1.61508798e+01 1.30350436e+01 1.14356400e+01
#  3.18380888e-01 4.91450654e-01 1.53649768e+02 3.97480809e-01
#  4.21145890e-01 1.24766520e-01 0.00000000e+00 1.32958664e-01
#  4.55722964e-02 5.76088251e-02 5.09380922e-02 5.19441554e-02
#  1.44247438e-02 1.44247438e-02 3.38131749e-02 6.59647379e-02
#  1.96593068e-01 1.67018682e-01 5.93756175e-02 2.82888897e-01
#  1.84999367e-01 3.01382454e-01 6.35751764e-02 0.00000000e+00
#  7.47500630e-02 1.02003649e-02 2.49791878e-02 5.38993728e-02
#  9.84164637e-02 8.19636438e-02 3.38131749e-02 4.77916435e-02
#  3.81404445e-02 4.20221526e-02 1.86817959e-01 2.28039615e-02
#  7.54350709e-02 4.66952730e-02 1.57933721e-01 8.13349707e-02
#  2.69870270e-01 1.39212702e-01 3.94770536e-02 2.03975450e-02
#  2.03975450e-02 0.00000000e+00 3.38131749e-02 2.88404782e-02
#  1.85781293e-01 1.44247438e-02 1.76657116e-02 4.07696010e-02
#  2.45115904e-01 8.50354119e-02 1.02003649e-02 2.03975450e-02
#  7.87687445e-02 6.10906258e-02 1.02971484e-01 4.44206959e-02
#  1.02003649e-02 5.48505556e-02 2.40432173e-01 1.12407068e-01
#  2.69792018e-02 5.76088251e-02 1.76657116e-02 1.20656274e-01
#  1.46879864e-01 1.02003649e-02 4.44206959e-02 1.76684696e-01
#  1.30289268e-01 2.03975450e-02 1.76657116e-02 2.36015747e-01
#  0.00000000e+00 3.05883536e-02 2.28039615e-02 2.02803166e-01
#  5.29308951e-02 2.36984897e-01 2.88404782e-02 6.97625938e-02
#  3.38131749e-02 2.28039615e-02 1.82099004e-01 1.20237026e-01
#  1.50554053e-01 1.40995120e-01 1.33710831e-01 8.44302559e-02
#  3.20753258e-01 8.13349707e-02 8.97255090e-02 9.84164637e-02
#  7.40585731e-02 1.28346040e-01 7.33604180e-02 2.19974364e-01
#  3.33500270e-01 6.27580955e-02 5.84989843e-02 2.69792018e-02
#  2.27257764e-01 1.79685739e-01 5.57853284e-02 4.94402043e-01
#  5.38993728e-02]

# %%
from sklearn.cluster import KMeans
inertia_dict = {}
for k in range(1,15):
    km = KMeans(n_clusters=k).fit(X)
    inertia_dict[k] = km.inertia_
    
plt.scatter(inertia_dict.keys(), inertia_dict.values())
plt.xlabel('Clusters')
plt.ylabel('Inertia');

# %% [markdown]
# ## Elbow Diagram

# %%
from sklearn.cluster import KMeans
inertia_dict = {}
for k in range(1,15):
    km = KMeans(n_clusters=k).fit(X)
    inertia_dict[k] = km.inertia_
    
plt.scatter(inertia_dict.keys(), inertia_dict.values())
plt.xlabel('Clusters')
plt.ylabel('Inertia');

# %%
# principle component analysis
from sklearn.decomposition import PCA
n_components = 121
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X)

plt.plot(range(1,n_components+1), pca.explained_variance_ratio_.cumsum(),marker='.');
plt.xlabel('Number of PCs')
plt.ylabel('Proportion of Variance Explained')
# Out:
# Text(0, 0.5, 'Proportion of Variance Explained')

# %%
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X)
inertia_dict = {}
for k in range(1,15):
    km = KMeans(n_clusters=k).fit(X_pca)
    inertia_dict[k] = km.inertia_
    
plt.scatter(inertia_dict.keys(), inertia_dict.values())
plt.xlabel('Clusters')
plt.ylabel('Inertia');

# %%
plt.scatter(X_pca[:,0],X_pca[:,1])

# %% [markdown]
# ## K-means Clusters

# %%
km = KMeans(n_clusters=4).fit(X_pca)
plt.scatter(X_pca[:,1], X_pca[:,2], c=km.labels_)

# %%
np.bincount(km.labels_)
# Out:
# array([2852, 2155, 4126,  477], dtype=int64)

# %%
km.cluster_centers_
# Out:
# array([[ 1.01203949, -0.40051431, -1.20591141],
#        [-1.13482941,  2.33145784,  0.25440853],
#        [-0.6484412 , -1.02714082,  0.50970472],
#        [ 4.68488285,  0.74624355,  1.65192303]])

# %%
from scipy import stats
corr_array=[]
for i in range(df.shape[1]-1):  
    corr_array.append([df.columns[i],
                       np.abs(stats.pearsonr(df[df.columns[i]], X_pca[:,2])[0]),
                       stats.pearsonr(df[df.columns[i]], X_pca[:,2])[0],
                       stats.pearsonr(df[df.columns[i]], X_pca[:,2])[1]])
    
corr_df = pd.DataFrame(corr_array, columns = ['feature', 'abs_corr', 'corr', 'p_value'])
corr_df.sort_values(by='abs_corr', ascending=False, inplace=True)
corr_df.reset_index(drop=True, inplace=True)
corr_df
# Out:
#                                                feature  abs_corr      corr  \
# 0                                     product_width_cm  0.449837 -0.449837
# 1                                                price  0.448949  0.448949
# 2                                    product_length_cm  0.419159 -0.419159
# 3                                        payment_value  0.414362  0.414362
# 4                           product_description_lenght  0.359471  0.359471
# ..                                                 ...       ...       ...
# 115            product_category_name_artigos_de_festas  0.000003 -0.000003
# 116                           payment_type_not_defined       NaN       NaN
# 117              product_category_name_casa_conforto_2       NaN       NaN
# 118  product_category_name_fashion_roupa_infanto_ju...       NaN       NaN
# 119           product_category_name_seguros_e_servicos       NaN       NaN
#
#            p_value
# 0     0.000000e+00
# 1     0.000000e+00
# 2     0.000000e+00
# 3     0.000000e+00
# 4    4.744925e-291
# ..             ...
# 115   9.998032e-01
# 116            NaN
# 117            NaN
# 118            NaN
# 119            NaN
#
# [120 rows x 4 columns]

# %%
for i in [0]:
    X=df
    y=X_pca[:,i]

    # scale data with standard scaler
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    X = pd.DataFrame(data=scaler.fit_transform(X), columns=X.columns)

    # fit logit function 
    import statsmodels.api as sm
    X_withconstant = sm.add_constant(X)
    logit = sm.OLS(y, X_withconstant).fit()
    display(logit.summary()) 

    # table of significant coefficinets sorted by absolute value
    coef_table = logit.summary().tables[1]
    coef_df = pd.DataFrame(data=coef_table.data[1:], columns=coef_table.data[0])
    coef_df['coef'] = coef_df['coef'].astype(float)
    coef_df['P>|t|'] = coef_df['P>|t|'].astype(float)
    coef_df['abs_coef'] = np.abs(coef_df['coef'])
    coef_df.drop(0, axis='index', inplace=True)
    coefs_by_mag = coef_df.sort_values(by='abs_coef', ascending=False)
    coefs_by_mag = coefs_by_mag[coefs_by_mag['P>|t|'] <= 0.05]
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.709e+31
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):               0.00
# Time:                        12:21:22   Log-Likelihood:             3.1032e+05
# No. Observations:                9610   AIC:                        -6.204e+05
# Df Residuals:                    9495   BIC:                        -6.196e+05
# Df Model:                         114
# Covariance Type:            nonrobust
# ========================================================================================================================================
#                                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 3.656e-16   2.35e-17     15.563      0.000     3.2e-16    4.12e-16
# order_id                                                                 0.0467   2.93e-17   1.59e+15      0.000       0.047       0.047
# payment_value                                                            0.2436   3.21e-17    7.6e+15      0.000       0.244       0.244
# payment_installments                                                     0.3065   2.79e-17    1.1e+16      0.000       0.307       0.307
# review_score                                                            -0.0524   2.49e-17   -2.1e+15      0.000      -0.052      -0.052
# price                                                                    0.3467   3.33e-17   1.04e+16      0.000       0.347       0.347
# freight_value                                                            0.3950   3.22e-17   1.23e+16      0.000       0.395       0.395
# product_name_lenght                                                      0.0434   2.48e-17   1.75e+15      0.000       0.043       0.043
# product_description_lenght                                               0.0737   2.65e-17   2.78e+15      0.000       0.074       0.074
# product_photos_qty                                                       0.0251   2.57e-17   9.79e+14      0.000       0.025       0.025
# product_length_cm                                                        0.3323   3.09e-17   1.07e+16      0.000       0.332       0.332
# product_height_cm                                                        0.3258   2.98e-17   1.09e+16      0.000       0.326       0.326
# product_width_cm                                                         0.3658   3.22e-17   1.14e+16      0.000       0.366       0.366
# review_comment_title                                                     0.0308   2.78e-17   1.11e+15      0.000       0.031       0.031
# review_comment_message                                                   0.0500   2.66e-17   1.88e+15      0.000       0.050       0.050
# order_purchase_timestamp                                                 0.0148   2.69e-17   5.52e+14      0.000       0.015       0.015
# payment_type_boleto                                                     -0.1632   1.48e-17   -1.1e+16      0.000      -0.163      -0.163
# payment_type_credit_card                                                 0.1813   1.34e-17   1.35e+16      0.000       0.181       0.181
# payment_type_debit_card                                                 -0.0412   2.28e-17   -1.8e+15      0.000      -0.041      -0.041
# payment_type_not_defined                                              1.889e-19   3.12e-32   6.05e+12      0.000    1.89e-19    1.89e-19
# payment_type_voucher                                                    -0.0476   2.32e-17  -2.05e+15      0.000      -0.048      -0.048
# product_category_name_agro_industria_e_comercio                          0.0332   2.37e-17    1.4e+15      0.000       0.033       0.033
# product_category_name_alimentos                                         -0.0298   2.36e-17  -1.27e+15      0.000      -0.030      -0.030
# product_category_name_alimentos_bebidas                                 -0.0199   2.36e-17  -8.45e+14      0.000      -0.020      -0.020
# product_category_name_artes                                              0.0113   2.36e-17   4.78e+14      0.000       0.011       0.011
# product_category_name_artes_e_artesanato                                -0.0067   2.35e-17  -2.85e+14      0.000      -0.007      -0.007
# product_category_name_artigos_de_festas                                 -0.0089   2.35e-17  -3.79e+14      0.000      -0.009      -0.009
# product_category_name_artigos_de_natal                                  -0.0086   2.35e-17  -3.66e+14      0.000      -0.009      -0.009
# product_category_name_audio                                             -0.0336   2.35e-17  -1.43e+15      0.000      -0.034      -0.034
# product_category_name_automotivo                                         0.0231   2.27e-17   1.02e+15      0.000       0.023       0.023
# product_category_name_bebes                                              0.0467   2.31e-17   2.02e+15      0.000       0.047       0.047
# product_category_name_bebidas                                           -0.0190   2.35e-17  -8.09e+14      0.000      -0.019      -0.019
# product_category_name_beleza_saude                                      -0.0495   2.24e-17  -2.21e+15      0.000      -0.050      -0.050
# product_category_name_brinquedos                                         0.0236    2.3e-17   1.03e+15      0.000       0.024       0.024
# product_category_name_cama_mesa_banho                                    0.0455   2.32e-17   1.96e+15      0.000       0.045       0.045
# product_category_name_casa_conforto                                      0.0261   2.36e-17   1.11e+15      0.000       0.026       0.026
# product_category_name_casa_conforto_2                                -1.745e-19   2.27e-32  -7.68e+12      0.000   -1.74e-19   -1.74e-19
# product_category_name_casa_construcao                                    0.0309   2.35e-17   1.31e+15      0.000       0.031       0.031
# product_category_name_cds_dvds_musicais                                  0.0003   2.35e-17   1.32e+13      0.000       0.000       0.000
# product_category_name_cine_foto                                          0.0113   2.35e-17   4.82e+14      0.000       0.011       0.011
# product_category_name_climatizacao                                       0.0215   2.35e-17   9.16e+14      0.000       0.022       0.022
# product_category_name_consoles_games                                    -0.0405   2.35e-17  -1.73e+15      0.000      -0.041      -0.041
# product_category_name_construcao_ferramentas_construcao                  0.0273   2.35e-17   1.16e+15      0.000       0.027       0.027
# product_category_name_construcao_ferramentas_ferramentas                -0.0145   2.35e-17  -6.17e+14      0.000      -0.015      -0.015
# product_category_name_construcao_ferramentas_iluminacao                  0.0018   2.35e-17   7.74e+13      0.000       0.002       0.002
# product_category_name_construcao_ferramentas_jardim                      0.0055   2.35e-17   2.33e+14      0.000       0.005       0.005
# product_category_name_construcao_ferramentas_seguranca                  -0.0046   2.35e-17  -1.95e+14      0.000      -0.005      -0.005
# product_category_name_cool_stuff                                         0.0540   2.29e-17   2.36e+15      0.000       0.054       0.054
# product_category_name_dvds_blu_ray                                      -0.0150   2.35e-17  -6.36e+14      0.000      -0.015      -0.015
# product_category_name_eletrodomesticos                                  -0.0068   2.34e-17  -2.92e+14      0.000      -0.007      -0.007
# product_category_name_eletrodomesticos_2                                 0.0530   2.36e-17   2.25e+15      0.000       0.053       0.053
# product_category_name_eletronicos                                       -0.0821   2.32e-17  -3.54e+15      0.000      -0.082      -0.082
# product_category_name_eletroportateis                                    0.0253   2.35e-17   1.08e+15      0.000       0.025       0.025
# product_category_name_esporte_lazer                                     -0.0211   2.23e-17  -9.46e+14      0.000      -0.021      -0.021
# product_category_name_fashion_bolsas_e_acessorios                       -0.0719   2.37e-17  -3.03e+15      0.000      -0.072      -0.072
# product_category_name_fashion_calcados                                  -0.0027   2.37e-17  -1.15e+14      0.000      -0.003      -0.003
# product_category_name_fashion_esporte                                   -0.0085   2.36e-17  -3.62e+14      0.000      -0.009      -0.009
# product_category_name_fashion_roupa_feminina                            -0.0083   2.35e-17  -3.54e+14      0.000      -0.008      -0.008
# product_category_name_fashion_roupa_infanto_juvenil                  -3.417e-19   2.63e-32   -1.3e+13      0.000   -3.42e-19   -3.42e-19
# product_category_name_fashion_roupa_masculina                            0.0018   2.35e-17   7.53e+13      0.000       0.002       0.002
# product_category_name_fashion_underwear_e_moda_praia                    -0.0179   2.35e-17   -7.6e+14      0.000      -0.018      -0.018
# product_category_name_ferramentas_jardim                                 0.0324   2.29e-17   1.41e+15      0.000       0.032       0.032
# product_category_name_flores                                            -0.0053   2.35e-17  -2.27e+14      0.000      -0.005      -0.005
# product_category_name_fraldas_higiene                                   -0.0047   2.35e-17  -1.99e+14      0.000      -0.005      -0.005
# product_category_name_industria_comercio_e_negocios                      0.0262   2.37e-17   1.11e+15      0.000       0.026       0.026
# product_category_name_informatica_acessorios                            -0.0810   2.26e-17  -3.59e+15      0.000      -0.081      -0.081
# product_category_name_instrumentos_musicais                              0.0468   2.35e-17   1.99e+15      0.000       0.047       0.047
# product_category_name_la_cuisine                                         0.0090   2.35e-17   3.83e+14      0.000       0.009       0.009
# product_category_name_livros_importados                                 -0.0120   2.35e-17  -5.11e+14      0.000      -0.012      -0.012
# product_category_name_livros_interesse_geral                            -0.0336   2.35e-17  -1.43e+15      0.000      -0.034      -0.034
# product_category_name_livros_tecnicos                                   -0.0251   2.36e-17  -1.06e+15      0.000      -0.025      -0.025
# product_category_name_malas_acessorios                                   0.0787   2.38e-17    3.3e+15      0.000       0.079       0.079
# product_category_name_market_place                                      -0.0134   2.35e-17  -5.69e+14      0.000      -0.013      -0.013
# product_category_name_moveis_colchao_e_estofado                          0.0168   2.36e-17   7.11e+14      0.000       0.017       0.017
# product_category_name_moveis_cozinha_area_de_servico_jantar_e_jardim     0.0451   2.36e-17   1.91e+15      0.000       0.045       0.045
# product_category_name_moveis_decoracao                                   0.0422   2.28e-17   1.85e+15      0.000       0.042       0.042
# product_category_name_moveis_escritorio                                  0.1380   2.49e-17   5.53e+15      0.000       0.138       0.138
# product_category_name_moveis_quarto                                      0.0310   2.36e-17   1.32e+15      0.000       0.031       0.031
# product_category_name_moveis_sala                                        0.0397   2.37e-17   1.68e+15      0.000       0.040       0.040
# product_category_name_musica                                             0.0098   2.35e-17   4.14e+14      0.000       0.010       0.010
# product_category_name_other                                             -0.0171   2.33e-17  -7.31e+14      0.000      -0.017      -0.017
# product_category_name_papelaria                                          0.0226   2.35e-17   9.63e+14      0.000       0.023       0.023
# product_category_name_pc_gamer                                          -0.0043   2.35e-17  -1.84e+14      0.000      -0.004      -0.004
# product_category_name_pcs                                                0.1058   2.45e-17   4.31e+15      0.000       0.106       0.106
# product_category_name_perfumaria                                        -0.0577   2.31e-17  -2.49e+15      0.000      -0.058      -0.058
# product_category_name_pet_shop                                           0.0155   2.32e-17   6.67e+14      0.000       0.015       0.015
# product_category_name_portateis_casa_forno_e_cafe                        0.0292   2.36e-17   1.24e+15      0.000       0.029       0.029
# product_category_name_portateis_cozinha_e_preparadores_de_alimentos      0.0108   2.36e-17   4.58e+14      0.000       0.011       0.011
# product_category_name_relogios_presentes                                -0.0474   2.37e-17     -2e+15      0.000      -0.047      -0.047
# product_category_name_seguros_e_servicos                              1.983e-20   1.58e-32   1.26e+12      0.000    1.98e-20    1.98e-20
# product_category_name_sinalizacao_e_seguranca                            0.0032   2.35e-17   1.37e+14      0.000       0.003       0.003
# product_category_name_tablets_impressao_imagem                          -0.0036   2.36e-17  -1.55e+14      0.000      -0.004      -0.004
# product_category_name_telefonia                                         -0.1211   2.36e-17  -5.13e+15      0.000      -0.121      -0.121
# product_category_name_telefonia_fixa                                     0.0091   2.38e-17   3.83e+14      0.000       0.009       0.009
# product_category_name_utilidades_domesticas                              0.0486   2.26e-17   2.15e+15      0.000       0.049       0.049
# customer_state_AC                                                        0.0025   2.36e-17   1.05e+14      0.000       0.002       0.002
# customer_state_AL                                                        0.0326   2.36e-17   1.38e+15      0.000       0.033       0.033
# customer_state_AM                                                       -0.0018   2.35e-17  -7.62e+13      0.000      -0.002      -0.002
# customer_state_AP                                                       -0.0060   2.36e-17  -2.56e+14      0.000      -0.006      -0.006
# customer_state_BA                                                        0.0230   2.27e-17   1.01e+15      0.000       0.023       0.023
# customer_state_CE                                                        0.0247   2.33e-17   1.06e+15      0.000       0.025       0.025
# customer_state_DF                                                       -0.0182   2.29e-17  -7.93e+14      0.000      -0.018      -0.018
# customer_state_ES                                                        0.0240   2.31e-17   1.04e+15      0.000       0.024       0.024
# customer_state_GO                                                        0.0165   2.31e-17   7.16e+14      0.000       0.017       0.017
# customer_state_MA                                                        0.0282   2.36e-17   1.19e+15      0.000       0.028       0.028
# customer_state_MG                                                        0.0107   2.06e-17   5.22e+14      0.000       0.011       0.011
# customer_state_MS                                                        0.0094   2.34e-17   4.03e+14      0.000       0.009       0.009
# customer_state_MT                                                        0.0200   2.34e-17   8.53e+14      0.000       0.020       0.020
# customer_state_PA                                                        0.0129   2.35e-17   5.51e+14      0.000       0.013       0.013
# customer_state_PB                                                        0.0374   2.36e-17   1.59e+15      0.000       0.037       0.037
# customer_state_PE                                                        0.0252   2.33e-17   1.08e+15      0.000       0.025       0.025
# customer_state_PI                                                        0.0100   2.35e-17   4.26e+14      0.000       0.010       0.010
# customer_state_PR                                                        0.0073   2.22e-17    3.3e+14      0.000       0.007       0.007
# customer_state_RJ                                                        0.0462   2.04e-17   2.27e+15      0.000       0.046       0.046
# customer_state_RN                                                        0.0199   2.36e-17   8.43e+14      0.000       0.020       0.020
# customer_state_RO                                                        0.0426   2.37e-17    1.8e+15      0.000       0.043       0.043
# customer_state_RR                                                        0.0180   2.35e-17   7.67e+14      0.000       0.018       0.018
# customer_state_RS                                                        0.0078   2.21e-17   3.51e+14      0.000       0.008       0.008
# customer_state_SC                                                       -0.0007   2.27e-17  -3.04e+13      0.000      -0.001      -0.001
# customer_state_SE                                                        0.0103   2.35e-17   4.39e+14      0.000       0.010       0.010
# customer_state_SP                                                       -0.1057   1.71e-17  -6.17e+15      0.000      -0.106      -0.106
# customer_state_TO                                                        0.0048   2.36e-17   2.05e+14      0.000       0.005       0.005
# ==============================================================================
# Omnibus:                     4638.214   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           131418.596
# Skew:                          -1.735   Prob(JB):                         0.00
# Kurtosis:                      20.781   Cond. No.                     2.03e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.94e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
for i in range(3):
    X=df
    y=X_pca[:,i]

    # scale data with standard scaler
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    X = pd.DataFrame(data=scaler.fit_transform(X), columns=X.columns)

    # fit logit function 
    import statsmodels.api as sm
    X_withconstant = sm.add_constant(X)
    logit = sm.OLS(y, X_withconstant).fit()
    #display(logit.summary()) 

    # table of significant coefficinets sorted by absolute value
    coef_table = logit.summary().tables[1]
    coef_df = pd.DataFrame(data=coef_table.data[1:], columns=coef_table.data[0])
    coef_df['coef'] = coef_df['coef'].astype(float)
    coef_df['P>|t|'] = coef_df['P>|t|'].astype(float)
    coef_df['abs_coef'] = np.abs(coef_df['coef'])
    coef_df.drop(0, axis='index', inplace=True)
    coefs_by_mag = coef_df.sort_values(by='abs_coef', ascending=False)
    coefs_by_mag = coefs_by_mag[coefs_by_mag['P>|t|'] <= 0.05]

    # bar chart of feature coefficients
    bar_names = coefs_by_mag['']
    bar_heights = coefs_by_mag['coef']
    bar_colors = np.where(bar_heights>0, 'blue', 'red')
    plt.figure(figsize=(5.0, 4.0))
    plt.barh(bar_names, bar_heights, color=bar_colors)
    plt.xlabel('normalized coefficient')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.709e+31
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):               0.00
# Time:                        12:39:39   Log-Likelihood:             3.1032e+05
# No. Observations:                9610   AIC:                        -6.204e+05
# Df Residuals:                    9495   BIC:                        -6.196e+05
# Df Model:                         114
# Covariance Type:            nonrobust
# ========================================================================================================================================
#                                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 3.656e-16   2.35e-17     15.563      0.000     3.2e-16    4.12e-16
# order_id                                                                 0.0467   2.93e-17   1.59e+15      0.000       0.047       0.047
# payment_value                                                            0.2436   3.21e-17    7.6e+15      0.000       0.244       0.244
# payment_installments                                                     0.3065   2.79e-17    1.1e+16      0.000       0.307       0.307
# review_score                                                            -0.0524   2.49e-17   -2.1e+15      0.000      -0.052      -0.052
# price                                                                    0.3467   3.33e-17   1.04e+16      0.000       0.347       0.347
# freight_value                                                            0.3950   3.22e-17   1.23e+16      0.000       0.395       0.395
# product_name_lenght                                                      0.0434   2.48e-17   1.75e+15      0.000       0.043       0.043
# product_description_lenght                                               0.0737   2.65e-17   2.78e+15      0.000       0.074       0.074
# product_photos_qty                                                       0.0251   2.57e-17   9.79e+14      0.000       0.025       0.025
# product_length_cm                                                        0.3323   3.09e-17   1.07e+16      0.000       0.332       0.332
# product_height_cm                                                        0.3258   2.98e-17   1.09e+16      0.000       0.326       0.326
# product_width_cm                                                         0.3658   3.22e-17   1.14e+16      0.000       0.366       0.366
# review_comment_title                                                     0.0308   2.78e-17   1.11e+15      0.000       0.031       0.031
# review_comment_message                                                   0.0500   2.66e-17   1.88e+15      0.000       0.050       0.050
# order_purchase_timestamp                                                 0.0148   2.69e-17   5.52e+14      0.000       0.015       0.015
# payment_type_boleto                                                     -0.1632   1.48e-17   -1.1e+16      0.000      -0.163      -0.163
# payment_type_credit_card                                                 0.1813   1.34e-17   1.35e+16      0.000       0.181       0.181
# payment_type_debit_card                                                 -0.0412   2.28e-17   -1.8e+15      0.000      -0.041      -0.041
# payment_type_not_defined                                              1.889e-19   3.12e-32   6.05e+12      0.000    1.89e-19    1.89e-19
# payment_type_voucher                                                    -0.0476   2.32e-17  -2.05e+15      0.000      -0.048      -0.048
# product_category_name_agro_industria_e_comercio                          0.0332   2.37e-17    1.4e+15      0.000       0.033       0.033
# product_category_name_alimentos                                         -0.0298   2.36e-17  -1.27e+15      0.000      -0.030      -0.030
# product_category_name_alimentos_bebidas                                 -0.0199   2.36e-17  -8.45e+14      0.000      -0.020      -0.020
# product_category_name_artes                                              0.0113   2.36e-17   4.78e+14      0.000       0.011       0.011
# product_category_name_artes_e_artesanato                                -0.0067   2.35e-17  -2.85e+14      0.000      -0.007      -0.007
# product_category_name_artigos_de_festas                                 -0.0089   2.35e-17  -3.79e+14      0.000      -0.009      -0.009
# product_category_name_artigos_de_natal                                  -0.0086   2.35e-17  -3.66e+14      0.000      -0.009      -0.009
# product_category_name_audio                                             -0.0336   2.35e-17  -1.43e+15      0.000      -0.034      -0.034
# product_category_name_automotivo                                         0.0231   2.27e-17   1.02e+15      0.000       0.023       0.023
# product_category_name_bebes                                              0.0467   2.31e-17   2.02e+15      0.000       0.047       0.047
# product_category_name_bebidas                                           -0.0190   2.35e-17  -8.09e+14      0.000      -0.019      -0.019
# product_category_name_beleza_saude                                      -0.0495   2.24e-17  -2.21e+15      0.000      -0.050      -0.050
# product_category_name_brinquedos                                         0.0236    2.3e-17   1.03e+15      0.000       0.024       0.024
# product_category_name_cama_mesa_banho                                    0.0455   2.32e-17   1.96e+15      0.000       0.045       0.045
# product_category_name_casa_conforto                                      0.0261   2.36e-17   1.11e+15      0.000       0.026       0.026
# product_category_name_casa_conforto_2                                -1.745e-19   2.27e-32  -7.68e+12      0.000   -1.74e-19   -1.74e-19
# product_category_name_casa_construcao                                    0.0309   2.35e-17   1.31e+15      0.000       0.031       0.031
# product_category_name_cds_dvds_musicais                                  0.0003   2.35e-17   1.32e+13      0.000       0.000       0.000
# product_category_name_cine_foto                                          0.0113   2.35e-17   4.82e+14      0.000       0.011       0.011
# product_category_name_climatizacao                                       0.0215   2.35e-17   9.16e+14      0.000       0.022       0.022
# product_category_name_consoles_games                                    -0.0405   2.35e-17  -1.73e+15      0.000      -0.041      -0.041
# product_category_name_construcao_ferramentas_construcao                  0.0273   2.35e-17   1.16e+15      0.000       0.027       0.027
# product_category_name_construcao_ferramentas_ferramentas                -0.0145   2.35e-17  -6.17e+14      0.000      -0.015      -0.015
# product_category_name_construcao_ferramentas_iluminacao                  0.0018   2.35e-17   7.74e+13      0.000       0.002       0.002
# product_category_name_construcao_ferramentas_jardim                      0.0055   2.35e-17   2.33e+14      0.000       0.005       0.005
# product_category_name_construcao_ferramentas_seguranca                  -0.0046   2.35e-17  -1.95e+14      0.000      -0.005      -0.005
# product_category_name_cool_stuff                                         0.0540   2.29e-17   2.36e+15      0.000       0.054       0.054
# product_category_name_dvds_blu_ray                                      -0.0150   2.35e-17  -6.36e+14      0.000      -0.015      -0.015
# product_category_name_eletrodomesticos                                  -0.0068   2.34e-17  -2.92e+14      0.000      -0.007      -0.007
# product_category_name_eletrodomesticos_2                                 0.0530   2.36e-17   2.25e+15      0.000       0.053       0.053
# product_category_name_eletronicos                                       -0.0821   2.32e-17  -3.54e+15      0.000      -0.082      -0.082
# product_category_name_eletroportateis                                    0.0253   2.35e-17   1.08e+15      0.000       0.025       0.025
# product_category_name_esporte_lazer                                     -0.0211   2.23e-17  -9.46e+14      0.000      -0.021      -0.021
# product_category_name_fashion_bolsas_e_acessorios                       -0.0719   2.37e-17  -3.03e+15      0.000      -0.072      -0.072
# product_category_name_fashion_calcados                                  -0.0027   2.37e-17  -1.15e+14      0.000      -0.003      -0.003
# product_category_name_fashion_esporte                                   -0.0085   2.36e-17  -3.62e+14      0.000      -0.009      -0.009
# product_category_name_fashion_roupa_feminina                            -0.0083   2.35e-17  -3.54e+14      0.000      -0.008      -0.008
# product_category_name_fashion_roupa_infanto_juvenil                  -3.417e-19   2.63e-32   -1.3e+13      0.000   -3.42e-19   -3.42e-19
# product_category_name_fashion_roupa_masculina                            0.0018   2.35e-17   7.53e+13      0.000       0.002       0.002
# product_category_name_fashion_underwear_e_moda_praia                    -0.0179   2.35e-17   -7.6e+14      0.000      -0.018      -0.018
# product_category_name_ferramentas_jardim                                 0.0324   2.29e-17   1.41e+15      0.000       0.032       0.032
# product_category_name_flores                                            -0.0053   2.35e-17  -2.27e+14      0.000      -0.005      -0.005
# product_category_name_fraldas_higiene                                   -0.0047   2.35e-17  -1.99e+14      0.000      -0.005      -0.005
# product_category_name_industria_comercio_e_negocios                      0.0262   2.37e-17   1.11e+15      0.000       0.026       0.026
# product_category_name_informatica_acessorios                            -0.0810   2.26e-17  -3.59e+15      0.000      -0.081      -0.081
# product_category_name_instrumentos_musicais                              0.0468   2.35e-17   1.99e+15      0.000       0.047       0.047
# product_category_name_la_cuisine                                         0.0090   2.35e-17   3.83e+14      0.000       0.009       0.009
# product_category_name_livros_importados                                 -0.0120   2.35e-17  -5.11e+14      0.000      -0.012      -0.012
# product_category_name_livros_interesse_geral                            -0.0336   2.35e-17  -1.43e+15      0.000      -0.034      -0.034
# product_category_name_livros_tecnicos                                   -0.0251   2.36e-17  -1.06e+15      0.000      -0.025      -0.025
# product_category_name_malas_acessorios                                   0.0787   2.38e-17    3.3e+15      0.000       0.079       0.079
# product_category_name_market_place                                      -0.0134   2.35e-17  -5.69e+14      0.000      -0.013      -0.013
# product_category_name_moveis_colchao_e_estofado                          0.0168   2.36e-17   7.11e+14      0.000       0.017       0.017
# product_category_name_moveis_cozinha_area_de_servico_jantar_e_jardim     0.0451   2.36e-17   1.91e+15      0.000       0.045       0.045
# product_category_name_moveis_decoracao                                   0.0422   2.28e-17   1.85e+15      0.000       0.042       0.042
# product_category_name_moveis_escritorio                                  0.1380   2.49e-17   5.53e+15      0.000       0.138       0.138
# product_category_name_moveis_quarto                                      0.0310   2.36e-17   1.32e+15      0.000       0.031       0.031
# product_category_name_moveis_sala                                        0.0397   2.37e-17   1.68e+15      0.000       0.040       0.040
# product_category_name_musica                                             0.0098   2.35e-17   4.14e+14      0.000       0.010       0.010
# product_category_name_other                                             -0.0171   2.33e-17  -7.31e+14      0.000      -0.017      -0.017
# product_category_name_papelaria                                          0.0226   2.35e-17   9.63e+14      0.000       0.023       0.023
# product_category_name_pc_gamer                                          -0.0043   2.35e-17  -1.84e+14      0.000      -0.004      -0.004
# product_category_name_pcs                                                0.1058   2.45e-17   4.31e+15      0.000       0.106       0.106
# product_category_name_perfumaria                                        -0.0577   2.31e-17  -2.49e+15      0.000      -0.058      -0.058
# product_category_name_pet_shop                                           0.0155   2.32e-17   6.67e+14      0.000       0.015       0.015
# product_category_name_portateis_casa_forno_e_cafe                        0.0292   2.36e-17   1.24e+15      0.000       0.029       0.029
# product_category_name_portateis_cozinha_e_preparadores_de_alimentos      0.0108   2.36e-17   4.58e+14      0.000       0.011       0.011
# product_category_name_relogios_presentes                                -0.0474   2.37e-17     -2e+15      0.000      -0.047      -0.047
# product_category_name_seguros_e_servicos                              1.983e-20   1.58e-32   1.26e+12      0.000    1.98e-20    1.98e-20
# product_category_name_sinalizacao_e_seguranca                            0.0032   2.35e-17   1.37e+14      0.000       0.003       0.003
# product_category_name_tablets_impressao_imagem                          -0.0036   2.36e-17  -1.55e+14      0.000      -0.004      -0.004
# product_category_name_telefonia                                         -0.1211   2.36e-17  -5.13e+15      0.000      -0.121      -0.121
# product_category_name_telefonia_fixa                                     0.0091   2.38e-17   3.83e+14      0.000       0.009       0.009
# product_category_name_utilidades_domesticas                              0.0486   2.26e-17   2.15e+15      0.000       0.049       0.049
# customer_state_AC                                                        0.0025   2.36e-17   1.05e+14      0.000       0.002       0.002
# customer_state_AL                                                        0.0326   2.36e-17   1.38e+15      0.000       0.033       0.033
# customer_state_AM                                                       -0.0018   2.35e-17  -7.62e+13      0.000      -0.002      -0.002
# customer_state_AP                                                       -0.0060   2.36e-17  -2.56e+14      0.000      -0.006      -0.006
# customer_state_BA                                                        0.0230   2.27e-17   1.01e+15      0.000       0.023       0.023
# customer_state_CE                                                        0.0247   2.33e-17   1.06e+15      0.000       0.025       0.025
# customer_state_DF                                                       -0.0182   2.29e-17  -7.93e+14      0.000      -0.018      -0.018
# customer_state_ES                                                        0.0240   2.31e-17   1.04e+15      0.000       0.024       0.024
# customer_state_GO                                                        0.0165   2.31e-17   7.16e+14      0.000       0.017       0.017
# customer_state_MA                                                        0.0282   2.36e-17   1.19e+15      0.000       0.028       0.028
# customer_state_MG                                                        0.0107   2.06e-17   5.22e+14      0.000       0.011       0.011
# customer_state_MS                                                        0.0094   2.34e-17   4.03e+14      0.000       0.009       0.009
# customer_state_MT                                                        0.0200   2.34e-17   8.53e+14      0.000       0.020       0.020
# customer_state_PA                                                        0.0129   2.35e-17   5.51e+14      0.000       0.013       0.013
# customer_state_PB                                                        0.0374   2.36e-17   1.59e+15      0.000       0.037       0.037
# customer_state_PE                                                        0.0252   2.33e-17   1.08e+15      0.000       0.025       0.025
# customer_state_PI                                                        0.0100   2.35e-17   4.26e+14      0.000       0.010       0.010
# customer_state_PR                                                        0.0073   2.22e-17    3.3e+14      0.000       0.007       0.007
# customer_state_RJ                                                        0.0462   2.04e-17   2.27e+15      0.000       0.046       0.046
# customer_state_RN                                                        0.0199   2.36e-17   8.43e+14      0.000       0.020       0.020
# customer_state_RO                                                        0.0426   2.37e-17    1.8e+15      0.000       0.043       0.043
# customer_state_RR                                                        0.0180   2.35e-17   7.67e+14      0.000       0.018       0.018
# customer_state_RS                                                        0.0078   2.21e-17   3.51e+14      0.000       0.008       0.008
# customer_state_SC                                                       -0.0007   2.27e-17  -3.04e+13      0.000      -0.001      -0.001
# customer_state_SE                                                        0.0103   2.35e-17   4.39e+14      0.000       0.010       0.010
# customer_state_SP                                                       -0.1057   1.71e-17  -6.17e+15      0.000      -0.106      -0.106
# customer_state_TO                                                        0.0048   2.36e-17   2.05e+14      0.000       0.005       0.005
# ==============================================================================
# Omnibus:                     4638.214   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           131418.596
# Skew:                          -1.735   Prob(JB):                         0.00
# Kurtosis:                      20.781   Cond. No.                     2.03e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.94e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)

# %%
plt.scatter(X_tsne[:,0], X_tsne[:,1], c=km.labels_)
plt.xlabel('TSNE 1')
plt.ylabel('TSNE 2')
# Out:
# Text(0, 0.5, 'TSNE 2')

# %%
for i in [0]:
    X=df
    y=X_tsne[:,i]

    # scale data with standard scaler
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    X = pd.DataFrame(data=scaler.fit_transform(X), columns=X.columns)

    # fit logit function 
    import statsmodels.api as sm
    X_withconstant = sm.add_constant(X)
    logit = sm.OLS(y, X_withconstant).fit()
    display(logit.summary()) 

    # table of significant coefficinets sorted by absolute value
    coef_table = logit.summary().tables[1]
    coef_df = pd.DataFrame(data=coef_table.data[1:], columns=coef_table.data[0])
    coef_df['coef'] = coef_df['coef'].astype(float)
    coef_df['P>|t|'] = coef_df['P>|t|'].astype(float)
    coef_df['abs_coef'] = np.abs(coef_df['coef'])
    coef_df.drop(0, axis='index', inplace=True)
    coefs_by_mag = coef_df.sort_values(by='abs_coef', ascending=False)
    coefs_by_mag = coefs_by_mag[coefs_by_mag['P>|t|'] <= 0.05]

    # bar chart of feature coefficients
    bar_names = coefs_by_mag['']
    bar_heights = coefs_by_mag['coef']
    bar_colors = np.where(bar_heights>0, 'blue', 'red')
    plt.figure(figsize=(5.0, 4.0))
    plt.barh(bar_names, bar_heights, color=bar_colors)
    plt.xlabel('normalized coefficient')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.851
# Method:                 Least Squares   F-statistic:                     480.7
# Date:                Fri, 20 Mar 2020   Prob (F-statistic):               0.00
# Time:                        12:40:26   Log-Likelihood:                -40572.
# No. Observations:                9610   AIC:                         8.137e+04
# Df Residuals:                    9495   BIC:                         8.220e+04
# Df Model:                         114
# Covariance Type:            nonrobust
# ========================================================================================================================================
#                                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------
# const                                                                   -0.3392      0.169     -2.004      0.045      -0.671      -0.007
# order_id                                                                -0.0023      0.211     -0.011      0.991      -0.416       0.411
# payment_value                                                           -0.1483      0.231     -0.642      0.521      -0.601       0.305
# payment_installments                                                    -0.1494      0.201     -0.744      0.457      -0.543       0.244
# review_score                                                            -0.1211      0.179     -0.675      0.500      -0.473       0.230
# price                                                                   -0.4244      0.240     -1.771      0.077      -0.894       0.045
# freight_value                                                            0.3457      0.232      1.491      0.136      -0.109       0.800
# product_name_lenght                                                     -0.0624      0.179     -0.349      0.727      -0.413       0.288
# product_description_lenght                                               0.2500      0.191      1.310      0.190      -0.124       0.624
# product_photos_qty                                                      -0.0246      0.185     -0.133      0.894      -0.387       0.338
# product_length_cm                                                       -0.2528      0.223     -1.135      0.256      -0.690       0.184
# product_height_cm                                                       -0.0682      0.215     -0.317      0.751      -0.490       0.353
# product_width_cm                                                         0.4845      0.232      2.091      0.037       0.030       0.939
# review_comment_title                                                     0.3916      0.200      1.957      0.050      -0.001       0.784
# review_comment_message                                                   0.3189      0.191      1.666      0.096      -0.056       0.694
# order_purchase_timestamp                                                 0.1742      0.194      0.900      0.368      -0.205       0.554
# payment_type_boleto                                                      0.4256      0.107      3.994      0.000       0.217       0.634
# payment_type_credit_card                                                -0.2352      0.097     -2.430      0.015      -0.425      -0.045
# payment_type_debit_card                                                 -0.9689      0.165     -5.888      0.000      -1.291      -0.646
# payment_type_not_defined                                             -5.674e-15   2.25e-16    -25.209      0.000   -6.12e-15   -5.23e-15
# payment_type_voucher                                                     0.3821      0.167      2.283      0.022       0.054       0.710
# product_category_name_agro_industria_e_comercio                          0.2461      0.170      1.444      0.149      -0.088       0.580
# product_category_name_alimentos                                          3.1736      0.170     18.684      0.000       2.841       3.507
# product_category_name_alimentos_bebidas                                  2.2266      0.170     13.107      0.000       1.894       2.560
# product_category_name_artes                                              1.4676      0.170      8.628      0.000       1.134       1.801
# product_category_name_artes_e_artesanato                                 0.0825      0.169      0.487      0.626      -0.250       0.415
# product_category_name_artigos_de_festas                                 -0.0982      0.170     -0.579      0.563      -0.431       0.234
# product_category_name_artigos_de_natal                                  -0.0842      0.170     -0.496      0.620      -0.417       0.248
# product_category_name_audio                                             -0.9391      0.169     -5.550      0.000      -1.271      -0.607
# product_category_name_automotivo                                       -11.8748      0.164    -72.620      0.000     -12.195     -11.554
# product_category_name_bebes                                             -4.2225      0.167    -25.352      0.000      -4.549      -3.896
# product_category_name_bebidas                                            6.0695      0.169     35.862      0.000       5.738       6.401
# product_category_name_beleza_saude                                      -0.8021      0.162     -4.965      0.000      -1.119      -0.485
# product_category_name_brinquedos                                         5.8490      0.166     35.321      0.000       5.524       6.174
# product_category_name_cama_mesa_banho                                    2.5273      0.167     15.109      0.000       2.199       2.855
# product_category_name_casa_conforto                                     -1.4718      0.170     -8.652      0.000      -1.805      -1.138
# product_category_name_casa_conforto_2                                -4.804e-15   1.64e-16    -29.340      0.000   -5.12e-15   -4.48e-15
# product_category_name_casa_construcao                                    4.6093      0.169     27.205      0.000       4.277       4.941
# product_category_name_cds_dvds_musicais                                  0.0930      0.169      0.549      0.583      -0.239       0.425
# product_category_name_cine_foto                                          0.6766      0.170      3.988      0.000       0.344       1.009
# product_category_name_climatizacao                                      -1.0090      0.169     -5.964      0.000      -1.341      -0.677
# product_category_name_consoles_games                                    -2.5645      0.169    -15.174      0.000      -2.896      -2.233
# product_category_name_construcao_ferramentas_construcao                  0.1836      0.169      1.086      0.277      -0.148       0.515
# product_category_name_construcao_ferramentas_ferramentas                 0.6333      0.169      3.737      0.000       0.301       0.965
# product_category_name_construcao_ferramentas_iluminacao                 -0.1740      0.170     -1.026      0.305      -0.506       0.158
# product_category_name_construcao_ferramentas_jardim                     -0.5154      0.169     -3.041      0.002      -0.848      -0.183
# product_category_name_construcao_ferramentas_seguranca                   0.9156      0.169      5.409      0.000       0.584       1.247
# product_category_name_cool_stuff                                         4.8243      0.165     29.214      0.000       4.501       5.148
# product_category_name_dvds_blu_ray                                      -0.3276      0.170     -1.932      0.053      -0.660       0.005
# product_category_name_eletrodomesticos                                   5.0095      0.169     29.692      0.000       4.679       5.340
# product_category_name_eletrodomesticos_2                                 0.9297      0.170      5.475      0.000       0.597       1.263
# product_category_name_eletronicos                                      -10.3504      0.167    -61.907      0.000     -10.678     -10.023
# product_category_name_eletroportateis                                    7.1260      0.169     42.123      0.000       6.794       7.458
# product_category_name_esporte_lazer                                      8.1406      0.160     50.734      0.000       7.826       8.455
# product_category_name_fashion_bolsas_e_acessorios                        2.5358      0.171     14.841      0.000       2.201       2.871
# product_category_name_fashion_calcados                                   0.9987      0.170      5.861      0.000       0.665       1.333
# product_category_name_fashion_esporte                                    0.4594      0.170      2.705      0.007       0.127       0.792
# product_category_name_fashion_roupa_feminina                             0.0802      0.169      0.474      0.636      -0.252       0.412
# product_category_name_fashion_roupa_infanto_juvenil                  -5.827e-15    1.9e-16    -30.697      0.000    -6.2e-15   -5.45e-15
# product_category_name_fashion_roupa_masculina                            0.0460      0.169      0.271      0.786      -0.286       0.378
# product_category_name_fashion_underwear_e_moda_praia                    -0.3005      0.170     -1.773      0.076      -0.633       0.032
# product_category_name_ferramentas_jardim                                 0.4205      0.165      2.547      0.011       0.097       0.744
# product_category_name_flores                                             0.0359      0.169      0.212      0.832      -0.296       0.368
# product_category_name_fraldas_higiene                                    0.0456      0.169      0.269      0.788      -0.286       0.377
# product_category_name_industria_comercio_e_negocios                     -0.3501      0.171     -2.051      0.040      -0.685      -0.015
# product_category_name_informatica_acessorios                            -7.2159      0.163    -44.362      0.000      -7.535      -6.897
# product_category_name_instrumentos_musicais                              0.0754      0.169      0.445      0.656      -0.257       0.407
# product_category_name_la_cuisine                                         0.2260      0.170      1.333      0.182      -0.106       0.558
# product_category_name_livros_importados                                  0.0209      0.169      0.124      0.902      -0.311       0.353
# product_category_name_livros_interesse_geral                             1.3940      0.170      8.224      0.000       1.062       1.726
# product_category_name_livros_tecnicos                                   -4.5750      0.170    -26.883      0.000      -4.909      -4.241
# product_category_name_malas_acessorios                                  -3.4600      0.172    -20.134      0.000      -3.797      -3.123
# product_category_name_market_place                                       0.8267      0.169      4.880      0.000       0.495       1.159
# product_category_name_moveis_colchao_e_estofado                         -0.1025      0.170     -0.603      0.547      -0.436       0.231
# product_category_name_moveis_cozinha_area_de_servico_jantar_e_jardim    -5.2240      0.170    -30.764      0.000      -5.557      -4.891
# product_category_name_moveis_decoracao                                  -7.6313      0.164    -46.472      0.000      -7.953      -7.309
# product_category_name_moveis_escritorio                                 -6.3974      0.180    -35.620      0.000      -6.749      -6.045
# product_category_name_moveis_quarto                                      0.1581      0.170      0.931      0.352      -0.175       0.491
# product_category_name_moveis_sala                                        6.0113      0.171     35.254      0.000       5.677       6.346
# product_category_name_musica                                             0.2357      0.170      1.390      0.165      -0.097       0.568
# product_category_name_other                                             -8.3875      0.168    -49.868      0.000      -8.717      -8.058
# product_category_name_papelaria                                         10.4548      0.169     61.736      0.000      10.123      10.787
# product_category_name_pc_gamer                                           0.0867      0.170      0.512      0.609      -0.246       0.419
# product_category_name_pcs                                                0.9165      0.177      5.185      0.000       0.570       1.263
# product_category_name_perfumaria                                         8.7129      0.167     52.313      0.000       8.386       9.039
# product_category_name_pet_shop                                          -6.5267      0.167    -39.024      0.000      -6.855      -6.199
# product_category_name_portateis_casa_forno_e_cafe                       -0.1581      0.170     -0.930      0.352      -0.491       0.175
# product_category_name_portateis_cozinha_e_preparadores_de_alimentos     -0.1710      0.170     -1.007      0.314      -0.504       0.162
# product_category_name_relogios_presentes                                 9.7922      0.171     57.419      0.000       9.458      10.127
# product_category_name_seguros_e_servicos                             -1.402e-17   1.14e-16     -0.123      0.902   -2.37e-16    2.09e-16
# product_category_name_sinalizacao_e_seguranca                            0.2508      0.169      1.480      0.139      -0.081       0.583
# product_category_name_tablets_impressao_imagem                           0.0105      0.170      0.062      0.951      -0.322       0.343
# product_category_name_telefonia                                          5.3857      0.170     31.650      0.000       5.052       5.719
# product_category_name_telefonia_fixa                                    -0.8434      0.172     -4.915      0.000      -1.180      -0.507
# product_category_name_utilidades_domesticas                             -8.7034      0.163    -53.530      0.000      -9.022      -8.385
# customer_state_AC                                                        0.9439      0.170      5.556      0.000       0.611       1.277
# customer_state_AL                                                        3.3644      0.170     19.816      0.000       3.032       3.697
# customer_state_AM                                                        0.0429      0.170      0.253      0.800      -0.289       0.375
# customer_state_AP                                                        0.5633      0.170      3.317      0.001       0.230       0.896
# customer_state_BA                                                       -1.2108      0.164     -7.399      0.000      -1.532      -0.890
# customer_state_CE                                                       -2.7100      0.168    -16.115      0.000      -3.040      -2.380
# customer_state_DF                                                        1.5457      0.165      9.366      0.000       1.222       1.869
# customer_state_ES                                                       -1.1639      0.166     -7.001      0.000      -1.490      -0.838
# customer_state_GO                                                        0.3431      0.166      2.063      0.039       0.017       0.669
# customer_state_MA                                                       -1.6137      0.170     -9.483      0.000      -1.947      -1.280
# customer_state_MG                                                       -0.2812      0.148     -1.897      0.058      -0.572       0.009
# customer_state_MS                                                       -0.6404      0.168     -3.802      0.000      -0.971      -0.310
# customer_state_MT                                                       -3.1761      0.169    -18.845      0.000      -3.507      -2.846
# customer_state_PA                                                       -3.1104      0.169    -18.385      0.000      -3.442      -2.779
# customer_state_PB                                                        4.6841      0.170     27.565      0.000       4.351       5.017
# customer_state_PE                                                        8.4122      0.168     50.207      0.000       8.084       8.741
# customer_state_PI                                                        4.9270      0.169     29.099      0.000       4.595       5.259
# customer_state_PR                                                       -0.3449      0.160     -2.159      0.031      -0.658      -0.032
# customer_state_RJ                                                       -0.2834      0.147     -1.932      0.053      -0.571       0.004
# customer_state_RN                                                        3.2230      0.170     18.986      0.000       2.890       3.556
# customer_state_RO                                                       -0.7317      0.171     -4.287      0.000      -1.066      -0.397
# customer_state_RR                                                       -0.0288      0.170     -0.170      0.865      -0.361       0.304
# customer_state_RS                                                        0.1148      0.159      0.720      0.471      -0.198       0.427
# customer_state_SC                                                       -1.6555      0.163    -10.142      0.000      -1.975      -1.336
# customer_state_SE                                                        0.3185      0.169      1.881      0.060      -0.013       0.651
# customer_state_SP                                                       -0.9689      0.123     -7.846      0.000      -1.211      -0.727
# customer_state_TO                                                       -0.3426      0.170     -2.019      0.044      -0.675      -0.010
# ==============================================================================
# Omnibus:                      892.204   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6189.992
# Skew:                           0.119   Prob(JB):                         0.00
# Kurtosis:                       6.925   Cond. No.                     2.03e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.94e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
    # bar chart of feature coefficients
    bar_names = coefs_by_mag['']
    bar_heights = coefs_by_mag['coef']
    bar_colors = np.where(bar_heights>0, 'blue', 'red')
    plt.figure(figsize=(9,17))
    plt.barh(bar_names, bar_heights, color=bar_colors)
    plt.xlabel('normalized coefficient')
# Out:
# Text(0.5, 0, 'normalized coefficient')
