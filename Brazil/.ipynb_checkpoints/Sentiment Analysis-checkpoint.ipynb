# %% [markdown]
# <h1 id="tocheading">Table of Contents</h1>
# <div id="toc"></div>

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %% [markdown]
# # Data Cleaning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime, date
from sklearn.cluster import KMeans

# %% [markdown]
# ## Order Dataset

# %%
order_df = pd.read_csv('olist_orders_dataset.csv')
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
# order_id                         99441 non-null object
# customer_id                      99441 non-null object
# order_status                     99441 non-null object
# order_purchase_timestamp         99441 non-null object
# order_approved_at                99281 non-null object
# order_delivered_carrier_date     97658 non-null object
# order_delivered_customer_date    96476 non-null object
# order_estimated_delivery_date    99441 non-null object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
order_df[order_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# Index: []

# %%
order_df.drop(['order_status',
               'order_delivered_carrier_date',
               'order_approved_at',
               'order_purchase_timestamp'], axis='columns', inplace=True)
#for column in ['order_purchase_timestamp', 'order_delivered_customer_date', 'order_estimated_delivery_date']:
#    order_df[column] = pd.to_datetime(order_df[column])
#order_df.info()

for column in ['order_delivered_customer_date', 'order_estimated_delivery_date']:
    order_df[column] = pd.to_datetime(order_df[column])
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 4 columns):
# order_id                         99441 non-null object
# customer_id                      99441 non-null object
# order_delivered_customer_date    96476 non-null datetime64[ns]
# order_estimated_delivery_date    99441 non-null datetime64[ns]
# dtypes: datetime64[ns](2), object(2)
# memory usage: 3.0+ MB

# %%
order_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_delivered_customer_date order_estimated_delivery_date
# 0           2017-10-10 21:25:13                    2017-10-18
# 1           2018-08-07 15:27:45                    2018-08-13
# 2           2018-08-17 18:06:29                    2018-09-04
# 3           2017-12-02 00:28:42                    2017-12-15
# 4           2018-02-16 18:17:02                    2018-02-26

# %% [markdown]
# ## Payment Dataset

# %%
payment_df = pd.read_csv('olist_order_payments_dataset.csv')
payment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
# order_id                103886 non-null object
# payment_sequential      103886 non-null int64
# payment_type            103886 non-null object
# payment_installments    103886 non-null int64
# payment_value           103886 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
payment_df.order_id.nunique()
# Out:
# 99440

# %%
payment_df[payment_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, payment_sequential, payment_type, payment_installments, payment_value]
# Index: []

# %%
payment_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
payment_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
payment_df.nunique()
# Out:
# order_id                99440
# payment_sequential         29
# payment_type                5
# payment_installments       24
# payment_value           29077
# dtype: int64

# %% [markdown]
# ## Customer Dataset

# %%
customer_df = pd.read_csv('olist_customers_dataset.csv')
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
# customer_id                 99441 non-null object
# customer_unique_id          99441 non-null object
# customer_zip_code_prefix    99441 non-null int64
# customer_city               99441 non-null object
# customer_state              99441 non-null object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customer_df[customer_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state]
# Index: []

# %%
customer_df.drop(['customer_zip_code_prefix', 'customer_city'], axis='columns', inplace=True)

# %%
customer_df.nunique()
# Out:
# customer_id           99441
# customer_unique_id    96096
# customer_state           27
# dtype: int64

# %%
customer_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#   customer_state
# 0             SP
# 1             SP
# 2             SP
# 3             SP
# 4             SP

# %% [markdown]
# ## Item Dataset

# %%
item_df = pd.read_csv('olist_order_items_dataset.csv')

# %%
item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
# order_id               112650 non-null object
# order_item_id          112650 non-null int64
# product_id             112650 non-null object
# seller_id              112650 non-null object
# shipping_limit_date    112650 non-null object
# price                  112650 non-null float64
# freight_value          112650 non-null float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
item_df[item_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value]
# Index: []

# %%
'''
item_df.drop(['seller_id',
              'shipping_limit_date',
              'price',
              'freight_value',
              'order_item_id'], axis='columns', inplace=True)
item_df.columns
'''
# Out:
# "\nitem_df.drop(['seller_id',\n              'shipping_limit_date',\n              'price',\n              'freight_value',\n              'order_item_id'], axis='columns', inplace=True)\nitem_df.columns\n"

# %%
item_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
item_df.order_id.nunique()
# Out:
# 98666

# %% [markdown]
# ## Product Dataset

# %%
product_df = pd.read_csv('olist_products_dataset.csv')

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
# product_id                    32951 non-null object
# product_category_name         32341 non-null object
# product_name_lenght           32341 non-null float64
# product_description_lenght    32341 non-null float64
# product_photos_qty            32341 non-null float64
# product_weight_g              32949 non-null float64
# product_length_cm             32949 non-null float64
# product_height_cm             32949 non-null float64
# product_width_cm              32949 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df[product_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm]
# Index: []

# %%
'''
product_df.drop(['product_name_lenght',
                 'product_description_lenght', 
                 'product_photos_qty', 
                 'product_weight_g',
                 'product_length_cm',
                 'product_height_cm',
                 'product_width_cm'], axis='columns', inplace=True)
'''
# Out:
# "\nproduct_df.drop(['product_name_lenght',\n                 'product_description_lenght', \n                 'product_photos_qty', \n                 'product_weight_g',\n                 'product_length_cm',\n                 'product_height_cm',\n                 'product_width_cm'], axis='columns', inplace=True)\n"

# %%
product_df.fillna(product_df.median(), inplace=True)
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
# product_id                    32951 non-null object
# product_category_name         32341 non-null object
# product_name_lenght           32951 non-null float64
# product_description_lenght    32951 non-null float64
# product_photos_qty            32951 non-null float64
# product_weight_g              32951 non-null float64
# product_length_cm             32951 non-null float64
# product_height_cm             32951 non-null float64
# product_width_cm              32951 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.fillna('other', inplace=True)
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
# product_id                    32951 non-null object
# product_category_name         32951 non-null object
# product_name_lenght           32951 non-null float64
# product_description_lenght    32951 non-null float64
# product_photos_qty            32951 non-null float64
# product_weight_g              32951 non-null float64
# product_length_cm             32951 non-null float64
# product_height_cm             32951 non-null float64
# product_width_cm              32951 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
product_df.product_category_name.nunique()
# Out:
# 74

# %% [markdown]
# ## Translation Dataset

# %%
translation_df = pd.read_csv('product_category_name_translation.csv')
translation_df.info()
translation_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
# product_category_name            71 non-null object
# product_category_name_english    71 non-null object
# dtypes: object(2)
# memory usage: 1.2+ KB
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# ## Review Dataset

# %%
review_df = pd.read_csv('olist_order_reviews_dataset.csv')
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
# review_id                  100000 non-null object
# order_id                   100000 non-null object
# review_score               100000 non-null int64
# review_comment_title       11715 non-null object
# review_comment_message     41753 non-null object
# review_creation_date       100000 non-null object
# review_answer_timestamp    100000 non-null object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
review_df[review_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [review_id, order_id, review_score, review_comment_title, review_comment_message, review_creation_date, review_answer_timestamp]
# Index: []

# %%
review_df.drop(['review_id', 'review_creation_date', 'review_answer_timestamp'], axis='columns', inplace=True)
review_df.columns
# Out:
# Index(['order_id', 'review_score', 'review_comment_title',
#        'review_comment_message'],
#       dtype='object')

# %%
for columns in ['review_comment_title', 'review_comment_message']:
    # replace present values with 1
    review_df.loc[review_df[columns].notnull(), columns] = 1
    # replace null values with 0
    review_df.loc[review_df[columns].isna(), columns] = 0
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
# order_id                  100000 non-null object
# review_score              100000 non-null int64
# review_comment_title      100000 non-null int64
# review_comment_message    100000 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 3.1+ MB

# %%
review_df.head()
# Out:
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  a548910a1c6147796b98fdf73dbeba33             5                     0
# 2  f9e4b658b201a9f2ecdecbb34bed034b             5                     0
# 3  658677c97b385a9be170737859d3511b             5                     0
# 4  8e6bfb81e283fa7e4f11123a3fb894f1             5                     0
#
#    review_comment_message
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       1

# %%
review_df.nunique()
# Out:
# order_id                  99441
# review_score                  5
# review_comment_title          2
# review_comment_message        2
# dtype: int64

# %%
review_df.review_score.value_counts(normalize=True)
# Out:
# 5    0.57420
# 4    0.19200
# 1    0.11858
# 3    0.08287
# 2    0.03235
# Name: review_score, dtype: float64

# %%
plt.bar(review_df.review_score.value_counts().index, review_df.review_score.value_counts().values)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Seller Dataset

# %%
seller_df = pd.read_csv('olist_sellers_dataset.csv')
seller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
# seller_id                 3095 non-null object
# seller_zip_code_prefix    3095 non-null int64
# seller_city               3095 non-null object
# seller_state              3095 non-null object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
seller_df.drop(['seller_zip_code_prefix', 'seller_city'], axis='columns', inplace=True)
seller_df.columns
# Out:
# Index(['seller_id', 'seller_state'], dtype='object')

# %% [markdown]
# # Exploratory Data Analytics with Raw Data

# %%
ro_df = pd.merge(review_df, order_df, how='left', on='order_id')
ro_df.info()
ro_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
# order_id                         100000 non-null object
# review_score                     100000 non-null int64
# review_comment_title             100000 non-null int64
# review_comment_message           100000 non-null int64
# customer_id                      100000 non-null object
# order_delivered_customer_date    97013 non-null datetime64[ns]
# order_estimated_delivery_date    100000 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int64(3), object(2)
# memory usage: 6.1+ MB
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  a548910a1c6147796b98fdf73dbeba33             5                     0
# 2  f9e4b658b201a9f2ecdecbb34bed034b             5                     0
# 3  658677c97b385a9be170737859d3511b             5                     0
# 4  8e6bfb81e283fa7e4f11123a3fb894f1             5                     0
#
#    review_comment_message                       customer_id  \
# 0                       0  41dcb106f807e993532d446263290104
# 1                       0  8a2e7ef9053dea531e4dc76bd6d853e6
# 2                       0  e226dfed6544df5b7b87a48208690feb
# 3                       1  de6dff97e5f1ba84a3cd9a3bc97df5f6
# 4                       1  5986b333ca0d44534a156a52a8e33a83
#
#   order_delivered_customer_date order_estimated_delivery_date
# 0           2018-01-17 18:42:41                    2018-02-02
# 1           2018-03-09 23:17:20                    2018-03-14
# 2           2018-02-16 17:28:48                    2018-03-09
# 3           2017-04-20 09:08:35                    2017-05-10
# 4           2018-02-28 16:33:35                    2018-03-09

# %%
roc_df = pd.merge(ro_df, customer_df, how='left', on='customer_id')
roc_df.drop(['customer_id', 'customer_unique_id'], axis='columns', inplace=True)
roc_df.info()
roc_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
# order_id                         100000 non-null object
# review_score                     100000 non-null int64
# review_comment_title             100000 non-null int64
# review_comment_message           100000 non-null int64
# order_delivered_customer_date    97013 non-null datetime64[ns]
# order_estimated_delivery_date    100000 non-null datetime64[ns]
# customer_state                   100000 non-null object
# dtypes: datetime64[ns](2), int64(3), object(2)
# memory usage: 6.1+ MB
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  a548910a1c6147796b98fdf73dbeba33             5                     0
# 2  f9e4b658b201a9f2ecdecbb34bed034b             5                     0
# 3  658677c97b385a9be170737859d3511b             5                     0
# 4  8e6bfb81e283fa7e4f11123a3fb894f1             5                     0
#
#    review_comment_message order_delivered_customer_date  \
# 0                       0           2018-01-17 18:42:41
# 1                       0           2018-03-09 23:17:20
# 2                       0           2018-02-16 17:28:48
# 3                       1           2017-04-20 09:08:35
# 4                       1           2018-02-28 16:33:35
#
#   order_estimated_delivery_date customer_state
# 0                    2018-02-02             SP
# 1                    2018-03-14             SP
# 2                    2018-03-09             BA
# 3                    2017-05-10             SC
# 4                    2018-03-09             SC

# %%
rocp_df = pd.merge(roc_df, payment_df, on='order_id')
rocp_df.drop('payment_sequential', axis='columns', inplace=True)
rocp_df.info()
rocp_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104485 entries, 0 to 104484
# Data columns (total 10 columns):
# order_id                         104485 non-null object
# review_score                     104485 non-null int64
# review_comment_title             104485 non-null int64
# review_comment_message           104485 non-null int64
# order_delivered_customer_date    101331 non-null datetime64[ns]
# order_estimated_delivery_date    104485 non-null datetime64[ns]
# customer_state                   104485 non-null object
# payment_type                     104485 non-null object
# payment_installments             104485 non-null int64
# payment_value                    104485 non-null float64
# dtypes: datetime64[ns](2), float64(1), int64(4), object(3)
# memory usage: 8.8+ MB
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  a548910a1c6147796b98fdf73dbeba33             5                     0
# 2  f9e4b658b201a9f2ecdecbb34bed034b             5                     0
# 3  658677c97b385a9be170737859d3511b             5                     0
# 4  8e6bfb81e283fa7e4f11123a3fb894f1             5                     0
#
#    review_comment_message order_delivered_customer_date  \
# 0                       0           2018-01-17 18:42:41
# 1                       0           2018-03-09 23:17:20
# 2                       0           2018-02-16 17:28:48
# 3                       1           2017-04-20 09:08:35
# 4                       1           2018-02-28 16:33:35
#
#   order_estimated_delivery_date customer_state payment_type  \
# 0                    2018-02-02             SP  credit_card
# 1                    2018-03-14             SP  credit_card
# 2                    2018-03-09             BA  credit_card
# 3                    2017-05-10             SC  credit_card
# 4                    2018-03-09             SC  credit_card
#
#    payment_installments  payment_value
# 0                     8         397.26
# 1                     1          88.09
# 2                     1         194.12
# 3                     1         222.84
# 4                    10        1333.25

# %%
rocpi_df = pd.merge(rocp_df, item_df, on='order_id')
rocpi_df.drop(['shipping_limit_date', 'order_item_id'], axis='columns', inplace=True)
rocpi_df.info()
rocpi_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 14 columns):
# order_id                         118315 non-null object
# review_score                     118315 non-null int64
# review_comment_title             118315 non-null int64
# review_comment_message           118315 non-null int64
# order_delivered_customer_date    115727 non-null datetime64[ns]
# order_estimated_delivery_date    118315 non-null datetime64[ns]
# customer_state                   118315 non-null object
# payment_type                     118315 non-null object
# payment_installments             118315 non-null int64
# payment_value                    118315 non-null float64
# product_id                       118315 non-null object
# seller_id                        118315 non-null object
# price                            118315 non-null float64
# freight_value                    118315 non-null float64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(5)
# memory usage: 13.5+ MB
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  73fc7af87114b39712e6da79b0a377eb             4                     0
# 2  a548910a1c6147796b98fdf73dbeba33             5                     0
# 3  f9e4b658b201a9f2ecdecbb34bed034b             5                     0
# 4  658677c97b385a9be170737859d3511b             5                     0
#
#    review_comment_message order_delivered_customer_date  \
# 0                       0           2018-01-17 18:42:41
# 1                       0           2018-01-17 18:42:41
# 2                       0           2018-03-09 23:17:20
# 3                       0           2018-02-16 17:28:48
# 4                       1           2017-04-20 09:08:35
#
#   order_estimated_delivery_date customer_state payment_type  \
# 0                    2018-02-02             SP  credit_card
# 1                    2018-02-02             SP  credit_card
# 2                    2018-03-14             SP  credit_card
# 3                    2018-03-09             BA  credit_card
# 4                    2017-05-10             SC  credit_card
#
#    payment_installments  payment_value                        product_id  \
# 0                     8         397.26  fd25ab760bfbba13c198fa3b4f1a0cd3
# 1                     8         397.26  fd25ab760bfbba13c198fa3b4f1a0cd3
# 2                     1          88.09  be0dbdc3d67d55727a65d4cd696ca73c
# 3                     1         194.12  d1c427060a0f73f6b889a5c7c61f2ac4
# 4                     1         222.84  52c80cedd4e90108bf4fa6a206ef6b03
#
#                           seller_id   price  freight_value
# 0  6d803cb79cc31c41c4c789a75933b3c7  185.00          13.63
# 1  6d803cb79cc31c41c4c789a75933b3c7  185.00          13.63
# 2  8e6d7754bc7e0f22c96d255ebda59eba   79.79           8.30
# 3  a1043bafd471dff536d0c462352beb48  149.00          45.12
# 4  a1043bafd471dff536d0c462352beb48  179.99          42.85

# %%
rocpip_df = pd.merge(rocpi_df, product_df, on='product_id')
rocpip_df.drop('product_id', axis='columns', inplace=True)
rocpip_df.info()
rocpip_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 21 columns):
# order_id                         118315 non-null object
# review_score                     118315 non-null int64
# review_comment_title             118315 non-null int64
# review_comment_message           118315 non-null int64
# order_delivered_customer_date    115727 non-null datetime64[ns]
# order_estimated_delivery_date    118315 non-null datetime64[ns]
# customer_state                   118315 non-null object
# payment_type                     118315 non-null object
# payment_installments             118315 non-null int64
# payment_value                    118315 non-null float64
# seller_id                        118315 non-null object
# price                            118315 non-null float64
# freight_value                    118315 non-null float64
# product_category_name            118315 non-null object
# product_name_lenght              118315 non-null float64
# product_description_lenght       118315 non-null float64
# product_photos_qty               118315 non-null float64
# product_weight_g                 118315 non-null float64
# product_length_cm                118315 non-null float64
# product_height_cm                118315 non-null float64
# product_width_cm                 118315 non-null float64
# dtypes: datetime64[ns](2), float64(10), int64(4), object(5)
# memory usage: 19.9+ MB
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  73fc7af87114b39712e6da79b0a377eb             4                     0
# 2  19721d59a9764437477eff0730b48665             5                     0
# 3  efd626e6a12a82d76e456e34093f8356             5                     0
# 4  a548910a1c6147796b98fdf73dbeba33             5                     0
#
#    review_comment_message order_delivered_customer_date  \
# 0                       0           2018-01-17 18:42:41
# 1                       0           2018-01-17 18:42:41
# 2                       0           2018-04-09 21:53:23
# 3                       0           2017-12-27 18:19:53
# 4                       0           2018-03-09 23:17:20
#
#   order_estimated_delivery_date customer_state payment_type  \
# 0                    2018-02-02             SP  credit_card
# 1                    2018-02-02             SP  credit_card
# 2                    2018-04-27             RS  credit_card
# 3                    2018-01-08             MG  credit_card
# 4                    2018-03-14             SP  credit_card
#
#    payment_installments  payment_value  ...   price  freight_value  \
# 0                     8         397.26  ...  185.00          13.63
# 1                     8         397.26  ...  185.00          13.63
# 2                     3         205.26  ...  185.00          20.26
# 3                     2         202.05  ...  185.00          17.05
# 4                     1          88.09  ...   79.79           8.30
#
#     product_category_name product_name_lenght  product_description_lenght  \
# 0           esporte_lazer                42.0                       858.0
# 1           esporte_lazer                42.0                       858.0
# 2           esporte_lazer                42.0                       858.0
# 3           esporte_lazer                42.0                       858.0
# 4  informatica_acessorios                47.0                       493.0
#
#    product_photos_qty  product_weight_g  product_length_cm  product_height_cm  \
# 0                 1.0            1300.0               30.0               30.0
# 1                 1.0            1300.0               30.0               30.0
# 2                 1.0            1300.0               30.0               30.0
# 3                 1.0            1300.0               30.0               30.0
# 4                 1.0             245.0               19.0               14.0
#
#    product_width_cm
# 0              35.0
# 1              35.0
# 2              35.0
# 3              35.0
# 4              14.0
#
# [5 rows x 21 columns]

# %%
rocpips_df = pd.merge(rocpip_df, seller_df, on='seller_id')
rocpips_df.drop('seller_id', axis='columns', inplace=True)
rocpips_df.info()
rocpips_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118315 entries, 0 to 118314
# Data columns (total 21 columns):
# order_id                         118315 non-null object
# review_score                     118315 non-null int64
# review_comment_title             118315 non-null int64
# review_comment_message           118315 non-null int64
# order_delivered_customer_date    115727 non-null datetime64[ns]
# order_estimated_delivery_date    118315 non-null datetime64[ns]
# customer_state                   118315 non-null object
# payment_type                     118315 non-null object
# payment_installments             118315 non-null int64
# payment_value                    118315 non-null float64
# price                            118315 non-null float64
# freight_value                    118315 non-null float64
# product_category_name            118315 non-null object
# product_name_lenght              118315 non-null float64
# product_description_lenght       118315 non-null float64
# product_photos_qty               118315 non-null float64
# product_weight_g                 118315 non-null float64
# product_length_cm                118315 non-null float64
# product_height_cm                118315 non-null float64
# product_width_cm                 118315 non-null float64
# seller_state                     118315 non-null object
# dtypes: datetime64[ns](2), float64(10), int64(4), object(5)
# memory usage: 19.9+ MB
#                            order_id  review_score  review_comment_title  \
# 0  73fc7af87114b39712e6da79b0a377eb             4                     0
# 1  73fc7af87114b39712e6da79b0a377eb             4                     0
# 2  19721d59a9764437477eff0730b48665             5                     0
# 3  efd626e6a12a82d76e456e34093f8356             5                     0
# 4  b0bc656fed47584c160f8cff2d7b8bbd             5                     0
#
#    review_comment_message order_delivered_customer_date  \
# 0                       0           2018-01-17 18:42:41
# 1                       0           2018-01-17 18:42:41
# 2                       0           2018-04-09 21:53:23
# 3                       0           2017-12-27 18:19:53
# 4                       0           2018-03-16 14:16:19
#
#   order_estimated_delivery_date customer_state payment_type  \
# 0                    2018-02-02             SP  credit_card
# 1                    2018-02-02             SP  credit_card
# 2                    2018-04-27             RS  credit_card
# 3                    2018-01-08             MG  credit_card
# 4                    2018-03-23             MG  credit_card
#
#    payment_installments  payment_value  ...  freight_value  \
# 0                     8         397.26  ...          13.63
# 1                     8         397.26  ...          13.63
# 2                     3         205.26  ...          20.26
# 3                     2         202.05  ...          17.05
# 4                     1         306.40  ...          18.20
#
#    product_category_name product_name_lenght  product_description_lenght  \
# 0          esporte_lazer                42.0                       858.0
# 1          esporte_lazer                42.0                       858.0
# 2          esporte_lazer                42.0                       858.0
# 3          esporte_lazer                42.0                       858.0
# 4          esporte_lazer                47.0                       858.0
#
#    product_photos_qty  product_weight_g  product_length_cm  product_height_cm  \
# 0                 1.0            1300.0               30.0               30.0
# 1                 1.0            1300.0               30.0               30.0
# 2                 1.0            1300.0               30.0               30.0
# 3                 1.0            1300.0               30.0               30.0
# 4                 1.0            1600.0               30.0               30.0
#
#    product_width_cm  seller_state
# 0              35.0            SP
# 1              35.0            SP
# 2              35.0            SP
# 3              35.0            SP
# 4              35.0            SP
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Feature Engineering

# %%
rocpips_df['delay'] = (rocpips_df.order_delivered_customer_date - rocpips_df.order_estimated_delivery_date).dt.days
rocpips_df.drop(['order_delivered_customer_date', 'order_estimated_delivery_date'], axis='columns', inplace=True)
rocpips_df.fillna(rocpips_df.median(), inplace=True)

# %%
rocpips_df
# Out:
#                                 order_id  review_score  review_comment_title  \
# 0       73fc7af87114b39712e6da79b0a377eb             4                     0
# 1       73fc7af87114b39712e6da79b0a377eb             4                     0
# 2       19721d59a9764437477eff0730b48665             5                     0
# 3       efd626e6a12a82d76e456e34093f8356             5                     0
# 4       b0bc656fed47584c160f8cff2d7b8bbd             5                     0
# ...                                  ...           ...                   ...
# 118310  8c1d27c10cc60cc369a428813bb71350             4                     1
# 118311  80ba449ea98f8e879a829759b5a66294             5                     0
# 118312  5fd71cc4eb69ae6f65ac3acfcbc17ab5             5                     0
# 118313  61d5f1dcdf9b023ea7622b65d2362e4f             1                     0
# 118314  5f4a120717a4d152577d7d2ec66c45be             5                     0
#
#         review_comment_message customer_state payment_type  \
# 0                            0             SP  credit_card
# 1                            0             SP  credit_card
# 2                            0             RS  credit_card
# 3                            0             MG  credit_card
# 4                            0             MG  credit_card
# ...                        ...            ...          ...
# 118310                       1             MG  credit_card
# 118311                       0             GO  credit_card
# 118312                       0             RJ  credit_card
# 118313                       1             SP  credit_card
# 118314                       0             RJ  credit_card
#
#         payment_installments  payment_value  price  freight_value  \
# 0                          8         397.26  185.0          13.63
# 1                          8         397.26  185.0          13.63
# 2                          3         205.26  185.0          20.26
# 3                          2         202.05  185.0          17.05
# 4                          1         306.40  135.0          18.20
# ...                      ...            ...    ...            ...
# 118310                     1         108.63   89.9          18.73
# 118311                     4         327.25  289.9          37.35
# 118312                     2          98.34   79.9          18.44
# 118313                     8         767.69  750.0          17.69
# 118314                     3         201.34  161.0          40.34
#
#                                  product_category_name  product_name_lenght  \
# 0                                        esporte_lazer                 42.0
# 1                                        esporte_lazer                 42.0
# 2                                        esporte_lazer                 42.0
# 3                                        esporte_lazer                 42.0
# 4                                        esporte_lazer                 47.0
# ...                                                ...                  ...
# 118310                                moveis_decoracao                 50.0
# 118311                                    beleza_saude                 47.0
# 118312                         sinalizacao_e_seguranca                 36.0
# 118313                              relogios_presentes                 43.0
# 118314  moveis_cozinha_area_de_servico_jantar_e_jardim                 38.0
#
#         product_description_lenght  product_photos_qty  product_weight_g  \
# 0                            858.0                 1.0            1300.0
# 1                            858.0                 1.0            1300.0
# 2                            858.0                 1.0            1300.0
# 3                            858.0                 1.0            1300.0
# 4                            858.0                 1.0            1600.0
# ...                            ...                 ...               ...
# 118310                      1141.0                 2.0             450.0
# 118311                       696.0                 1.0             692.0
# 118312                       609.0                 2.0             575.0
# 118313                       381.0                 4.0             350.0
# 118314                       245.0                 1.0            4000.0
#
#         product_length_cm  product_height_cm  product_width_cm seller_state  \
# 0                    30.0               30.0              35.0           SP
# 1                    30.0               30.0              35.0           SP
# 2                    30.0               30.0              35.0           SP
# 3                    30.0               30.0              35.0           SP
# 4                    30.0               30.0              35.0           SP
# ...                   ...                ...               ...          ...
# 118310               16.0               16.0              16.0           SP
# 118311               15.0               12.0              14.0           PR
# 118312               45.0               21.0              23.0           SP
# 118313               20.0               20.0              20.0           SP
# 118314               31.0               42.0              43.0           PR
#
#         delay
# 0       -16.0
# 1       -16.0
# 2       -18.0
# 3       -12.0
# 4        -7.0
# ...       ...
# 118310  -14.0
# 118311  -15.0
# 118312  -14.0
# 118313   -7.0
# 118314  -24.0
#
# [118315 rows x 20 columns]

# %% [markdown]
# ## Linear Modeling

# %%
dummies_df = rocpips_df.drop('order_id', axis='columns', inplace=True)
dummied_df = pd.get_dummies(dummies_df)

# %%
dummied_df.info()
dummied_df.head()

# %%
target = dummied_df.review_score
df = dummied_df.drop('review_score', axis='columns')
df['review_score'] = target
df

# %%
corr_df.head(10)

# %%
df[df.columns[:-1]]

# %%
'''
X = df[df.columns[:-1]]
y = df[df.columns[-1]]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# logistic regression 
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
print('Train Accuracy: ', lr.score(X_train, y_train))
print('Test Accuracy: ', lr.score(X_test, y_test))

# %%
df.loc[df.review_score < 5, 'review_score'] = 0
df.loc[df.review_score == 5, 'review_score'] = 1

# %%
# seperate target from features
X = df[df.columns[:-1]]
y = df[df.columns[-1]]

# scale data with standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = pd.DataFrame(data=scaler.fit_transform(X), columns=X.columns)

# fit logit function 
import statsmodels.api as sm
X_withconstant = sm.add_constant(X)
logit = sm.Logit(y, X_withconstant).fit()
display(logit.summary()) 

# table of significant coefficinets sorted by absolute value
coef_table = summary.tables[1]
coef_df = pd.DataFrame(data=coef_table.data[1:], columns=coef_table.data[0])
coef_df['coef'] = coef_df['coef'].astype(float)
coef_df['P>|z|'] = coef_df['P>|z|'].astype(float)
coef_df['abs_coef'] = np.abs(coef_df['coef'])
coef_df.drop(0, axis='index', inplace=True)
coefs_by_mag = coef_df.sort_values(by='abs_coef', ascending=False)
coefs_by_mag = coefs_by_mag[coefs_by_mag['P>|z|'] <= 0.05]

# bar chart of feature coefficients
bar_names = coefs_by_mag['']
bar_heights = coefs_by_mag['coef']
bar_colors = np.where(bar_heights>0, 'blue', 'red')
plt.figure(figsize=(5.0, 4.0))
plt.barh(bar_names, bar_heights, color=bar_colors)
plt.xlabel('normalized coefficient')
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.650620
#          Iterations: 35
# C:\Users\arali\Anaconda3\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           review_score   No. Observations:               118315
# Model:                          Logit   Df Residuals:                   118176
# Method:                           MLE   Df Model:                          138
# Date:                Tue, 17 Mar 2020   Pseudo R-squ.:                 0.05115
# Time:                        20:38:52   Log-Likelihood:                -76978.
# converged:                      False   LL-Null:                       -81128.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ========================================================================================================================================
#                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------
# const                                                                    0.2507      7.510      0.033      0.973     -14.468      14.970
# review_comment_title                                                     0.0732      0.006     11.340      0.000       0.061       0.086
# review_comment_message                                                  -0.3291      0.006    -51.080      0.000      -0.342      -0.316
# payment_installments                                                     0.0022      0.007      0.301      0.764      -0.012       0.016
# payment_value                                                           -0.3552      0.015    -24.222      0.000      -0.384      -0.326
# price                                                                    0.2738      0.012     22.006      0.000       0.249       0.298
# freight_value                                                           -0.0096      0.009     -1.017      0.309      -0.028       0.009
# product_name_lenght                                                     -0.0248      0.006     -3.849      0.000      -0.037      -0.012
# product_description_lenght                                               0.0062      0.007      0.909      0.364      -0.007       0.019
# product_photos_qty                                                       0.0078      0.007      1.187      0.235      -0.005       0.021
# product_weight_g                                                         0.0182      0.010      1.760      0.078      -0.002       0.038
# product_length_cm                                                       -0.0203      0.008     -2.517      0.012      -0.036      -0.004
# product_height_cm                                                       -0.0301      0.008     -3.570      0.000      -0.047      -0.014
# product_width_cm                                                         0.0070      0.008      0.837      0.403      -0.009       0.023
# delay                                                                   -0.3650      0.007    -51.380      0.000      -0.379      -0.351
# customer_state_AC                                                       -0.0047        nan        nan        nan         nan         nan
# customer_state_AL                                                       -0.0124        nan        nan        nan         nan         nan
# customer_state_AM                                                       -0.0051        nan        nan        nan         nan         nan
# customer_state_AP                                                       -0.0094        nan        nan        nan         nan         nan
# customer_state_BA                                                       -0.0432        nan        nan        nan         nan         nan
# customer_state_CE                                                       -0.0200        nan        nan        nan         nan         nan
# customer_state_DF                                                       -0.0077        nan        nan        nan         nan         nan
# customer_state_ES                                                       -0.0068        nan        nan        nan         nan         nan
# customer_state_GO                                                       -0.0146        nan        nan        nan         nan         nan
# customer_state_MA                                                       -0.0224        nan        nan        nan         nan         nan
# customer_state_MG                                                        0.0084        nan        nan        nan         nan         nan
# customer_state_MS                                                        0.0119        nan        nan        nan         nan         nan
# customer_state_MT                                                       -0.0199        nan        nan        nan         nan         nan
# customer_state_PA                                                       -0.0342        nan        nan        nan         nan         nan
# customer_state_PB                                                        0.0043        nan        nan        nan         nan         nan
# customer_state_PE                                                       -0.0075        nan        nan        nan         nan         nan
# customer_state_PI                                                       -0.0143        nan        nan        nan         nan         nan
# customer_state_PR                                                        0.0119        nan        nan        nan         nan         nan
# customer_state_RJ                                                       -0.0363        nan        nan        nan         nan         nan
# customer_state_RN                                                       -0.0020        nan        nan        nan         nan         nan
# customer_state_RO                                                       -0.0117        nan        nan        nan         nan         nan
# customer_state_RR                                                       -0.0143        nan        nan        nan         nan         nan
# customer_state_RS                                                       -0.0168        nan        nan        nan         nan         nan
# customer_state_SC                                                       -0.0016        nan        nan        nan         nan         nan
# customer_state_SE                                                       -0.0004        nan        nan        nan         nan         nan
# customer_state_SP                                                        0.0717        nan        nan        nan         nan         nan
# customer_state_TO                                                        0.0018        nan        nan        nan         nan         nan
# payment_type_boleto                                                      0.0158   2.62e+05   6.02e-08      1.000   -5.13e+05    5.13e+05
# payment_type_credit_card                                                -0.0020   2.91e+05  -6.74e-09      1.000    -5.7e+05     5.7e+05
# payment_type_debit_card                                                  0.0198   7.86e+04   2.52e-07      1.000   -1.54e+05    1.54e+05
# payment_type_voucher                                                    -0.0343   1.49e+05  -2.31e-07      1.000   -2.92e+05    2.92e+05
# product_category_name_agro_industria_e_comercio                         -0.0013        nan        nan        nan         nan         nan
# product_category_name_alimentos                                          0.0151        nan        nan        nan         nan         nan
# product_category_name_alimentos_bebidas                                  0.0134        nan        nan        nan         nan         nan
# product_category_name_artes                                             -0.0077        nan        nan        nan         nan         nan
# product_category_name_artes_e_artesanato                                 0.0043        nan        nan        nan         nan         nan
# product_category_name_artigos_de_festas                                 -0.0024        nan        nan        nan         nan         nan
# product_category_name_artigos_de_natal                                  -0.0066        nan        nan        nan         nan         nan
# product_category_name_audio                                             -0.0066        nan        nan        nan         nan         nan
# product_category_name_automotivo                                         0.0026        nan        nan        nan         nan         nan
# product_category_name_bebes                                             -0.0082        nan        nan        nan         nan         nan
# product_category_name_bebidas                                           -0.0028        nan        nan        nan         nan         nan
# product_category_name_beleza_saude                                       0.0339        nan        nan        nan         nan         nan
# product_category_name_brinquedos                                         0.0316        nan        nan        nan         nan         nan
# product_category_name_cama_mesa_banho                                   -0.0435        nan        nan        nan         nan         nan
# product_category_name_casa_conforto                                      0.0081        nan        nan        nan         nan         nan
# product_category_name_casa_conforto_2                                   -0.0058        nan        nan        nan         nan         nan
# product_category_name_casa_construcao                                   -0.0170        nan        nan        nan         nan         nan
# product_category_name_cds_dvds_musicais                                  0.0055        nan        nan        nan         nan         nan
# product_category_name_cine_foto                                          0.0142        nan        nan        nan         nan         nan
# product_category_name_climatizacao                                      -0.0028        nan        nan        nan         nan         nan
# product_category_name_consoles_games                                    -0.0124        nan        nan        nan         nan         nan
# product_category_name_construcao_ferramentas_construcao                  0.0032        nan        nan        nan         nan         nan
# product_category_name_construcao_ferramentas_ferramentas                 0.0152        nan        nan        nan         nan         nan
# product_category_name_construcao_ferramentas_iluminacao                 -0.0060        nan        nan        nan         nan         nan
# product_category_name_construcao_ferramentas_jardim                      0.0085        nan        nan        nan         nan         nan
# product_category_name_construcao_ferramentas_seguranca                  -0.0076        nan        nan        nan         nan         nan
# product_category_name_cool_stuff                                         0.0143        nan        nan        nan         nan         nan
# product_category_name_dvds_blu_ray                                      -0.0006        nan        nan        nan         nan         nan
# product_category_name_eletrodomesticos                                   0.0059        nan        nan        nan         nan         nan
# product_category_name_eletrodomesticos_2                                -0.0022        nan        nan        nan         nan         nan
# product_category_name_eletronicos                                       -0.0063        nan        nan        nan         nan         nan
# product_category_name_eletroportateis                                    0.0053        nan        nan        nan         nan         nan
# product_category_name_esporte_lazer                                      0.0216        nan        nan        nan         nan         nan
# product_category_name_fashion_bolsas_e_acessorios                       -0.0040        nan        nan        nan         nan         nan
# product_category_name_fashion_calcados                                   0.0128        nan        nan        nan         nan         nan
# product_category_name_fashion_esporte                                -1.478e-05        nan        nan        nan         nan         nan
# product_category_name_fashion_roupa_feminina                            -0.0138        nan        nan        nan         nan         nan
# product_category_name_fashion_roupa_infanto_juvenil                      0.0108        nan        nan        nan         nan         nan
# product_category_name_fashion_roupa_masculina                           -0.0050        nan        nan        nan         nan         nan
# product_category_name_fashion_underwear_e_moda_praia                    -0.0075        nan        nan        nan         nan         nan
# product_category_name_ferramentas_jardim                                 0.0197        nan        nan        nan         nan         nan
# product_category_name_flores                                             0.0062        nan        nan        nan         nan         nan
# product_category_name_fraldas_higiene                                   -0.0220        nan        nan        nan         nan         nan
# product_category_name_industria_comercio_e_negocios                      0.0008        nan        nan        nan         nan         nan
# product_category_name_informatica_acessorios                            -0.0283        nan        nan        nan         nan         nan
# product_category_name_instrumentos_musicais                              0.0118        nan        nan        nan         nan         nan
# product_category_name_la_cuisine                                         0.0068        nan        nan        nan         nan         nan
# product_category_name_livros_importados                                  0.0200        nan        nan        nan         nan         nan
# product_category_name_livros_interesse_geral                             0.0405        nan        nan        nan         nan         nan
# product_category_name_livros_tecnicos                                    0.0246        nan        nan        nan         nan         nan
# product_category_name_malas_acessorios                                   0.0344        nan        nan        nan         nan         nan
# product_category_name_market_place                                      -0.0161        nan        nan        nan         nan         nan
# product_category_name_moveis_colchao_e_estofado                         -0.0042        nan        nan        nan         nan         nan
# product_category_name_moveis_cozinha_area_de_servico_jantar_e_jardim    -0.0134        nan        nan        nan         nan         nan
# product_category_name_moveis_decoracao                                  -0.0200        nan        nan        nan         nan         nan
# product_category_name_moveis_escritorio                                 -0.0611        nan        nan        nan         nan         nan
# product_category_name_moveis_quarto                                     -0.0008        nan        nan        nan         nan         nan
# product_category_name_moveis_sala                                       -0.0126        nan        nan        nan         nan         nan
# product_category_name_musica                                             0.0014        nan        nan        nan         nan         nan
# product_category_name_other                                             -0.0182        nan        nan        nan         nan         nan
# product_category_name_papelaria                                          0.0256        nan        nan        nan         nan         nan
# product_category_name_pc_gamer                                          -0.0111        nan        nan        nan         nan         nan
# product_category_name_pcs                                                0.0152        nan        nan        nan         nan         nan
# product_category_name_perfumaria                                         0.0340        nan        nan        nan         nan         nan
# product_category_name_pet_shop                                           0.0239        nan        nan        nan         nan         nan
# product_category_name_portateis_casa_forno_e_cafe                        0.0084        nan        nan        nan         nan         nan
# product_category_name_portateis_cozinha_e_preparadores_de_alimentos     -0.0100        nan        nan        nan         nan         nan
# product_category_name_relogios_presentes                                -0.0143        nan        nan        nan         nan         nan
# product_category_name_seguros_e_servicos                                -0.1074        nan        nan        nan         nan         nan
# product_category_name_sinalizacao_e_seguranca                            0.0063        nan        nan        nan         nan         nan
# product_category_name_tablets_impressao_imagem                          -0.0064        nan        nan        nan         nan         nan
# product_category_name_telefonia                                         -0.0343        nan        nan        nan         nan         nan
# product_category_name_telefonia_fixa                                    -0.0168        nan        nan        nan         nan         nan
# product_category_name_utilidades_domesticas                              0.0068        nan        nan        nan         nan         nan
# seller_state_AC                                                         -0.0804    631.591     -0.000      1.000   -1237.976    1237.815
# seller_state_AM                                                          0.0011        nan        nan        nan         nan         nan
# seller_state_BA                                                         -0.0079        nan        nan        nan         nan         nan
# seller_state_CE                                                          0.0080        nan        nan        nan         nan         nan
# seller_state_DF                                                          0.0017        nan        nan        nan         nan         nan
# seller_state_ES                                                         -0.0102        nan        nan        nan         nan         nan
# seller_state_GO                                                          0.0145        nan        nan        nan         nan         nan
# seller_state_MA                                                         -0.0116        nan        nan        nan         nan         nan
# seller_state_MG                                                         -0.0008        nan        nan        nan         nan         nan
# seller_state_MS                                                          0.0206        nan        nan        nan         nan         nan
# seller_state_MT                                                         -0.0058        nan        nan        nan         nan         nan
# seller_state_PA                                                          0.0042        nan        nan        nan         nan         nan
# seller_state_PB                                                         -0.0034        nan        nan        nan         nan         nan
# seller_state_PE                                                         -0.0017        nan        nan        nan         nan         nan
# seller_state_PI                                                         -0.0004        nan        nan        nan         nan         nan
# seller_state_PR                                                         -0.0039        nan        nan        nan         nan         nan
# seller_state_RJ                                                          0.0169        nan        nan        nan         nan         nan
# seller_state_RN                                                          0.0063        nan        nan        nan         nan         nan
# seller_state_RO                                                         -0.0030        nan        nan        nan         nan         nan
# seller_state_RS                                                          0.0099        nan        nan        nan         nan         nan
# seller_state_SC                                                         -0.0069        nan        nan        nan         nan         nan
# seller_state_SE                                                      -6.719e-05        nan        nan        nan         nan         nan
# seller_state_SP                                                         -0.0038        nan        nan        nan         nan         nan
# ========================================================================================================================================
# """
# Text(0.5, 0, 'normalized coefficient')

# %% [markdown]
# ## VIF

# %%
# variance inflation factors
from statsmodels.stats.outliers_influence import variance_inflation_factor
VIF_series = pd.Series([variance_inflation_factor(X.values, i) for i in range(X.shape[1])], index=X.columns)
VIF_series.sort_values(ascending=False, inplace=True)
# Out:
# seller_state_SP                                 inf
# product_category_name_eletroportateis           inf
# product_category_name_alimentos                 inf
# product_category_name_alimentos_bebidas         inf
# product_category_name_artes                     inf
#                                              ...
# product_photos_qty                         1.173839
# review_comment_title                       1.148259
# review_comment_message                     1.138200
# product_name_lenght                        1.118339
# delay                                      1.040132
# Length: 142, dtype: float64

# %%
VIF_df = pd.DataFrame(VIF_series, columns=['vif'])
VIF_df
# Out:
#                              vif
# review_comment_title    1.148259
# review_comment_message  1.138200
# payment_installments    1.399674
# payment_value           2.401510
# price                   2.680180
# ...                          ...
# seller_state_RO              inf
# seller_state_RS              inf
# seller_state_SC              inf
# seller_state_SE              inf
# seller_state_SP              inf
#
# [142 rows x 1 columns]

# %%
VIF_df[VIF_df.vif!=float('inf')]
# Out:
#                                  vif
# review_comment_title        1.148259
# review_comment_message      1.138200
# payment_installments        1.399674
# payment_value               2.401510
# price                       2.680180
# freight_value               2.317535
# product_name_lenght         1.118339
# product_description_lenght  1.244824
# product_photos_qty          1.173839
# product_weight_g            2.863894
# product_length_cm           1.763969
# product_height_cm           1.919684
# product_width_cm            1.903856
# delay                       1.040132

# %%
# seperate target from features
X = df[VIF_df[VIF_df.vif!=float('inf')].index]
y = df[df.columns[-1]]

# scale data with standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = pd.DataFrame(data=scaler.fit_transform(X), columns=X.columns)

# fit logit function 
import statsmodels.api as sm
X_withconstant = sm.add_constant(X)
logit = sm.Logit(y, X_withconstant).fit()
display(logit.summary()) 

# table of significant coefficinets sorted by absolute value
coef_table = logit.summary().tables[1]
coef_df = pd.DataFrame(data=coef_table.data[1:], columns=coef_table.data[0])
coef_df['coef'] = coef_df['coef'].astype(float)
coef_df['P>|z|'] = coef_df['P>|z|'].astype(float)
coef_df['abs_coef'] = np.abs(coef_df['coef'])
coef_df.drop(0, axis='index', inplace=True)
coefs_by_mag = coef_df.sort_values(by='abs_coef', ascending=False)
coefs_by_mag = coefs_by_mag[coefs_by_mag['P>|z|'] <= 0.05]

# bar chart of feature coefficients
bar_names = coefs_by_mag['']
bar_heights = coefs_by_mag['coef']
bar_colors = np.where(bar_heights>0, 'blue', 'red')
plt.figure(figsize=(5.0, 4.0))
plt.barh(bar_names, bar_heights, color=bar_colors)
plt.xlabel('normalized coefficient')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.655240
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           review_score   No. Observations:               118315
# Model:                          Logit   Df Residuals:                   118300
# Method:                           MLE   Df Model:                           14
# Date:                Wed, 18 Mar 2020   Pseudo R-squ.:                 0.04442
# Time:                        17:15:28   Log-Likelihood:                -77525.
# converged:                       True   LL-Null:                       -81128.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.2505      0.006     41.425      0.000       0.239       0.262
# review_comment_title           0.0789      0.006     12.415      0.000       0.066       0.091
# review_comment_message        -0.3382      0.006    -53.016      0.000      -0.351      -0.326
# payment_installments          -0.0080      0.006     -1.236      0.216      -0.021       0.005
# payment_value                 -0.3656      0.014    -25.797      0.000      -0.393      -0.338
# price                          0.2999      0.012     25.292      0.000       0.277       0.323
# freight_value                 -0.0690      0.008     -8.341      0.000      -0.085      -0.053
# product_name_lenght           -0.0334      0.006     -5.423      0.000      -0.045      -0.021
# product_description_lenght     0.0190      0.006      3.020      0.003       0.007       0.031
# product_photos_qty             0.0139      0.006      2.249      0.025       0.002       0.026
# product_weight_g               0.0214      0.010      2.200      0.028       0.002       0.041
# product_length_cm             -0.0284      0.007     -3.799      0.000      -0.043      -0.014
# product_height_cm             -0.0112      0.008     -1.493      0.136      -0.026       0.004
# product_width_cm               0.0151      0.008      1.952      0.051   -5.85e-05       0.030
# delay                         -0.3579      0.007    -51.699      0.000      -0.371      -0.344
# ==============================================================================================
# """
# Text(0.5, 0, 'normalized coefficient')

# %% [markdown]
# ## Regularization

# %% [markdown]
# ### Regualr

# %%
# seperate target from features
X = df[df.columns[:-1]]
y = df[df.columns[-1]]

# fit regularized logit function 
import statsmodels.api as sm
X_withconstant = sm.add_constant(X)
logit = sm.Logit(y, X_withconstant).fit_regularized()
display(logit.summary()) 

# table of significant coefficinets sorted by absolute value
coef_table = logit.summary().tables[1]
coef_df = pd.DataFrame(data=coef_table.data[1:], columns=coef_table.data[0])
coef_df['coef'] = coef_df['coef'].astype(float)
coef_df['P>|z|'] = coef_df['P>|z|'].astype(float)
coef_df['abs_coef'] = np.abs(coef_df['coef'])
coef_df.drop(0, axis='index', inplace=True)
coefs_by_mag = coef_df.sort_values(by='abs_coef', ascending=False)
coefs_by_mag = coefs_by_mag[coefs_by_mag['P>|z|'] <= 0.05]

# bar chart of feature coefficients
bar_names = coefs_by_mag['']
bar_heights = coefs_by_mag['coef']
bar_colors = np.where(bar_heights>0, 'blue', 'red')
plt.figure(figsize=(5.0, 4.0))
plt.barh(bar_names, bar_heights, color=bar_colors)
plt.xlabel('normalized coefficient')
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.650620161040217
#             Iterations: 862
#             Function evaluations: 894
#             Gradient evaluations: 862
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           review_score   No. Observations:               118315
# Model:                          Logit   Df Residuals:                   118172
# Method:                           MLE   Df Model:                          142
# Date:                Wed, 18 Mar 2020   Pseudo R-squ.:                 0.05115
# Time:                        20:23:40   Log-Likelihood:                -76978.
# converged:                       True   LL-Null:                       -81128.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ========================================================================================================================================
#                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------
# const                                                                   -0.1326    6.9e+05  -1.92e-07      1.000   -1.35e+06    1.35e+06
# review_comment_title                                                     0.2259      0.020     11.341      0.000       0.187       0.265
# review_comment_message                                                  -0.6650      0.013    -51.082      0.000      -0.691      -0.640
# payment_installments                                                     0.0008      0.003      0.299      0.765      -0.004       0.006
# payment_value                                                           -0.0013   5.49e-05    -24.223      0.000      -0.001      -0.001
# price                                                                    0.0015   6.76e-05     22.006      0.000       0.001       0.002
# freight_value                                                           -0.0006      0.001     -1.018      0.309      -0.002       0.001
# product_name_lenght                                                     -0.0025      0.001     -3.848      0.000      -0.004      -0.001
# product_description_lenght                                            9.506e-06   1.05e-05      0.908      0.364    -1.1e-05       3e-05
# product_photos_qty                                                       0.0046      0.004      1.186      0.236      -0.003       0.012
# product_weight_g                                                      4.814e-06   2.73e-06      1.763      0.078   -5.38e-07    1.02e-05
# product_length_cm                                                       -0.0013      0.000     -2.518      0.012      -0.002      -0.000
# product_height_cm                                                       -0.0022      0.001     -3.566      0.000      -0.003      -0.001
# product_width_cm                                                         0.0006      0.001      0.839      0.402      -0.001       0.002
# delay                                                                   -0.0363      0.001    -51.380      0.000      -0.038      -0.035
# customer_state_AC                                                       -0.0029    9.7e+05  -2.94e-09      1.000    -1.9e+06     1.9e+06
# customer_state_AL                                                       -0.0357   8.89e+05  -4.01e-08      1.000   -1.74e+06    1.74e+06
# customer_state_AM                                                        0.0312   8.79e+05   3.55e-08      1.000   -1.72e+06    1.72e+06
# customer_state_AP                                                       -0.1980   9.37e+05  -2.11e-07      1.000   -1.84e+06    1.84e+06
# customer_state_BA                                                       -0.0751   9.34e+05  -8.04e-08      1.000   -1.83e+06    1.83e+06
# customer_state_CE                                                       -0.0139   9.66e+05  -1.44e-08      1.000   -1.89e+06    1.89e+06
# customer_state_DF                                                        0.1080   9.63e+05   1.12e-07      1.000   -1.89e+06    1.89e+06
# customer_state_ES                                                        0.1130   9.52e+05   1.19e-07      1.000   -1.87e+06    1.87e+06
# customer_state_GO                                                        0.0590   9.13e+05   6.46e-08      1.000   -1.79e+06    1.79e+06
# customer_state_MA                                                       -0.1039   9.81e+05  -1.06e-07      1.000   -1.92e+06    1.92e+06
# customer_state_MG                                                        0.1882   9.41e+05      2e-07      1.000   -1.85e+06    1.85e+06
# customer_state_MS                                                        0.3024   9.21e+05   3.28e-07      1.000   -1.81e+06    1.81e+06
# customer_state_MT                                                       -0.0435    9.2e+05  -4.73e-08      1.000    -1.8e+06     1.8e+06
# customer_state_PA                                                       -0.1904    8.7e+05  -2.19e-07      1.000   -1.71e+06    1.71e+06
# customer_state_PB                                                        0.2203   9.94e+05   2.22e-07      1.000   -1.95e+06    1.95e+06
# customer_state_PE                                                        0.1022   9.09e+05   1.12e-07      1.000   -1.78e+06    1.78e+06
# customer_state_PI                                                       -0.0447    9.5e+05  -4.71e-08      1.000   -1.86e+06    1.86e+06
# customer_state_PR                                                        0.2163   9.74e+05   2.22e-07      1.000   -1.91e+06    1.91e+06
# customer_state_RJ                                                        0.0542   8.73e+05   6.21e-08      1.000   -1.71e+06    1.71e+06
# customer_state_RN                                                        0.1329   9.11e+05   1.46e-07      1.000   -1.79e+06    1.79e+06
# customer_state_RO                                                       -0.0747   9.53e+05  -7.84e-08      1.000   -1.87e+06    1.87e+06
# customer_state_RR                                                       -0.5184   9.36e+05  -5.54e-07      1.000   -1.83e+06    1.83e+06
# customer_state_RS                                                        0.0882   9.39e+05   9.38e-08      1.000   -1.84e+06    1.84e+06
# customer_state_SC                                                        0.1531   9.06e+05   1.69e-07      1.000   -1.78e+06    1.78e+06
# customer_state_SE                                                        0.1559   9.29e+05   1.68e-07      1.000   -1.82e+06    1.82e+06
# customer_state_SP                                                        0.3070   9.64e+05   3.19e-07      1.000   -1.89e+06    1.89e+06
# customer_state_TO                                                        0.1937   9.17e+05   2.11e-07      1.000    -1.8e+06     1.8e+06
# payment_type_boleto                                                     -0.1265   3.53e+05  -3.58e-07      1.000   -6.92e+05    6.92e+05
# payment_type_credit_card                                                -0.1708   3.82e+05  -4.46e-07      1.000    -7.5e+05     7.5e+05
# payment_type_debit_card                                                  0.0001    3.2e+05   4.02e-10      1.000   -6.27e+05    6.27e+05
# payment_type_voucher                                                    -0.3189   3.88e+05  -8.22e-07      1.000   -7.61e+05    7.61e+05
# product_category_name_agro_industria_e_comercio                          0.0691   3.04e+05   2.28e-07      1.000   -5.95e+05    5.95e+05
# product_category_name_alimentos                                          0.3285   3.43e+05   9.58e-07      1.000   -6.72e+05    6.72e+05
# product_category_name_alimentos_bebidas                                  0.3711   3.17e+05   1.17e-06      1.000   -6.21e+05    6.21e+05
# product_category_name_artes                                             -0.0768   2.95e+05   -2.6e-07      1.000   -5.79e+05    5.79e+05
# product_category_name_artes_e_artesanato                                 0.4233   3.14e+05   1.35e-06      1.000   -6.15e+05    6.15e+05
# product_category_name_artigos_de_festas                                 -0.0183   2.99e+05  -6.12e-08      1.000   -5.86e+05    5.86e+05
# product_category_name_artigos_de_natal                                  -0.0865   2.92e+05  -2.96e-07      1.000   -5.72e+05    5.72e+05
# product_category_name_audio                                             -0.0148   3.14e+05  -4.71e-08      1.000   -6.16e+05    6.16e+05
# product_category_name_automotivo                                         0.1138   2.98e+05   3.82e-07      1.000   -5.83e+05    5.83e+05
# product_category_name_bebes                                              0.0495   2.83e+05   1.75e-07      1.000   -5.55e+05    5.55e+05
# product_category_name_bebidas                                            0.0507   3.27e+05   1.55e-07      1.000   -6.41e+05    6.41e+05
# product_category_name_beleza_saude                                       0.2219   3.13e+05   7.09e-07      1.000   -6.13e+05    6.13e+05
# product_category_name_brinquedos                                         0.2692   3.02e+05   8.92e-07      1.000   -5.91e+05    5.91e+05
# product_category_name_cama_mesa_banho                                   -0.0440   2.86e+05  -1.54e-07      1.000    -5.6e+05     5.6e+05
# product_category_name_casa_conforto                                      0.2291   2.95e+05   7.76e-07      1.000   -5.78e+05    5.78e+05
# product_category_name_casa_conforto_2                                   -0.2485   3.18e+05  -7.81e-07      1.000   -6.24e+05    6.24e+05
# product_category_name_casa_construcao                                   -0.1326   3.03e+05  -4.37e-07      1.000   -5.95e+05    5.95e+05
# product_category_name_cds_dvds_musicais                                  0.6320    2.7e+05   2.34e-06      1.000   -5.29e+05    5.29e+05
# product_category_name_cine_foto                                          0.6644   3.08e+05   2.16e-06      1.000   -6.04e+05    6.04e+05
# product_category_name_climatizacao                                       0.0465   2.88e+05   1.62e-07      1.000   -5.64e+05    5.64e+05
# product_category_name_consoles_games                                    -0.0239   3.28e+05  -7.28e-08      1.000   -6.43e+05    6.43e+05
# product_category_name_construcao_ferramentas_construcao                  0.1362   2.93e+05   4.64e-07      1.000   -5.75e+05    5.75e+05
# product_category_name_construcao_ferramentas_ferramentas                 0.6060   2.87e+05   2.11e-06      1.000   -5.63e+05    5.63e+05
# product_category_name_construcao_ferramentas_iluminacao                 -0.0163   2.92e+05  -5.57e-08      1.000   -5.72e+05    5.72e+05
# product_category_name_construcao_ferramentas_jardim                      0.2847   2.94e+05   9.67e-07      1.000   -5.77e+05    5.77e+05
# product_category_name_construcao_ferramentas_seguranca                  -0.0831   3.08e+05   -2.7e-07      1.000   -6.03e+05    6.03e+05
# product_category_name_cool_stuff                                         0.1796   3.06e+05   5.87e-07      1.000      -6e+05       6e+05
# product_category_name_dvds_blu_ray                                       0.0759   3.23e+05   2.35e-07      1.000   -6.33e+05    6.33e+05
# product_category_name_eletrodomesticos                                   0.1717   3.04e+05   5.66e-07      1.000   -5.95e+05    5.95e+05
# product_category_name_eletrodomesticos_2                                 0.0522   2.94e+05   1.78e-07      1.000   -5.76e+05    5.76e+05
# product_category_name_eletronicos                                        0.0589   3.24e+05   1.82e-07      1.000   -6.34e+05    6.34e+05
# product_category_name_eletroportateis                                    0.1699   2.92e+05   5.82e-07      1.000   -5.73e+05    5.73e+05
# product_category_name_esporte_lazer                                      0.1817    3.1e+05   5.85e-07      1.000   -6.08e+05    6.08e+05
# product_category_name_fashion_bolsas_e_acessorios                        0.0708   3.24e+05   2.19e-07      1.000   -6.34e+05    6.34e+05
# product_category_name_fashion_calcados                                   0.3665   3.37e+05   1.09e-06      1.000   -6.61e+05    6.61e+05
# product_category_name_fashion_esporte                                    0.0903   3.27e+05   2.77e-07      1.000    -6.4e+05     6.4e+05
# product_category_name_fashion_roupa_feminina                            -0.5681    3.1e+05  -1.83e-06      1.000   -6.07e+05    6.07e+05
# product_category_name_fashion_roupa_infanto_juvenil                      1.4780   3.09e+05   4.78e-06      1.000   -6.06e+05    6.06e+05
# product_category_name_fashion_roupa_masculina                           -0.0407   2.91e+05   -1.4e-07      1.000    -5.7e+05     5.7e+05
# product_category_name_fashion_underwear_e_moda_praia                    -0.1138   3.24e+05  -3.51e-07      1.000   -6.35e+05    6.35e+05
# product_category_name_ferramentas_jardim                                 0.2021   2.79e+05   7.25e-07      1.000   -5.47e+05    5.47e+05
# product_category_name_flores                                             0.4484   2.99e+05    1.5e-06      1.000   -5.86e+05    5.86e+05
# product_category_name_fraldas_higiene                                   -1.1213   2.99e+05  -3.76e-06      1.000   -5.85e+05    5.85e+05
# product_category_name_industria_comercio_e_negocios                      0.1151   2.95e+05    3.9e-07      1.000   -5.78e+05    5.78e+05
# product_category_name_informatica_acessorios                            -0.0114   3.25e+05   -3.5e-08      1.000   -6.37e+05    6.37e+05
# product_category_name_instrumentos_musicais                              0.2520   3.06e+05   8.24e-07      1.000   -5.99e+05    5.99e+05
# product_category_name_la_cuisine                                         0.6767      3e+05   2.26e-06      1.000   -5.87e+05    5.87e+05
# product_category_name_livros_importados                                  0.9684   3.08e+05   3.15e-06      1.000   -6.03e+05    6.03e+05
# product_category_name_livros_interesse_geral                             0.6865   3.22e+05   2.13e-06      1.000   -6.32e+05    6.32e+05
# product_category_name_livros_tecnicos                                    0.6146   3.12e+05   1.97e-06      1.000   -6.12e+05    6.12e+05
# product_category_name_malas_acessorios                                   0.4491   2.95e+05   1.52e-06      1.000   -5.78e+05    5.78e+05
# product_category_name_market_place                                      -0.2045   3.05e+05  -6.71e-07      1.000   -5.97e+05    5.97e+05
# product_category_name_moveis_colchao_e_estofado                         -0.1311   2.92e+05  -4.49e-07      1.000   -5.72e+05    5.72e+05
# product_category_name_moveis_cozinha_area_de_servico_jantar_e_jardim    -0.1684   3.02e+05  -5.58e-07      1.000   -5.91e+05    5.91e+05
# product_category_name_moveis_decoracao                                   0.0241   2.76e+05   8.72e-08      1.000   -5.42e+05    5.42e+05
# product_category_name_moveis_escritorio                                 -0.4007   2.85e+05  -1.41e-06      1.000   -5.58e+05    5.58e+05
# product_category_name_moveis_quarto                                      0.0738   3.05e+05   2.42e-07      1.000   -5.97e+05    5.97e+05
# product_category_name_moveis_sala                                       -0.0882   3.16e+05  -2.79e-07      1.000   -6.19e+05    6.19e+05
# product_category_name_musica                                             0.1731   3.25e+05   5.33e-07      1.000   -6.37e+05    6.37e+05
# product_category_name_other                                             -0.0521   2.83e+05  -1.84e-07      1.000   -5.54e+05    5.54e+05
# product_category_name_papelaria                                          0.2743   3.05e+05   8.99e-07      1.000   -5.98e+05    5.98e+05
# product_category_name_pc_gamer                                          -1.1118   3.27e+05   -3.4e-06      1.000    -6.4e+05     6.4e+05
# product_category_name_pcs                                                0.4531   2.75e+05   1.65e-06      1.000   -5.38e+05    5.38e+05
# product_category_name_perfumaria                                         0.2985   3.16e+05   9.44e-07      1.000    -6.2e+05     6.2e+05
# product_category_name_pet_shop                                           0.2845    3.2e+05   8.88e-07      1.000   -6.28e+05    6.28e+05
# product_category_name_portateis_casa_forno_e_cafe                        0.4283    2.8e+05   1.53e-06      1.000    -5.5e+05     5.5e+05
# product_category_name_portateis_cozinha_e_preparadores_de_alimentos     -0.7831   2.84e+05  -2.76e-06      1.000   -5.56e+05    5.56e+05
# product_category_name_relogios_presentes                                 0.0363   3.12e+05   1.16e-07      1.000   -6.11e+05    6.11e+05
# product_category_name_seguros_e_servicos                                -5.2038   3.15e+05  -1.65e-05      1.000   -6.17e+05    6.17e+05
# product_category_name_sinalizacao_e_seguranca                            0.2558   2.96e+05   8.63e-07      1.000   -5.81e+05    5.81e+05
# product_category_name_tablets_impressao_imagem                          -0.1325   3.32e+05     -4e-07      1.000    -6.5e+05     6.5e+05
# product_category_name_telefonia                                         -0.0747   3.09e+05  -2.42e-07      1.000   -6.06e+05    6.06e+05
# product_category_name_telefonia_fixa                                    -0.2497   3.04e+05   -8.2e-07      1.000   -5.97e+05    5.97e+05
# product_category_name_utilidades_domesticas                              0.1283   2.96e+05   4.34e-07      1.000    -5.8e+05     5.8e+05
# seller_state_AC                                                         -5.5826   4.32e+05  -1.29e-05      1.000   -8.47e+05    8.47e+05
# seller_state_AM                                                          0.6254   4.32e+05   1.45e-06      1.000   -8.47e+05    8.47e+05
# seller_state_BA                                                          0.2012   4.32e+05   4.66e-07      1.000   -8.47e+05    8.47e+05
# seller_state_CE                                                          0.5800   4.32e+05   1.34e-06      1.000   -8.47e+05    8.47e+05
# seller_state_DF                                                          0.3239   4.32e+05    7.5e-07      1.000   -8.47e+05    8.47e+05
# seller_state_ES                                                          0.1273   4.32e+05   2.95e-07      1.000   -8.47e+05    8.47e+05
# seller_state_GO                                                          0.5186   4.32e+05    1.2e-06      1.000   -8.47e+05    8.47e+05
# seller_state_MA                                                          0.1052   4.32e+05   2.43e-07      1.000   -8.47e+05    8.47e+05
# seller_state_MG                                                          0.3015   4.32e+05   6.98e-07      1.000   -8.47e+05    8.47e+05
# seller_state_MS                                                          1.2302   4.32e+05   2.85e-06      1.000   -8.47e+05    8.47e+05
# seller_state_MT                                                          0.1423   4.32e+05   3.29e-07      1.000   -8.47e+05    8.47e+05
# seller_state_PA                                                          0.7050   4.32e+05   1.63e-06      1.000   -8.47e+05    8.47e+05
# seller_state_PB                                                          0.1333   4.32e+05   3.09e-07      1.000   -8.47e+05    8.47e+05
# seller_state_PE                                                          0.2752   4.32e+05   6.37e-07      1.000   -8.47e+05    8.47e+05
# seller_state_PI                                                          0.2741   4.32e+05   6.34e-07      1.000   -8.47e+05    8.47e+05
# seller_state_PR                                                          0.2901   4.32e+05   6.71e-07      1.000   -8.47e+05    8.47e+05
# seller_state_RJ                                                          0.3882   4.32e+05   8.98e-07      1.000   -8.47e+05    8.47e+05
# seller_state_RN                                                          0.6022   4.32e+05   1.39e-06      1.000   -8.47e+05    8.47e+05
# seller_state_RO                                                          0.0406   4.32e+05   9.39e-08      1.000   -8.47e+05    8.47e+05
# seller_state_RS                                                          0.3758   4.32e+05    8.7e-07      1.000   -8.47e+05    8.47e+05
# seller_state_SC                                                          0.2678   4.32e+05    6.2e-07      1.000   -8.47e+05    8.47e+05
# seller_state_SE                                                          0.3303   4.32e+05   7.64e-07      1.000   -8.47e+05    8.47e+05
# seller_state_SP                                                          0.2962   4.32e+05   6.85e-07      1.000   -8.47e+05    8.47e+05
# ========================================================================================================================================
# """
# Text(0.5, 0, 'normalized coefficient')

# %% [markdown]
# ### L1

# %%
# seperate target from features
X = df[df.columns[:-1]]
y = df[df.columns[-1]]

# fit regularized logit function 
import statsmodels.api as sm
X_withconstant = sm.add_constant(X)
logit = sm.Logit(y, X_withconstant).fit_regularized(method='l1')
display(logit.summary()) 

# table of significant coefficinets sorted by absolute value
coef_table = logit.summary().tables[1]
coef_df = pd.DataFrame(data=coef_table.data[1:], columns=coef_table.data[0])
coef_df['coef'] = coef_df['coef'].astype(float)
coef_df['P>|z|'] = coef_df['P>|z|'].astype(float)
coef_df['abs_coef'] = np.abs(coef_df['coef'])
coef_df.drop(0, axis='index', inplace=True)
coefs_by_mag = coef_df.sort_values(by='abs_coef', ascending=False)
coefs_by_mag = coefs_by_mag[coefs_by_mag['P>|z|'] <= 0.05]

# bar chart of feature coefficients
bar_names = coefs_by_mag['']
bar_heights = coefs_by_mag['coef']
bar_colors = np.where(bar_heights>0, 'blue', 'red')
plt.figure(figsize=(5.0, 4.0))
plt.barh(bar_names, bar_heights, color=bar_colors)
plt.xlabel('normalized coefficient')
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.650620161040217
#             Iterations: 862
#             Function evaluations: 894
#             Gradient evaluations: 862
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           review_score   No. Observations:               118315
# Model:                          Logit   Df Residuals:                   118172
# Method:                           MLE   Df Model:                          142
# Date:                Wed, 18 Mar 2020   Pseudo R-squ.:                 0.05115
# Time:                        20:39:27   Log-Likelihood:                -76978.
# converged:                       True   LL-Null:                       -81128.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ========================================================================================================================================
#                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------
# const                                                                   -0.1326    6.9e+05  -1.92e-07      1.000   -1.35e+06    1.35e+06
# review_comment_title                                                     0.2259      0.020     11.341      0.000       0.187       0.265
# review_comment_message                                                  -0.6650      0.013    -51.082      0.000      -0.691      -0.640
# payment_installments                                                     0.0008      0.003      0.299      0.765      -0.004       0.006
# payment_value                                                           -0.0013   5.49e-05    -24.223      0.000      -0.001      -0.001
# price                                                                    0.0015   6.76e-05     22.006      0.000       0.001       0.002
# freight_value                                                           -0.0006      0.001     -1.018      0.309      -0.002       0.001
# product_name_lenght                                                     -0.0025      0.001     -3.848      0.000      -0.004      -0.001
# product_description_lenght                                            9.506e-06   1.05e-05      0.908      0.364    -1.1e-05       3e-05
# product_photos_qty                                                       0.0046      0.004      1.186      0.236      -0.003       0.012
# product_weight_g                                                      4.814e-06   2.73e-06      1.763      0.078   -5.38e-07    1.02e-05
# product_length_cm                                                       -0.0013      0.000     -2.518      0.012      -0.002      -0.000
# product_height_cm                                                       -0.0022      0.001     -3.566      0.000      -0.003      -0.001
# product_width_cm                                                         0.0006      0.001      0.839      0.402      -0.001       0.002
# delay                                                                   -0.0363      0.001    -51.380      0.000      -0.038      -0.035
# customer_state_AC                                                       -0.0029    9.7e+05  -2.94e-09      1.000    -1.9e+06     1.9e+06
# customer_state_AL                                                       -0.0357   8.89e+05  -4.01e-08      1.000   -1.74e+06    1.74e+06
# customer_state_AM                                                        0.0312   8.79e+05   3.55e-08      1.000   -1.72e+06    1.72e+06
# customer_state_AP                                                       -0.1980   9.37e+05  -2.11e-07      1.000   -1.84e+06    1.84e+06
# customer_state_BA                                                       -0.0751   9.34e+05  -8.04e-08      1.000   -1.83e+06    1.83e+06
# customer_state_CE                                                       -0.0139   9.66e+05  -1.44e-08      1.000   -1.89e+06    1.89e+06
# customer_state_DF                                                        0.1080   9.63e+05   1.12e-07      1.000   -1.89e+06    1.89e+06
# customer_state_ES                                                        0.1130   9.52e+05   1.19e-07      1.000   -1.87e+06    1.87e+06
# customer_state_GO                                                        0.0590   9.13e+05   6.46e-08      1.000   -1.79e+06    1.79e+06
# customer_state_MA                                                       -0.1039   9.81e+05  -1.06e-07      1.000   -1.92e+06    1.92e+06
# customer_state_MG                                                        0.1882   9.41e+05      2e-07      1.000   -1.85e+06    1.85e+06
# customer_state_MS                                                        0.3024   9.21e+05   3.28e-07      1.000   -1.81e+06    1.81e+06
# customer_state_MT                                                       -0.0435    9.2e+05  -4.73e-08      1.000    -1.8e+06     1.8e+06
# customer_state_PA                                                       -0.1904    8.7e+05  -2.19e-07      1.000   -1.71e+06    1.71e+06
# customer_state_PB                                                        0.2203   9.94e+05   2.22e-07      1.000   -1.95e+06    1.95e+06
# customer_state_PE                                                        0.1022   9.09e+05   1.12e-07      1.000   -1.78e+06    1.78e+06
# customer_state_PI                                                       -0.0447    9.5e+05  -4.71e-08      1.000   -1.86e+06    1.86e+06
# customer_state_PR                                                        0.2163   9.74e+05   2.22e-07      1.000   -1.91e+06    1.91e+06
# customer_state_RJ                                                        0.0542   8.73e+05   6.21e-08      1.000   -1.71e+06    1.71e+06
# customer_state_RN                                                        0.1329   9.11e+05   1.46e-07      1.000   -1.79e+06    1.79e+06
# customer_state_RO                                                       -0.0747   9.53e+05  -7.84e-08      1.000   -1.87e+06    1.87e+06
# customer_state_RR                                                       -0.5184   9.36e+05  -5.54e-07      1.000   -1.83e+06    1.83e+06
# customer_state_RS                                                        0.0882   9.39e+05   9.38e-08      1.000   -1.84e+06    1.84e+06
# customer_state_SC                                                        0.1531   9.06e+05   1.69e-07      1.000   -1.78e+06    1.78e+06
# customer_state_SE                                                        0.1559   9.29e+05   1.68e-07      1.000   -1.82e+06    1.82e+06
# customer_state_SP                                                        0.3070   9.64e+05   3.19e-07      1.000   -1.89e+06    1.89e+06
# customer_state_TO                                                        0.1937   9.17e+05   2.11e-07      1.000    -1.8e+06     1.8e+06
# payment_type_boleto                                                     -0.1265   3.53e+05  -3.58e-07      1.000   -6.92e+05    6.92e+05
# payment_type_credit_card                                                -0.1708   3.82e+05  -4.46e-07      1.000    -7.5e+05     7.5e+05
# payment_type_debit_card                                                  0.0001    3.2e+05   4.02e-10      1.000   -6.27e+05    6.27e+05
# payment_type_voucher                                                    -0.3189   3.88e+05  -8.22e-07      1.000   -7.61e+05    7.61e+05
# product_category_name_agro_industria_e_comercio                          0.0691   3.04e+05   2.28e-07      1.000   -5.95e+05    5.95e+05
# product_category_name_alimentos                                          0.3285   3.43e+05   9.58e-07      1.000   -6.72e+05    6.72e+05
# product_category_name_alimentos_bebidas                                  0.3711   3.17e+05   1.17e-06      1.000   -6.21e+05    6.21e+05
# product_category_name_artes                                             -0.0768   2.95e+05   -2.6e-07      1.000   -5.79e+05    5.79e+05
# product_category_name_artes_e_artesanato                                 0.4233   3.14e+05   1.35e-06      1.000   -6.15e+05    6.15e+05
# product_category_name_artigos_de_festas                                 -0.0183   2.99e+05  -6.12e-08      1.000   -5.86e+05    5.86e+05
# product_category_name_artigos_de_natal                                  -0.0865   2.92e+05  -2.96e-07      1.000   -5.72e+05    5.72e+05
# product_category_name_audio                                             -0.0148   3.14e+05  -4.71e-08      1.000   -6.16e+05    6.16e+05
# product_category_name_automotivo                                         0.1138   2.98e+05   3.82e-07      1.000   -5.83e+05    5.83e+05
# product_category_name_bebes                                              0.0495   2.83e+05   1.75e-07      1.000   -5.55e+05    5.55e+05
# product_category_name_bebidas                                            0.0507   3.27e+05   1.55e-07      1.000   -6.41e+05    6.41e+05
# product_category_name_beleza_saude                                       0.2219   3.13e+05   7.09e-07      1.000   -6.13e+05    6.13e+05
# product_category_name_brinquedos                                         0.2692   3.02e+05   8.92e-07      1.000   -5.91e+05    5.91e+05
# product_category_name_cama_mesa_banho                                   -0.0440   2.86e+05  -1.54e-07      1.000    -5.6e+05     5.6e+05
# product_category_name_casa_conforto                                      0.2291   2.95e+05   7.76e-07      1.000   -5.78e+05    5.78e+05
# product_category_name_casa_conforto_2                                   -0.2485   3.18e+05  -7.81e-07      1.000   -6.24e+05    6.24e+05
# product_category_name_casa_construcao                                   -0.1326   3.03e+05  -4.37e-07      1.000   -5.95e+05    5.95e+05
# product_category_name_cds_dvds_musicais                                  0.6320    2.7e+05   2.34e-06      1.000   -5.29e+05    5.29e+05
# product_category_name_cine_foto                                          0.6644   3.08e+05   2.16e-06      1.000   -6.04e+05    6.04e+05
# product_category_name_climatizacao                                       0.0465   2.88e+05   1.62e-07      1.000   -5.64e+05    5.64e+05
# product_category_name_consoles_games                                    -0.0239   3.28e+05  -7.28e-08      1.000   -6.43e+05    6.43e+05
# product_category_name_construcao_ferramentas_construcao                  0.1362   2.93e+05   4.64e-07      1.000   -5.75e+05    5.75e+05
# product_category_name_construcao_ferramentas_ferramentas                 0.6060   2.87e+05   2.11e-06      1.000   -5.63e+05    5.63e+05
# product_category_name_construcao_ferramentas_iluminacao                 -0.0163   2.92e+05  -5.57e-08      1.000   -5.72e+05    5.72e+05
# product_category_name_construcao_ferramentas_jardim                      0.2847   2.94e+05   9.67e-07      1.000   -5.77e+05    5.77e+05
# product_category_name_construcao_ferramentas_seguranca                  -0.0831   3.08e+05   -2.7e-07      1.000   -6.03e+05    6.03e+05
# product_category_name_cool_stuff                                         0.1796   3.06e+05   5.87e-07      1.000      -6e+05       6e+05
# product_category_name_dvds_blu_ray                                       0.0759   3.23e+05   2.35e-07      1.000   -6.33e+05    6.33e+05
# product_category_name_eletrodomesticos                                   0.1717   3.04e+05   5.66e-07      1.000   -5.95e+05    5.95e+05
# product_category_name_eletrodomesticos_2                                 0.0522   2.94e+05   1.78e-07      1.000   -5.76e+05    5.76e+05
# product_category_name_eletronicos                                        0.0589   3.24e+05   1.82e-07      1.000   -6.34e+05    6.34e+05
# product_category_name_eletroportateis                                    0.1699   2.92e+05   5.82e-07      1.000   -5.73e+05    5.73e+05
# product_category_name_esporte_lazer                                      0.1817    3.1e+05   5.85e-07      1.000   -6.08e+05    6.08e+05
# product_category_name_fashion_bolsas_e_acessorios                        0.0708   3.24e+05   2.19e-07      1.000   -6.34e+05    6.34e+05
# product_category_name_fashion_calcados                                   0.3665   3.37e+05   1.09e-06      1.000   -6.61e+05    6.61e+05
# product_category_name_fashion_esporte                                    0.0903   3.27e+05   2.77e-07      1.000    -6.4e+05     6.4e+05
# product_category_name_fashion_roupa_feminina                            -0.5681    3.1e+05  -1.83e-06      1.000   -6.07e+05    6.07e+05
# product_category_name_fashion_roupa_infanto_juvenil                      1.4780   3.09e+05   4.78e-06      1.000   -6.06e+05    6.06e+05
# product_category_name_fashion_roupa_masculina                           -0.0407   2.91e+05   -1.4e-07      1.000    -5.7e+05     5.7e+05
# product_category_name_fashion_underwear_e_moda_praia                    -0.1138   3.24e+05  -3.51e-07      1.000   -6.35e+05    6.35e+05
# product_category_name_ferramentas_jardim                                 0.2021   2.79e+05   7.25e-07      1.000   -5.47e+05    5.47e+05
# product_category_name_flores                                             0.4484   2.99e+05    1.5e-06      1.000   -5.86e+05    5.86e+05
# product_category_name_fraldas_higiene                                   -1.1213   2.99e+05  -3.76e-06      1.000   -5.85e+05    5.85e+05
# product_category_name_industria_comercio_e_negocios                      0.1151   2.95e+05    3.9e-07      1.000   -5.78e+05    5.78e+05
# product_category_name_informatica_acessorios                            -0.0114   3.25e+05   -3.5e-08      1.000   -6.37e+05    6.37e+05
# product_category_name_instrumentos_musicais                              0.2520   3.06e+05   8.24e-07      1.000   -5.99e+05    5.99e+05
# product_category_name_la_cuisine                                         0.6767      3e+05   2.26e-06      1.000   -5.87e+05    5.87e+05
# product_category_name_livros_importados                                  0.9684   3.08e+05   3.15e-06      1.000   -6.03e+05    6.03e+05
# product_category_name_livros_interesse_geral                             0.6865   3.22e+05   2.13e-06      1.000   -6.32e+05    6.32e+05
# product_category_name_livros_tecnicos                                    0.6146   3.12e+05   1.97e-06      1.000   -6.12e+05    6.12e+05
# product_category_name_malas_acessorios                                   0.4491   2.95e+05   1.52e-06      1.000   -5.78e+05    5.78e+05
# product_category_name_market_place                                      -0.2045   3.05e+05  -6.71e-07      1.000   -5.97e+05    5.97e+05
# product_category_name_moveis_colchao_e_estofado                         -0.1311   2.92e+05  -4.49e-07      1.000   -5.72e+05    5.72e+05
# product_category_name_moveis_cozinha_area_de_servico_jantar_e_jardim    -0.1684   3.02e+05  -5.58e-07      1.000   -5.91e+05    5.91e+05
# product_category_name_moveis_decoracao                                   0.0241   2.76e+05   8.72e-08      1.000   -5.42e+05    5.42e+05
# product_category_name_moveis_escritorio                                 -0.4007   2.85e+05  -1.41e-06      1.000   -5.58e+05    5.58e+05
# product_category_name_moveis_quarto                                      0.0738   3.05e+05   2.42e-07      1.000   -5.97e+05    5.97e+05
# product_category_name_moveis_sala                                       -0.0882   3.16e+05  -2.79e-07      1.000   -6.19e+05    6.19e+05
# product_category_name_musica                                             0.1731   3.25e+05   5.33e-07      1.000   -6.37e+05    6.37e+05
# product_category_name_other                                             -0.0521   2.83e+05  -1.84e-07      1.000   -5.54e+05    5.54e+05
# product_category_name_papelaria                                          0.2743   3.05e+05   8.99e-07      1.000   -5.98e+05    5.98e+05
# product_category_name_pc_gamer                                          -1.1118   3.27e+05   -3.4e-06      1.000    -6.4e+05     6.4e+05
# product_category_name_pcs                                                0.4531   2.75e+05   1.65e-06      1.000   -5.38e+05    5.38e+05
# product_category_name_perfumaria                                         0.2985   3.16e+05   9.44e-07      1.000    -6.2e+05     6.2e+05
# product_category_name_pet_shop                                           0.2845    3.2e+05   8.88e-07      1.000   -6.28e+05    6.28e+05
# product_category_name_portateis_casa_forno_e_cafe                        0.4283    2.8e+05   1.53e-06      1.000    -5.5e+05     5.5e+05
# product_category_name_portateis_cozinha_e_preparadores_de_alimentos     -0.7831   2.84e+05  -2.76e-06      1.000   -5.56e+05    5.56e+05
# product_category_name_relogios_presentes                                 0.0363   3.12e+05   1.16e-07      1.000   -6.11e+05    6.11e+05
# product_category_name_seguros_e_servicos                                -5.2038   3.15e+05  -1.65e-05      1.000   -6.17e+05    6.17e+05
# product_category_name_sinalizacao_e_seguranca                            0.2558   2.96e+05   8.63e-07      1.000   -5.81e+05    5.81e+05
# product_category_name_tablets_impressao_imagem                          -0.1325   3.32e+05     -4e-07      1.000    -6.5e+05     6.5e+05
# product_category_name_telefonia                                         -0.0747   3.09e+05  -2.42e-07      1.000   -6.06e+05    6.06e+05
# product_category_name_telefonia_fixa                                    -0.2497   3.04e+05   -8.2e-07      1.000   -5.97e+05    5.97e+05
# product_category_name_utilidades_domesticas                              0.1283   2.96e+05   4.34e-07      1.000    -5.8e+05     5.8e+05
# seller_state_AC                                                         -5.5826   4.32e+05  -1.29e-05      1.000   -8.47e+05    8.47e+05
# seller_state_AM                                                          0.6254   4.32e+05   1.45e-06      1.000   -8.47e+05    8.47e+05
# seller_state_BA                                                          0.2012   4.32e+05   4.66e-07      1.000   -8.47e+05    8.47e+05
# seller_state_CE                                                          0.5800   4.32e+05   1.34e-06      1.000   -8.47e+05    8.47e+05
# seller_state_DF                                                          0.3239   4.32e+05    7.5e-07      1.000   -8.47e+05    8.47e+05
# seller_state_ES                                                          0.1273   4.32e+05   2.95e-07      1.000   -8.47e+05    8.47e+05
# seller_state_GO                                                          0.5186   4.32e+05    1.2e-06      1.000   -8.47e+05    8.47e+05
# seller_state_MA                                                          0.1052   4.32e+05   2.43e-07      1.000   -8.47e+05    8.47e+05
# seller_state_MG                                                          0.3015   4.32e+05   6.98e-07      1.000   -8.47e+05    8.47e+05
# seller_state_MS                                                          1.2302   4.32e+05   2.85e-06      1.000   -8.47e+05    8.47e+05
# seller_state_MT                                                          0.1423   4.32e+05   3.29e-07      1.000   -8.47e+05    8.47e+05
# seller_state_PA                                                          0.7050   4.32e+05   1.63e-06      1.000   -8.47e+05    8.47e+05
# seller_state_PB                                                          0.1333   4.32e+05   3.09e-07      1.000   -8.47e+05    8.47e+05
# seller_state_PE                                                          0.2752   4.32e+05   6.37e-07      1.000   -8.47e+05    8.47e+05
# seller_state_PI                                                          0.2741   4.32e+05   6.34e-07      1.000   -8.47e+05    8.47e+05
# seller_state_PR                                                          0.2901   4.32e+05   6.71e-07      1.000   -8.47e+05    8.47e+05
# seller_state_RJ                                                          0.3882   4.32e+05   8.98e-07      1.000   -8.47e+05    8.47e+05
# seller_state_RN                                                          0.6022   4.32e+05   1.39e-06      1.000   -8.47e+05    8.47e+05
# seller_state_RO                                                          0.0406   4.32e+05   9.39e-08      1.000   -8.47e+05    8.47e+05
# seller_state_RS                                                          0.3758   4.32e+05    8.7e-07      1.000   -8.47e+05    8.47e+05
# seller_state_SC                                                          0.2678   4.32e+05    6.2e-07      1.000   -8.47e+05    8.47e+05
# seller_state_SE                                                          0.3303   4.32e+05   7.64e-07      1.000   -8.47e+05    8.47e+05
# seller_state_SP                                                          0.2962   4.32e+05   6.85e-07      1.000   -8.47e+05    8.47e+05
# ========================================================================================================================================
# """
# Text(0.5, 0, 'normalized coefficient')

# %% [markdown]
# ## Overcharge Modeling

# %%
payment_value_df = pd.DataFrame(payment_df.groupby('order_id')['payment_value'].sum())
payment_value_df
# Out:
#                                   payment_value
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214          72.19
# 00018f77f2f0320c557190d7a144bdd3         259.83
# 000229ec398224ef6ca0657da4fc703e         216.87
# 00024acbcdf0a6daa1e931b038114c75          25.78
# 00042b26cf59d7ce69dfabb4e55b4fd9         218.04
# ...                                         ...
# fffc94f6ce00a00581880bf54a75a037         343.40
# fffcd46ef2263f404302a634eb57f7eb         386.53
# fffce4705a9662cd70adb13d4a31832d         116.85
# fffe18544ffabc95dfada21779c9644f          64.71
# fffe41c64501cc87c801fd61db3f6244          55.79
#
# [99440 rows x 1 columns]

# %%
price_df = pd.DataFrame(item_df.groupby('order_id')['price'].sum())
price_df
# Out:
#                                    price
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214   58.90
# 00018f77f2f0320c557190d7a144bdd3  239.90
# 000229ec398224ef6ca0657da4fc703e  199.00
# 00024acbcdf0a6daa1e931b038114c75   12.99
# 00042b26cf59d7ce69dfabb4e55b4fd9  199.90
# ...                                  ...
# fffc94f6ce00a00581880bf54a75a037  299.99
# fffcd46ef2263f404302a634eb57f7eb  350.00
# fffce4705a9662cd70adb13d4a31832d   99.90
# fffe18544ffabc95dfada21779c9644f   55.99
# fffe41c64501cc87c801fd61db3f6244   43.00
#
# [98666 rows x 1 columns]

# %%
payment_price_df = pd.merge(payment_value_df, price_df, how='left', left_index=True, right_index=True)
payment_price_df['overcharge'] = payment_price_df.payment_value - payment_price_df.price
payment_price_df
# Out:
#                                   payment_value   price  overcharge
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214          72.19   58.90       13.29
# 00018f77f2f0320c557190d7a144bdd3         259.83  239.90       19.93
# 000229ec398224ef6ca0657da4fc703e         216.87  199.00       17.87
# 00024acbcdf0a6daa1e931b038114c75          25.78   12.99       12.79
# 00042b26cf59d7ce69dfabb4e55b4fd9         218.04  199.90       18.14
# ...                                         ...     ...         ...
# fffc94f6ce00a00581880bf54a75a037         343.40  299.99       43.41
# fffcd46ef2263f404302a634eb57f7eb         386.53  350.00       36.53
# fffce4705a9662cd70adb13d4a31832d         116.85   99.90       16.95
# fffe18544ffabc95dfada21779c9644f          64.71   55.99        8.72
# fffe41c64501cc87c801fd61db3f6244          55.79   43.00       12.79
#
# [99440 rows x 3 columns]

# %%
payment_price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99440 entries, 00010242fe8c5a6d1ba2dd792cb16214 to fffe41c64501cc87c801fd61db3f6244
# Data columns (total 3 columns):
# payment_value    99440 non-null float64
# price            98665 non-null float64
# overcharge       98665 non-null float64
# dtypes: float64(3)
# memory usage: 5.5+ MB

# %%
plt.hist(payment_price_df.overcharge, bins=100);

# %%
print(payment_price_df.overcharge.min())
print(payment_price_df.overcharge.max())
# Out:
# -5.170000000000016
# 1794.96

# %%
rocpips_df = pd.merge(rocpips_df, pd.DataFrame(payment_price_df.overcharge), how='left', left_on='order_id', right_index=True)
rocpips_df
# Out:
#                                 order_id  review_score  review_comment_title  \
# 0       73fc7af87114b39712e6da79b0a377eb             4                     0
# 1       73fc7af87114b39712e6da79b0a377eb             4                     0
# 2       19721d59a9764437477eff0730b48665             5                     0
# 3       efd626e6a12a82d76e456e34093f8356             5                     0
# 4       b0bc656fed47584c160f8cff2d7b8bbd             5                     0
# ...                                  ...           ...                   ...
# 118310  8c1d27c10cc60cc369a428813bb71350             4                     1
# 118311  80ba449ea98f8e879a829759b5a66294             5                     0
# 118312  5fd71cc4eb69ae6f65ac3acfcbc17ab5             5                     0
# 118313  61d5f1dcdf9b023ea7622b65d2362e4f             1                     0
# 118314  5f4a120717a4d152577d7d2ec66c45be             5                     0
#
#         review_comment_message customer_state payment_type  \
# 0                            0             SP  credit_card
# 1                            0             SP  credit_card
# 2                            0             RS  credit_card
# 3                            0             MG  credit_card
# 4                            0             MG  credit_card
# ...                        ...            ...          ...
# 118310                       1             MG  credit_card
# 118311                       0             GO  credit_card
# 118312                       0             RJ  credit_card
# 118313                       1             SP  credit_card
# 118314                       0             RJ  credit_card
#
#         payment_installments  payment_value  price  freight_value  ...  \
# 0                          8         397.26  185.0          13.63  ...
# 1                          8         397.26  185.0          13.63  ...
# 2                          3         205.26  185.0          20.26  ...
# 3                          2         202.05  185.0          17.05  ...
# 4                          1         306.40  135.0          18.20  ...
# ...                      ...            ...    ...            ...  ...
# 118310                     1         108.63   89.9          18.73  ...
# 118311                     4         327.25  289.9          37.35  ...
# 118312                     2          98.34   79.9          18.44  ...
# 118313                     8         767.69  750.0          17.69  ...
# 118314                     3         201.34  161.0          40.34  ...
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 0                           858.0                 1.0            1300.0
# 1                           858.0                 1.0            1300.0
# 2                           858.0                 1.0            1300.0
# 3                           858.0                 1.0            1300.0
# 4                           858.0                 1.0            1600.0
# ...                           ...                 ...               ...
# 118310                     1141.0                 2.0             450.0
# 118311                      696.0                 1.0             692.0
# 118312                      609.0                 2.0             575.0
# 118313                      381.0                 4.0             350.0
# 118314                      245.0                 1.0            4000.0
#
#         product_length_cm  product_height_cm  product_width_cm  seller_state  \
# 0                    30.0               30.0              35.0            SP
# 1                    30.0               30.0              35.0            SP
# 2                    30.0               30.0              35.0            SP
# 3                    30.0               30.0              35.0            SP
# 4                    30.0               30.0              35.0            SP
# ...                   ...                ...               ...           ...
# 118310               16.0               16.0              16.0            SP
# 118311               15.0               12.0              14.0            PR
# 118312               45.0               21.0              23.0            SP
# 118313               20.0               20.0              20.0            SP
# 118314               31.0               42.0              43.0            PR
#
#         delay overcharge_x  overcharge_y
# 0       -16.0        27.26         27.26
# 1       -16.0        27.26         27.26
# 2       -18.0        20.26         20.26
# 3       -12.0        17.05         17.05
# 4        -7.0        36.40         36.40
# ...       ...          ...           ...
# 118310  -14.0        18.73         18.73
# 118311  -15.0        37.35         37.35
# 118312  -14.0        18.44         18.44
# 118313   -7.0        17.69         17.69
# 118314  -24.0        40.34         40.34
#
# [118315 rows x 22 columns]

# %%
from scipy import stats
corr_array=[]
for i in range(df.shape[1]-1):  
    corr_array.append([df.columns[i],
                       np.abs(stats.pearsonr(df[df.columns[i]], df[df.columns[-1]])[0]),
                       stats.pearsonr(df[df.columns[i]], df[df.columns[-1]])[0],
                       stats.pearsonr(df[df.columns[i]], df[df.columns[-1]])[1]])
    
corr_df = pd.DataFrame(corr_array, columns = ['feature', 'abs_corr', 'corr', 'p_value'])
corr_df.sort_values(by='abs_corr', ascending=False, inplace=True)
corr_df.reset_index(drop=True, inplace=True)
corr_df

# variance inflation factors
from statsmodels.stats.outliers_influence import variance_inflation_factor
VIF_series = pd.Series([variance_inflation_factor(X.values, i) for i in range(X.shape[1])], index=X.columns)
VIF_series.sort_values(ascending=False, inplace=True)

VIF_df = pd.DataFrame(VIF_series, columns=['vif'])
VIF_df

# %%
import statsmodels.api as sm
X_withconstant = sm.add_constant(X)
logit = sm.Logit(y, X_withconstant).fit()
summary = logit.summary()
display(summary)

# %% [markdown]
# ## Review Dataset

# %%
review_df = pd.read_csv('olist_order_reviews_dataset.csv')
review_df.info()

# %%
df.groupby('review_score').mean()

# %%
plt.bar(df.columns[:-1], df.groupby('review_score').mean().iloc[0])

# %%
review_df[review_df.duplicated()]

# %%
review_df.drop(['review_id', 'review_creation_date', 'review_answer_timestamp'], axis='columns', inplace=True)
review_df.columns

# %%
for columns in ['review_comment_title', 'review_comment_message']:
    # replace present values with 1
    review_df.loc[review_df[columns].notnull(), columns] = 1
    # replace null values with 0
    review_df.loc[review_df[columns].isna(), columns] = 0
review_df.info()

# %%
review_df.head()

# %%
review_df.nunique()

# %%
plt.bar(payment_df.groupby('payment_type').sum().index, 
        payment_df.groupby('payment_type').sum()['payment_value']/payment_df.groupby('payment_type').count()['payment_value']);

# %%
plt.scatter(payment_df.payment_installments, payment_df.payment_value);

# %%
plt.hist(review_df.review_score);

# %%
po_df = pd.merge(payment_df, order_df, how='left', on='order_id')
po_df.info()
po_df.head()

# %%
poc_df = pd.merge(po_df, customer_df, how='left', on='customer_id')
poc_df.drop('customer_id', axis='columns', inplace=True)
poc_df.info()
poc_df.head()

# %%
state_pay_series = poc_df.groupby('customer_state').sum()['payment_value']/poc_df.groupby('customer_state').count()['payment_value']
state_pay_series.sort_values(inplace=True, ascending=False)
plt.bar(state_pay_series.index, state_pay_series);

# %%
poci_df = pd.merge(poc_df, item_df, how='right', on='order_id')
poci_df.info()

# %%
poci_df.drop(poci_df[poci_df.payment_value.isnull()].index, axis='index', inplace=True)
poci_df.info()

# %%
pocip_df = pd.merge(poci_df, product_df, how='left', on='product_id')
pocip_df.drop('product_id', axis='columns', inplace=True)
pocip_df.info()
pocip_df.head()

# %%
#df = pd.merge(df, translation_df, how='left', on='product_category_name')
#df.drop('product_category_name', axis='columns', inplace=True)
#df.head()

# %%
payment_by_category = pocip_df.groupby('product_category_name')['payment_value'].sum()
payment_by_category.sort_values(ascending=False, inplace=True)
plt.figure(figsize=(12,20))
plt.barh(payment_by_category.index, payment_by_category)

# %%
pocipr_df = pd.merge(pocip_df, review_df, how='right', on='order_id')
pocipr_df.info()
pocipr_df.head()

# %%
pocipr_df.drop(pocipr_df[pocipr_df.payment_value.isnull()].index, axis='index', inplace=True)
pocipr_df.info()

# %% [markdown]
# # Feature Engineering

# %%
pocipr_df['purchase_date'] = pocipr_df['order_purchase_timestamp'].dt.date
pocipr_df['delay'] = (pocipr_df.order_delivered_customer_date - pocipr_df.order_estimated_delivery_date).dt.days
pocipr_df.drop(['order_purchase_timestamp', 'order_delivered_customer_date', 'order_estimated_delivery_date'], axis='columns', inplace=True)
pocipr_df.head()

# %%
pocipr_df.info()

# %%
pocipr_df.fillna(pocipr_df.median(), inplace=True)

# %%
pocipr_df.info()

# %%
plt.hist(pocipr_df.delay, bins=50);

# %%
plt.scatter(pocipr_df.purchase_date, pocipr_df.delay);

# %%
pocipr_df.head()

# %%
pocipr_df1 = pocipr_df[(date(2016,10,1) <= pocipr_df.purchase_date) & (pocipr_df.purchase_date < date(2018,4,1))]
pocipr_df2 = pocipr_df[(date(2018,4,1) <= pocipr_df.purchase_date) & (pocipr_df.purchase_date < date(2018,10,1))]
pocipr_df2 = pocipr_df2[['customer_unique_id', 'payment_value']]

# %%
pocipr_df1

# %%
pocipr_df2

# %% [markdown]
# # Exploratory Data Analytics

# %%
cust_pocipr_df1 = pocipr_df1.groupby('customer_unique_id').agg({'purchase_date': lambda x: min((max(pocipr_df1.purchase_date)-x).dt.days),  
                                                    'order_id': 'count',
                                                    'payment_value': 'sum',
                                                    'delay': 'mean',
                                                    'payment_installments': 'mean',
                                                    'review_score': 'mean',
                                                    'review_comment_title': 'mean',
                                                    'review_comment_message': 'mean',
                                           'payment_type': lambda x: x.value_counts().index[0],
                                           'product_category_name': lambda x: x.value_counts().index[0],
                                                'customer_state': lambda x: x.value_counts().index[0]})

# %%
cust_pocipr_df1.columns = ['recency', 'frequency', 'monetary', 'delay', 'installments', 'review_score', 'comment_title', 'comment_message',
            'pop_payment_type', 'pop_category', 'customer_state']

cust_pocipr_df1

# %%
cust_pocipr_df1.head()

# %%
cust_pocipr_df1.to_csv('cust_pocipr_df1.csv', index=True);
#cust_pocipr_df1 = pd.read_csv('cust_pocipr_df1.csv', index_col=0)

# %%
cust_pocipr_df1

# %%
#cust_pocipr_df1['customer_state'] = pocipr_df1.groupby('customer_unique_id').agg({'customer_state': lambda x: x.value_counts().index[0]})
#cust_pocipr_df1

# %%
#cust_pocipr_df1 = pd.merge(cust_pocipr_df1, customer_df.set_index('customer_unique_id')['customer_state'], how='left', left_index=True, right_index=True)
#cust_pocipr_df1

# %%
cust_pocipr_df1

# %%
feature_df = pd.get_dummies(cust_pocipr_df1)
feature_df

# %%
target_df = pocipr_df2.groupby('customer_unique_id').agg({'payment_value':'sum'})
target_df

# %%
df = pd.merge(feature_df, target_df, on='customer_unique_id')
df.info()
df.head()

# %%
df = df.loc[:, (df != df.iloc[0]).any()]

# %% [markdown]
# ## Corrlation Analysis

# %%
from scipy import stats
corr_array=[]
for i in range(df.shape[1]-1):  
    corr_array.append([df.columns[i], 
    np.abs(stats.pearsonr(df[df.columns[i]], df.payment_value)[0]),
    stats.pearsonr(df[df.columns[i]], df.payment_value)[0],
    stats.pearsonr(df[df.columns[i]], df.payment_value)[1]])
    
    
    
corr_df = pd.DataFrame(corr_array, columns = ['Info', 'abs_corr', 'corr', 'p_value'])
corr_df.sort_values(by = 'abs_corr', ascending = False, inplace = True)
corr_df.reset_index(drop = True, inplace = True)
corr_df

# %%
plt.scatter(df.monetary, df.payment_value)

# %%
plt.scatter(df.frequency, df.payment_value)

# %%
plt.scatter(df.installments, df.payment_value)

# %%
plt.scatter(df.pop_category_relogios_presentes, df.payment_value)

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# logistic regression 
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
print('Train Accuracy: ', lr.score(X_train, y_train))
print('Test Accuracy: ', lr.score(X_test, y_test))

# %% [markdown]
# ## Quartile-based

# %%
df_q4 = df
df_q4.payment_value = pd.qcut(df_q4.payment_value, 4, labels=[1, 2, 3, 4])
df_q4

# %%
from scipy import stats
corr_array=[]
for i in range(df_q4.shape[1]-1):  
    corr_array.append([df_q4.columns[i], 
    np.abs(stats.pearsonr(df_q4[df_q4.columns[i]], df_q4.payment_value)[0]),
    stats.pearsonr(df_q4[df_q4.columns[i]], df_q4.payment_value)[0],
    stats.pearsonr(df_q4[df_q4.columns[i]], df_q4.payment_value)[1]])
        
corr_df_q4 = pd.DataFrame(corr_array, columns = ['Info', 'abs_corr', 'corr', 'p_value'])
corr_df_q4.sort_values(by = 'abs_corr', ascending = False, inplace = True)
corr_df_q4.reset_index(drop = True, inplace = True)
corr_df_q4

# %% [markdown]
# ## Binary

# %%
df_q2 = df
df_q2.payment_value = pd.qcut(df_q2.payment_value, 2, labels=[0, 1])
df_q2

# %%
from scipy import stats
corr_array=[]
for i in range(df_q2.shape[1]-1):  
    corr_array.append([df_q2.columns[i], 
    np.abs(stats.pearsonr(df_q2[df_q2.columns[i]], df_q2.payment_value)[0]),
    stats.pearsonr(df_q2[df_q2.columns[i]], df_q2.payment_value)[0],
    stats.pearsonr(df_q2[df_q2.columns[i]], df_q2.payment_value)[1]])
        
corr_df_q2 = pd.DataFrame(corr_array, columns = ['Info', 'abs_corr', 'corr', 'p_value'])
corr_df_q2.sort_values(by = 'abs_corr', ascending = False, inplace = True)
corr_df_q2.reset_index(drop = True, inplace = True)
corr_df_q2

# %%
plt.scatter(common_customer_df.review_score, common_customer_df.payment_value)

# %%
plt.scatter(common_cust.delay, common_cust.payment_value)

# %%
boleto_series = common_cust.loc[common_cust.payment_type_boleto==1, 'payment_value']
credit_series = common_cust.loc[common_cust.payment_type_credit_card==1, 'payment_value']
debit_series = common_cust.loc[common_cust.payment_type_debit_card==1, 'payment_value']
voucher_series = common_cust.loc[common_cust.payment_type_voucher==1, 'payment_value']

type_dict = {}
type_dict['boleto'] = boleto_series.sum()/boleto_series.count()
type_dict['credit'] = credit_series.sum()/credit_series.count()
type_dict['debit'] = debit_series.sum()/debit_series.count()
type_dict['voucher'] = voucher_series.sum()/voucher_series.count()

type_dict

# %%
X = common_cust.iloc[:,:-1]
y = common_cust.iloc[:,-1]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# logistic regression 
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
print('Train Accuracy: ', lr.score(X_train, y_train))
print('Test Accuracy: ', lr.score(X_test, y_test))

from sklearn.model_selection import cross_val_score
print('CV Score:', np.mean(cross_val_score(lr, X_train, y_train, cv = 5)))

# %%
rfm1_df = poc1_df.groupby('customer_unique_id').agg({'purchase_date':'max', 'order_id':'count', 'payment_value':'sum'})
rfm1_df.columns = ['recency', 'frequency', 'monetary']
rfm1_df

# %%
rfm1_df.recency = rfm1_df.recency.apply(lambda x: (poc1_df.purchase_date.max()-x).days)
rfm1_df

# %%
#rfm1_df = pd.read_csv('rfm3m.csv', index_col=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(rfm1_df)
X_scaled = scaler.transform(rfm1_df)
rfm1_km = KMeans(n_clusters=4).fit(X_scaled)

# %%
plt.scatter(rfm1_df.recency, rfm1_df.monetary, c=rfm1_km.labels_)

# %%
plt.scatter(rfm1_df.frequency, rfm1_df.monetary, c=rfm1_km.labels_)

# %%
rfm2_df = poc2_df.groupby('customer_unique_id').agg({'purchase_date':'max', 'order_id':'count', 'payment_value':'sum'})
rfm2_df.columns = ['recency', 'frequency', 'monetary']
rfm2_df

# %%
m2 = rfm2_df[['monetary']]

# %%
clust1_df = pd.DataFrame()
clust1_df['customer_unique_id'] = rfm1_df.index
clust1_df['segment'] = rfm1_km.labels_
clust1_df

# %%
common_cust = pd.merge(clust1_df, m2, on='customer_unique_id')
common_cust

# %%
X = np.array(common_cust.segment).reshape(-1, 1)
y = common_cust.monetary

# %%
plt.scatter(X, y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

from sklearn.linear_model import LinearRegression
lr = LinearRegression().fit(X_train, y_train)
print(lr.score(X_train, y_train))
print(lr.score(X_test, y_test))

# %%
lr.coef_

# %%
rfm1_m2_df = pd.merge(rfm1_df, m2, left_index=True, right_index=True)
rfm1_m2_df

# %%
plt.scatter(rfm1_m2_df.recency, rfm1_m2_df.monetary_y)

# %%
plt.scatter(rfm1_m2_df.frequency, rfm1_m2_df.monetary_y)

# %%
plt.scatter(rfm1_m2_df.monetary_x, rfm1_m2_df.monetary_y)

# %%
X = rfm1_m2_df.iloc[:,:-1]
y = rfm1_m2_df.iloc[:,-1]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# logistic regression 
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
print('Train Accuracy: ', lr.score(X_train, y_train))
print('Test Accuracy: ', lr.score(X_test, y_test))

# %%
lr.coef_

# %%
common_cust[['monetary']]

# %%
m6m_km = KMeans(n_clusters=2)
m6m_km.fit(common_cust[['monetary']])
plt.scatter(common_cust.monetary, np.zeros([1,common_cust.shape[0]]), c=m6m_km.labels_)

# %%
1-m6m_km.labels_.mean()

# %%
plt.scatter(common_cust.rfm_clust_3m, m6m_km.labels_)

# %%
from sklearn.linear_model import LogisticRegression 
clust_lr = LogisticRegression().fit(common_cust[['rfm_clust_3m']], m6m_km.labels_)

# %%
clust_lr.score(common_cust[['rfm_clust_3m']], m6m_km.labels_)
